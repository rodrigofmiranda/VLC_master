# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Treino + ranking de CVAE para modelagem de canal VLC
====================================================

• Autor:  <Rodrigo Fuchs Miranda>
• Data :  09/06/2025>
"""

# ────────────────────────────────────────────────────────────────────────
# 0)  IMPORTS & BACKEND
# ────────────────────────────────────────────────────────────────────────
import os
import time
import itertools
import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from scipy import stats
import matplotlib.pyplot as plt

# GPU/CPU backend setup
try:
    import cupy as cp
    xp, gpu_enabled = cp, True
    print("CuPy (GPU) backend ativado.")
except ImportError:
    xp, gpu_enabled = np, False
    print("NumPy (CPU) backend ativado.")

# Reproducibilidade
np.random.seed(33)
tf.random.set_seed(33)
if gpu_enabled:
    cp.random.seed(33)

# ────────────────────────────────────────────────────────────────────────
# 1)  CARREGAMENTO E PREPARAÇÃO DOS DADOS
# ────────────────────────────────────────────────────────────────────────
print("Carregando dados...")
base_path = "/workspace/1-Dataset(GNU_RADIO)/FULLSQUARE/IQ_data"

# Verificação dos arquivos
for fname in ["sent_data_tuple.npy", "received_data_tuple_sync-phase.npy"]:
    fpath = os.path.join(base_path, fname)
    if not os.path.exists(fpath):
        raise FileNotFoundError(f"Arquivo não encontrado: {fpath}")
    print(f"Arquivo localizado: {fpath}")

# Carregamento dos dados
X = np.load(os.path.join(base_path, "sent_data_tuple.npy"))
Y = np.load(os.path.join(base_path, "received_data_tuple_sync-phase.npy"))

print(f"Dados carregados - X: {X.shape}, Y: {Y.shape}")

# Embaralhamento e divisão
idx = np.arange(len(X))
np.random.shuffle(idx)
X, Y = X[idx], Y[idx]

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
Y_train, Y_test = Y[:split], Y[split:]

print(f"Divisão - Train: X{X_train.shape}, Y{Y_train.shape}")
print(f"         Test:  X{X_test.shape}, Y{Y_test.shape}")

# ────────────────────────────────────────────────────────────────────────
# 2)  FUNÇÕES DE MÉTRICA
# ────────────────────────────────────────────────────────────────────────

def safe_log10(x, eps=1e-12):
    """Log10 seguro com epsilon para evitar log(0)"""
    return xp.log10(xp.maximum(x, eps))

def safe_log2(x, eps=1e-12):
    """Log2 seguro com epsilon para evitar log(0)"""
    return xp.log2(xp.maximum(x, eps))

def calculate_evm(ref, test):
    """Calcula EVM (Error Vector Magnitude)"""
    ref, test = xp.asarray(ref), xp.asarray(test)
    rc = ref[:,0] + 1j * ref[:,1]
    tc = test[:,0] + 1j * test[:,1]
    
    mean_power = xp.mean(xp.abs(rc)**2)
    if mean_power == 0:
        return float('inf'), float('-inf')
    
    err = tc - rc
    evm_val = xp.sqrt(xp.mean(xp.abs(err)**2) / mean_power)
    evm_pct = float(evm_val * 100)
    evm_db = float(20 * safe_log10(evm_val))
    
    return evm_pct, evm_db

def calculate_snr(ref, test):
    """Calcula SNR (Signal-to-Noise Ratio)"""
    ref, test = xp.asarray(ref), xp.asarray(test)
    rc = ref[:,0] + 1j * ref[:,1]
    tc = test[:,0] + 1j * test[:,1]
    
    noise = rc - tc
    signal_power = xp.mean(xp.abs(rc)**2)
    noise_power = xp.mean(xp.abs(noise)**2)
    
    if noise_power == 0:
        return float('inf') if signal_power > 0 else 0.0
    
    snr_val = signal_power / noise_power
    return float(10 * safe_log10(snr_val))

def calculate_psnr(mse, peak=1.0):
    """Calcula PSNR (Peak Signal-to-Noise Ratio)"""
    if mse <= 0:
        return float('inf') if mse == 0 else float('-inf')
    return float(20 * np.log10(peak) - 10 * np.log10(mse))

def calculate_noise_power(sent, recv):
    """Calcula potência do ruído"""
    sent, recv = xp.asarray(sent), xp.asarray(recv)
    noise = recv - sent
    return float(xp.mean(xp.sum(noise**2, axis=1)))

def compute_basic_metrics(x, y):
    """Calcula métricas básicas (MSE, RMSE, MAE, correlação)"""
    x_gpu, y_gpu = xp.asarray(x), xp.asarray(y)
    err = x_gpu - y_gpu
    
    # MSE e RMSE
    mse = float(xp.mean(xp.sum(err**2, axis=1)))
    rmse = float(xp.sqrt(mse))
    
    # MAE
    mae = float(xp.mean(xp.linalg.norm(err, axis=1)))
    
    # Similaridade cosseno
    norm_x = xp.linalg.norm(x_gpu.ravel())
    norm_y = xp.linalg.norm(y_gpu.ravel())
    if norm_x == 0 or norm_y == 0:
        cos = 0.0
    else:
        cos = float(xp.dot(x_gpu.ravel(), y_gpu.ravel()) / (norm_x * norm_y))
    
    # Correlação (na CPU)
    x_cpu = cp.asnumpy(x_gpu) if gpu_enabled else x_gpu
    y_cpu = cp.asnumpy(y_gpu) if gpu_enabled else y_gpu
    
    if len(x_cpu.ravel()) < 2 or len(y_cpu.ravel()) < 2:
        corr = 0.0
    else:
        try:
            corr_matrix = np.corrcoef(x_cpu.ravel(), y_cpu.ravel())
            corr = float(corr_matrix[0,1]) if corr_matrix.ndim == 2 else 0.0
        except:
            corr = 0.0
    
    return mse, rmse, mae, cos, corr

# --- KDE-based JSD / KL (GPU-ready) ---
def _kde_gpu(data, positions, bw=0.1, batch_size=2000):
    """Estimação de densidade por kernel na GPU"""
    data = xp.asarray(data)
    val = xp.zeros(positions.shape[0], dtype=xp.float32)
    num_points = len(data)
    
    if num_points == 0:
        return val
    
    for i in range(0, num_points, batch_size):
        batch_data = data[i:i+batch_size]
        exp_term = -0.5 * (((batch_data[:,0,None] - positions[:,0])/bw)**2 +
                          ((batch_data[:,1,None] - positions[:,1])/bw)**2)
        val += xp.sum(xp.exp(exp_term), axis=0)
    
    val /= num_points
    val /= (2 * np.pi * bw**2)  # Normalização Gaussiana
    
    sum_val = xp.sum(val)
    if sum_val > 0:
        val /= sum_val
    
    return val

def _prep_grid(grid_res=100, data_min=-1.5, data_max=1.5):
    """Prepara grade para estimação de densidade"""
    xi = xp.linspace(data_min, data_max, grid_res)
    X_grid, Y_grid = xp.meshgrid(xi, xi)
    return xp.stack([X_grid.ravel(), Y_grid.ravel()], axis=1)

def calculate_jsd_gpu(real, pred, grid_res=100, bw=0.1):
    """Calcula Jensen-Shannon Divergence"""
    pos = _prep_grid(grid_res)
    P = _kde_gpu(real, pos, bw)
    Q = _kde_gpu(pred, pos, bw)
    M = 0.5 * (P + Q)
    
    eps = 1e-12
    jsd = 0.5 * xp.sum(xp.where(P > eps, P * safe_log2(P / (M + eps)), 0)) + \
          0.5 * xp.sum(xp.where(Q > eps, Q * safe_log2(Q / (M + eps)), 0))
    
    return float(jsd)

def calculate_kl_gpu(real, pred, grid_res=100, bw=0.1):
    """Calcula Kullback-Leibler Divergence"""
    pos = _prep_grid(grid_res)
    P = _kde_gpu(real, pos, bw)
    Q = _kde_gpu(pred, pos, bw)
    
    eps = 1e-12
    kl_val = xp.sum(xp.where(P > eps, P * xp.log((P + eps) / (Q + eps)), 0))
    
    return float(kl_val)

def calculate_ks_test(data1, data2):
    """Calcula teste Kolmogorov-Smirnov"""
    if gpu_enabled:
        data1 = cp.asnumpy(data1) if isinstance(data1, cp.ndarray) else data1
        data2 = cp.asnumpy(data2) if isinstance(data2, cp.ndarray) else data2
    
    if data1.ndim > 1:
        data1 = data1.ravel()
    if data2.ndim > 1:
        data2 = data2.ravel()
    
    if len(data1) == 0 or len(data2) == 0:
        return 0.0, 0.0
    
    try:
        ks_statistic, p_value = stats.ks_2samp(data1, data2)
        return float(ks_statistic), float(p_value)
    except:
        return 0.0, 0.0

# ────────────────────────────────────────────────────────────────────────
# 3)  DEFINIÇÕES DO VAE
# ────────────────────────────────────────────────────────────────────────

class Sampling(layers.Layer):
    """Camada de amostragem para VAE"""
    def call(self, inputs):
        z_mu, z_logv = inputs
        eps = tf.random.normal(tf.shape(z_mu))
        return z_mu + tf.exp(0.5 * z_logv) * eps

class BetaScheduler(tf.keras.callbacks.Callback):
    """Agendador de beta para VAE"""
    def __init__(self, loss_layer, max_beta=1.0, warmup_epochs=10):
        super().__init__()
        self.loss_layer = loss_layer
        self.max_beta = max_beta
        self.warmup_epochs = warmup_epochs
    
    def on_epoch_begin(self, epoch, logs=None):
        if self.warmup_epochs > 0:
            current_beta = self.max_beta * min(1.0, epoch / self.warmup_epochs)
        else:
            current_beta = self.max_beta
        if isinstance(self.loss_layer.beta, tf.Variable):
            self.loss_layer.beta.assign(current_beta)   # ← use assign()
        else:                                           # fallback de segurança
            self.loss_layer.beta = tf.Variable(current_beta, trainable=False)

class VAELossLayer(layers.Layer):
    """
    Enhanced VAE Loss Layer optimized for VLC channel digital twin modeling.
    
    Combines proper Gaussian NLL with KL divergence and includes robust
    numerical stability measures for telecommunications signal processing.
    """
    
    def __init__(self, beta=1.0, name="vae_loss_layer", **kwargs):
        super().__init__(name=name, **kwargs)
        
        # Use tf.Variable for dynamic beta scheduling during training
        self.beta = tf.Variable(beta, trainable=False, dtype=tf.float32, name="beta")
        
        # Separate metric trackers for monitoring
        self.kl_tracker = tf.keras.metrics.Mean(name="kl_divergence")
        self.nll_tracker = tf.keras.metrics.Mean(name="neg_log_likelihood")
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        
        # Additional metrics for VLC channel analysis
        self.reconstruction_error = tf.keras.metrics.Mean(name="reconstruction_error")

    def call(self, inputs):
        x_in, dec_out, y_true, z_mu, z_logv = inputs
        
        # Separate decoder outputs: mean and log-variance
        mu = dec_out[:, :2]  # First 2 components: I and Q means
        
        # Clip log-variance for numerical stability (critical for VLC signals)
        logv = tf.clip_by_value(dec_out[:, 2:], -10.0, 10.0)
        var = tf.exp(logv) + 1e-8  # Add small epsilon to prevent division by zero
        
        # === NEGATIVE LOG-LIKELIHOOD (Gaussian) ===
        # Complete formula for multivariate Gaussian NLL
        diff_squared = tf.square(y_true - mu)
        
        nll = 0.5 * tf.reduce_mean(
            tf.reduce_sum(
                tf.math.log(2 * np.pi) + logv + (diff_squared / var), 
                axis=-1
            )
        )
        
        # === KL DIVERGENCE ===
        # KL divergence between learned latent distribution and standard Gaussian
        kl_div = -0.5 * tf.reduce_mean(
            tf.reduce_sum(
                1 + z_logv - tf.square(z_mu) - tf.exp(z_logv), 
                axis=-1
            )
        )
        
        # === TOTAL LOSS ===
        total_loss = nll + self.beta * kl_div
        
        # Add loss to the model
        self.add_loss(total_loss)
        
        # === UPDATE METRICS ===
        self.nll_tracker.update_state(nll)
        self.kl_tracker.update_state(kl_div)
        self.total_loss_tracker.update_state(total_loss)
        
        # Track reconstruction error for VLC channel analysis
        mse = tf.reduce_mean(diff_squared)
        self.reconstruction_error.update_state(mse)
        
        # === REPARAMETERIZATION TRICK ===
        # Sample from learned distribution
        eps = tf.random.normal(tf.shape(mu))
        sampled_output = mu + tf.sqrt(var) * eps
        
        return sampled_output

    @property
    def metrics(self):
        """Return all tracked metrics"""
        return [
            self.nll_tracker, 
            self.kl_tracker, 
            self.total_loss_tracker,
            self.reconstruction_error
        ]

    def get_kl(self):
        """Get current KL divergence value - useful for monitoring training"""
        return self.kl_tracker.result().numpy()
    
    def get_nll(self):
        """Get current NLL value - useful for monitoring reconstruction quality"""
        return self.nll_tracker.result().numpy()
    
    def get_reconstruction_error(self):
        """Get current reconstruction MSE - important for VLC channel fidelity"""
        return self.reconstruction_error.result().numpy()
    
    def update_beta(self, new_beta):
        """Update beta value during training (for beta-VAE scheduling)"""
        self.beta.assign(new_beta)
    
    def get_config(self):
        config = super().get_config()
        beta_val = self.beta.numpy() if isinstance(self.beta, tf.Variable) else self.beta
        config.update({"beta": float(beta_val)})
        return config

    @classmethod
    def from_config(cls, config):
        """Enable model loading"""
        return cls(**config)

def build_encoder(layer_sizes, latent_dim, activation):
    """
    Constrói o Encoder CONDICIONAL.
    Recebe tanto o sinal de entrada (condição) quanto o sinal de saída (alvo)
    para aprender a representação latente do CANAL.
    """
    # Define two separate inputs: one for the original signal and one for the target signal
    x_in = layers.Input(shape=(2,), name="encoder_x_input")
    y_in = layers.Input(shape=(2,), name="encoder_y_input")

    # Concatenate the inputs to condition the encoder on both
    concatenated_inputs = layers.Concatenate()([x_in, y_in])
    
    x = concatenated_inputs
    for size in reversed(layer_sizes):
        x = layers.Dense(size, activation=activation)(x)
    
    z_mu = layers.Dense(latent_dim, name="z_mu")(x)
    z_logv = layers.Dense(latent_dim, name="z_log_var")(x)
    
    # The model now takes a list of two inputs
    return models.Model(inputs=[x_in, y_in], outputs=[z_mu, z_logv], name="conditional_encoder")

def build_decoder(layer_sizes, latent_dim, activation):
    """
    Constrói o Decoder CONDICIONAL.
    Recebe o vetor latente 'z' (representando o canal) e o sinal de entrada 'x_in' (a condição)
    para reconstruir o sinal de saída.
    """
    # Define two separate inputs: one for the latent vector and one for the condition
    z_in = layers.Input(shape=(latent_dim,), name="decoder_z_input")
    condition_in = layers.Input(shape=(2,), name="decoder_condition_input")

    # Concatenate the inputs to make the decoding process conditional
    concatenated_inputs = layers.Concatenate()([z_in, condition_in])

    z = concatenated_inputs
    for size in layer_sizes:
        z = layers.Dense(size, activation=activation)(z)
        
    # A saída permanece a mesma: [mu_I, mu_Q, logv_I, logv_Q] 
    out = layers.Dense(4, activation="linear", name="mu_logv")(z)
    
    # The model now takes a list of two inputs
    return models.Model(inputs=[z_in, condition_in], outputs=out, name="conditional_decoder")

def build_conditional_vae(layer_sizes, latent_dim, activation, beta, learning_rate):
    """
    Constrói o CVAE completo com a arquitetura CONDICIONAL correta.
    """
    # Instantiate the corrected conditional encoder and decoder
    enc = build_encoder(layer_sizes, latent_dim, activation)
    dec = build_decoder(layer_sizes, latent_dim, activation)

    # Entradas para o modelo completo 
    x_in = layers.Input(shape=(2,), name="x_in")
    y_true = layers.Input(shape=(2,), name="y_true")

    # --- Forward pass CORRIGIDO ---
    # 1. Encoder recebe X e Y para gerar z (o canal)
    z_mu, z_logv = enc([x_in, y_true])
    
    # 2. Amostragem para obter z 
    z = Sampling()([z_mu, z_logv])
    
    # 3. Decoder recebe z (o canal) e X (a condição) para gerar a predição
    dec_out = dec([z, x_in])

    # A camada de perda e a compilação permanecem as mesmas 
    loss_layer = VAELossLayer(beta=0.0)
    y_out = loss_layer([x_in, dec_out, y_true, z_mu, z_logv])

    vae = models.Model(inputs=[x_in, y_true], outputs=y_out, name="cvae")
    vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=None)

    beta_scheduler = BetaScheduler(loss_layer, max_beta=beta, warmup_epochs=10)

    return vae, beta_scheduler

# ────────────────────────────────────────────────────────────────────────
# 4)  CONFIGURAÇÃO DO GRID SEARCH
# ────────────────────────────────────────────────────────────────────────

param_grid = {
    "layer1": [128],
    "layer2": [256], 
    "layer3": [512],
    "latent_dim": [48,54],
    "beta": [0.48,0.58],
    "batch_size": [12000,20000],
    "learning_rate": [1e-4],
    "activation": ["leaky_relu"]
}

# Configuração de logs
logs_base_dir = "/workspace/2-Training_Codes_Jupyter/logs_runs/"

os.makedirs(logs_base_dir, exist_ok=True)

log_path = os.path.join(logs_base_dir, "experimentos.csv")
ranked_log_path = os.path.join(logs_base_dir, "experimentos_ranked.csv")

# Limpar logs existentes
for path in [log_path, ranked_log_path]:
    if os.path.exists(path):
        print(f"Removendo arquivo existente: {path}")
        os.remove(path)

# ────────────────────────────────────────────────────────────────────────
# 5)  EXECUÇÃO DO GRID SEARCH
# ────────────────────────────────────────────────────────────────────────

print("\nIniciando Grid Search...")
results_list = []
total_combos = len(list(itertools.product(*param_grid.values())))

for i, combo in enumerate(itertools.product(*param_grid.values())):
    params = dict(zip(param_grid.keys(), combo))
    print(f"\n--- Combinação {i+1}/{total_combos} ---")
    print(params)
    
    # Construir modelo
    layer_sizes = [params['layer1'], params['layer2'], params['layer3']]
    vae, beta_scheduler = build_conditional_vae(
        layer_sizes=layer_sizes,
        latent_dim=params['latent_dim'],
        activation=params['activation'],
        beta=params['beta'],
        learning_rate=params['learning_rate']
    )
    
    # Callback de early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )
    
    # Treinamento
    start_time = time.time()
    history = vae.fit(
        [X_train, Y_train], Y_train,
        validation_data=([X_test, Y_test], Y_test),
        epochs=800,
        batch_size=params['batch_size'],
        callbacks=[early_stopping, beta_scheduler],
        verbose=0
    )
    duration = time.time() - start_time
    
    # Extrair métricas do treinamento
    val_losses = history.history.get('val_loss', [])
    best_val_loss = min(val_losses) if val_losses else float('inf')
    epochs_trained = len(history.history['loss'])
    
    # Predições
    Y_pred = vae.predict([X_test, Y_test], 
                        batch_size=params['batch_size'], 
                        verbose=0)
    Y_pred = Y_pred[:len(Y_test)]  # Garantir mesmo tamanho
    
    # Calcular métricas
    try:
        # Métricas básicas
        evm_real_pct, _ = calculate_evm(X_test, Y_test)
        evm_pred_pct, _ = calculate_evm(X_test, Y_pred)
        snr_real = calculate_snr(X_test, Y_test)
        snr_pred = calculate_snr(X_test, Y_pred)
        noise_pow_real = calculate_noise_power(X_test, Y_test)
        noise_pow_pred = calculate_noise_power(X_test, Y_pred)
        
        # Métricas de distribuição
        kl_divergence = calculate_kl_gpu(Y_test, Y_pred)
        jsd = calculate_jsd_gpu(Y_test, Y_pred)
        
        # Testes KS
        ks_stat_i, p_val_i = calculate_ks_test(Y_test[:, 0], Y_pred[:, 0])
        ks_stat_q, p_val_q = calculate_ks_test(Y_test[:, 1], Y_pred[:, 1])
        
        # Métricas básicas
        mse, rmse, mae, cos_sim, corr = compute_basic_metrics(X_test, Y_pred)
        psnr = calculate_psnr(mse)
        
        # KL latente
        kl_latent = 0.0
        for layer in vae.layers:
            if isinstance(layer, VAELossLayer):
                kl_latent = layer.get_kl()
                break
        
    except Exception as e:
        print(f"Erro no cálculo de métricas: {e}")
        # Valores padrão em caso de erro
        evm_real_pct = evm_pred_pct = float('inf')
        snr_real = snr_pred = 0.0
        noise_pow_real = noise_pow_pred = 0.0
        kl_divergence = jsd = float('inf')
        ks_stat_i = ks_stat_q = p_val_i = p_val_q = 0.0
        mse = rmse = mae = psnr = float('inf')
        cos_sim = corr = kl_latent = 0.0
    
    # Registro dos resultados
    result = {
        **params,
        "val_loss": best_val_loss,
        "kl_latent": kl_latent,
        "kl_real_pred": kl_divergence,
        "jsd_real_pred": jsd,
        "ks_stat_i": ks_stat_i,
        "p_value_i": p_val_i,
        "ks_stat_q": ks_stat_q,
        "p_value_q": p_val_q,
        "evm_real_%": evm_real_pct,
        "evm_pred_%": evm_pred_pct,
        "delta_evm_%": evm_pred_pct - evm_real_pct,
        "snr_real_dB": snr_real,
        "snr_pred_dB": snr_pred,
        "delta_snr_dB": snr_pred - snr_real,
        "rmse_pred": rmse,
        "psnr_pred_dB": psnr,
        "diff_noise_pow": noise_pow_pred - noise_pow_real,
        "epochs": epochs_trained,
        "duration_sec": round(duration, 2),
        "timestamp": datetime.datetime.now().isoformat(timespec='seconds')
    }
    
    results_list.append(result)
    
    print(f" → val_loss={result['val_loss']:.4f} | "
          f"ΔEVM={result['delta_evm_%']:+.2f}% | "
          f"ΔSNR={result['delta_snr_dB']:+.2f} dB | "
          f"JSD={result['jsd_real_pred']:.4f}")

# Salvar resultados
df_results = pd.DataFrame(results_list)
df_results.to_csv(log_path, index=False)
print(f"\nResultados salvos em: {log_path}")

# ────────────────────────────────────────────────────────────────────────
# 6)  RANKING DOS MODELOS
# ────────────────────────────────────────────────────────────────────────

print("\nIniciando ranking dos modelos...")

# Critérios de ranking e pesos
ranking_criteria = {
    'delta_evm_%': {'weight': -1.0, 'maximize': False},
    'delta_snr_dB': {'weight': 1.0, 'maximize': True},
    'jsd_real_pred': {'weight': -2.0, 'maximize': False},
    'rmse_pred': {'weight': -1.0, 'maximize': False},
    'diff_noise_pow': {'weight': -0.5, 'maximize': False},
    'p_value_i': {'weight': 1.0, 'maximize': True},
    'p_value_q': {'weight': 1.0, 'maximize': True}
}

# Normalização robusta das métricas
df_normalized = df_results.copy()
df_normalized['score'] = 0.0

for metric, props in ranking_criteria.items():
    if metric in df_results.columns:
        values = df_results[metric]
        
        # Verificar se há variação nos dados
        if values.nunique() <= 1 or not np.isfinite(values).all():
            print(f"Aviso: Métrica '{metric}' tem valores constantes ou inválidos")
            df_normalized[f'{metric}_norm'] = 0.0
            continue
        
        # Normalização robusta (usando mediana e IQR)
        median = values.median()
        q25, q75 = values.quantile([0.25, 0.75])
        iqr = q75 - q25
        
        if iqr == 0:
            print(f"Aviso: IQR zero para métrica '{metric}'")
            df_normalized[f'{metric}_norm'] = 0.0
            continue
        
        # Normalizar
        normalized = (values - median) / iqr
        df_normalized[f'{metric}_norm'] = normalized
        
        # Calcular contribuição para o score
        if props['maximize']:
            score_contrib = normalized * props['weight']
        else:
            score_contrib = -normalized * props['weight']
        
        df_normalized['score'] += score_contrib

# Ranking final
df_ranked = df_normalized.sort_values('score', ascending=False)
df_ranked.to_csv(ranked_log_path, index=False)
print(f"Resultados rankeados salvos em: {ranked_log_path}")

# Mostrar top modelos
TOP_N = 10
display_cols = ['score'] + list(param_grid.keys()) + list(ranking_criteria.keys())
display_cols = [col for col in display_cols if col in df_ranked.columns]

print(f"\n### TOP-{TOP_N} MODELOS ###")
print(df_ranked[display_cols].head(TOP_N).to_string(index=False))

# Selecionar melhor modelo
best_model = df_ranked.iloc[0]
print(f"\nMelhor modelo selecionado com score: {best_model['score']:.4f}")

print("\n🏆 GRID SEARCH CONCLUÍDO! 🏆")
print(f"Total de combinações testadas: {total_combos}")
print(f"Melhor configuração encontrada:")
for param in param_grid.keys():
    if param in best_model.index:
        print(f"  {param}: {best_model[param]}")
# Out:
# CuPy (GPU) backend ativado.
# Carregando dados...
# Arquivo localizado: /workspace/1-Dataset(GNU_RADIO)/FULLSQUARE/IQ_data/sent_data_tuple.npy
# Arquivo localizado: /workspace/1-Dataset(GNU_RADIO)/FULLSQUARE/IQ_data/received_data_tuple_sync-phase.npy
# Dados carregados - X: (900000, 2), Y: (900000, 2)
# Divisão - Train: X(720000, 2), Y(720000, 2)
#          Test:  X(180000, 2), Y(180000, 2)
#
# Iniciando Grid Search...
#
# --- Combinação 1/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.48, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# 2025-06-10 15:40:03.986275: I tensorflow/core/platform/cpu_feature_guard.cc:152] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-10 15:40:04.206142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46104 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:17:00.0, compute capability: 8.6
# 2025-06-10 15:40:06.401414: I tensorflow/stream_executor/cuda/cuda_blas.cc:1804] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Restoring model weights from the end of the best epoch: 267.
# Epoch 287: early stopping
#  → val_loss=-4.6844 | ΔEVM=-0.03% | ΔSNR=+0.01 dB | JSD=0.0000
#
# --- Combinação 2/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.48, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 420.
# Epoch 440: early stopping
#  → val_loss=-4.6874 | ΔEVM=+0.69% | ΔSNR=-0.33 dB | JSD=0.0000
#
# --- Combinação 3/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.58, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 321.
# Epoch 341: early stopping
#  → val_loss=-4.0993 | ΔEVM=+0.66% | ΔSNR=-0.31 dB | JSD=0.0000
#
# --- Combinação 4/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.58, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 405.
# Epoch 425: early stopping
#  → val_loss=-4.0778 | ΔEVM=-0.04% | ΔSNR=+0.02 dB | JSD=0.0000
#
# --- Combinação 5/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.48, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 263.
# Epoch 283: early stopping
#  → val_loss=-4.6922 | ΔEVM=+0.02% | ΔSNR=-0.01 dB | JSD=0.0000
#
# --- Combinação 6/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.48, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 406.
# Epoch 426: early stopping
#  → val_loss=-4.6770 | ΔEVM=+0.09% | ΔSNR=-0.04 dB | JSD=0.0000
#
# --- Combinação 7/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.58, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 280.
# Epoch 300: early stopping
#  → val_loss=-4.0839 | ΔEVM=-0.00% | ΔSNR=+0.00 dB | JSD=0.0000
#
# --- Combinação 8/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.58, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Restoring model weights from the end of the best epoch: 390.
# Epoch 410: early stopping
#  → val_loss=-4.0564 | ΔEVM=-0.02% | ΔSNR=+0.01 dB | JSD=0.0000
#
# Resultados salvos em: /workspace/2-Training_Codes_Jupyter/logs_runs/experimentos.csv
#
# Iniciando ranking dos modelos...
# Resultados rankeados salvos em: /workspace/2-Training_Codes_Jupyter/logs_runs/experimentos_ranked.csv
#
# ### TOP-10 MODELOS ###
#         score  layer1  layer2  layer3  latent_dim  beta  batch_size  learning_rate activation  delta_evm_%  delta_snr_dB  jsd_real_pred  rmse_pred  diff_noise_pow  p_value_i  p_value_q
#     10.757748     128     256     512          48  0.58       12000         0.0001 leaky_relu     0.660200     -0.311787       0.000004   0.152750        0.001616   1.000000        1.0
#      5.683534     128     256     512          48  0.48       20000         0.0001 leaky_relu     0.690855     -0.325995       0.000002   0.153000        0.001693   1.000000        1.0
#      0.189192     128     256     512          54  0.48       20000         0.0001 leaky_relu     0.086889     -0.041678       0.000001   0.148073        0.000209   1.000000        1.0
#      0.094744     128     256     512          54  0.58       12000         0.0001 leaky_relu    -0.001308      0.000629       0.000002   0.147354       -0.000003   1.000000        1.0
#     -0.793135     128     256     512          54  0.48       12000         0.0001 leaky_relu     0.018341     -0.008814       0.000001   0.147514        0.000044   1.000000        1.0
#     -0.974563     128     256     512          48  0.58       20000         0.0001 leaky_relu    -0.039843      0.019178       0.000002   0.147039       -0.000096   1.000000        1.0
#     -6.379603     128     256     512          48  0.48       12000         0.0001 leaky_relu    -0.030300      0.014582       0.000001   0.147117       -0.000073   1.000000        1.0
# -23878.983940     128     256     512          54  0.58       20000         0.0001 leaky_relu    -0.021976      0.010574       0.000001   0.147185       -0.000053   0.999999        1.0
#
# Melhor modelo selecionado com score: 10.7577
#
# 🏆 GRID SEARCH CONCLUÍDO! 🏆
# Total de combinações testadas: 8
# Melhor configuração encontrada:
#   layer1: 128
#   layer2: 256
#   layer3: 512
#   latent_dim: 48
#   beta: 0.58
#   batch_size: 12000
#   learning_rate: 0.0001
#   activation: leaky_relu

# %%
# ────────────────────────────────────────────────────────────────────────
# 7)  RETREINA E SALVA O MODELO CAMPEÃO
# ────────────────────────────────────────────────────────────────────────
print("\nRetreinando o modelo campeão...")

# Selecionar os parâmetros do melhor modelo
best_params = {k: best_model[k] for k in param_grid.keys() if k in best_model.index}

# Construir o modelo campeão
vae_best, beta_cb_champion = build_conditional_vae(
    layer_sizes=[int(best_params['layer1']), int(best_params['layer2']), int(best_params['layer3'])],
    latent_dim=int(best_params['latent_dim']),
    activation=best_params['activation'],
    beta=float(best_params['beta']),
    learning_rate=float(best_params['learning_rate'])
)

# Configurar treinamento do campeão
epochs_champion_retrain = int(best_model['epochs'])
batch_size_champion_retrain = int(best_params['batch_size'])

print(f"Retreinando por {epochs_champion_retrain} épocas com batch_size {batch_size_champion_retrain}")

# Treinar o modelo campeão
history_champion = vae_best.fit(
    [X_train, Y_train], Y_train,
    epochs=epochs_champion_retrain,
    batch_size=batch_size_champion_retrain,
    callbacks=[beta_cb_champion],
    verbose=1
)

# Gerar predições finais
Y_pred_final_champion = vae_best.predict(
    [X_test, Y_test],
    batch_size=batch_size_champion_retrain,
    verbose=0
)
Y_pred_final_champion = Y_pred_final_champion[:Y_test.shape[0]]

# ─── Salvar o modelo campeão em dois formatos ──────────────────────────
modelo_escolhido = "cvae_campeao_exported"     # nome base único
savedmodel_dir   = os.path.join(logs_base_dir, modelo_escolhido)      # pasta
keras_file       = savedmodel_dir + ".keras"                          # arquivo

# 1) SavedModel (pasta)  → bom para TF-Serving / outro notebook
vae_best.save(savedmodel_dir, save_format="tf", include_optimizer=False)

# 2) Arquivo único .keras → prático para versionar/compartilhar
vae_best.save(keras_file, include_optimizer=False)

print("✅ Modelo campeão salvo em:")
print(f"   • {savedmodel_dir}   (SavedModel)")
print(f"   • {keras_file} (.keras)")



# ────────────────────────────────────────────────────────────────────────
# 8)  PLOTS E MÉTRICAS DO CAMPEÃO
# ────────────────────────────────────────────────────────────────────────
print("\nGerando análises visuais e métricas para o modelo campeão...")

# Converter dados para CPU para plotagem
if gpu_enabled:
    y_test_cpu = cp.asnumpy(Y_test) if isinstance(Y_test, cp.ndarray) else Y_test
    y_pred_final_champion_cpu = cp.asnumpy(Y_pred_final_champion) if isinstance(Y_pred_final_champion, cp.ndarray) else Y_pred_final_champion
    x_test_cpu = cp.asnumpy(X_test) if isinstance(X_test, cp.ndarray) else X_test
else:
    y_test_cpu = Y_test
    y_pred_final_champion_cpu = Y_pred_final_champion
    x_test_cpu = X_test

# --- 8.1 Constelações ---
fig_const, ax_const = plt.subplots(1, 2, figsize=(12, 5))

ax_const[0].scatter(y_test_cpu[:,0], y_test_cpu[:,1], s=0.5, alpha=0.6, label="Y_test (Real)")
ax_const[0].set_title("Constelação Recebida (Y_test)")
ax_const[0].set_xlabel("Componente I")
ax_const[0].set_ylabel("Componente Q")
ax_const[0].axis('equal')
ax_const[0].grid(True, linestyle='--', alpha=0.5)
ax_const[0].legend()

ax_const[1].scatter(y_pred_final_champion_cpu[:,0], y_pred_final_champion_cpu[:,1], s=0.5, alpha=0.6, color='red', label="Y_pred (Campeão)")
ax_const[1].set_title("Constelação Reconstruída (Ŷ_campeão)")
ax_const[1].set_xlabel("Componente I")
ax_const[1].set_ylabel("Componente Q")
ax_const[1].axis('equal')
ax_const[1].grid(True, linestyle='--', alpha=0.5)
ax_const[1].legend()

plt.tight_layout()
plt.suptitle("Comparação de Constelações: Real vs. Predição do Campeão", fontsize=16, y=1.03)
plot_save_path_const = os.path.join(logs_base_dir, "campeao_constelacao_plot.png")
plt.savefig(plot_save_path_const, dpi=300, bbox_inches='tight')
print(f"Plot de constelações salvo em: {plot_save_path_const}")
plt.show()

# --- 8.2 Análise de Distribuições de Ruído ---
noise_real = y_test_cpu - x_test_cpu
noise_pred = y_pred_final_champion_cpu - x_test_cpu

noise_real_I = noise_real[:,0]
noise_real_Q = noise_real[:,1]
noise_real_Amp = np.sqrt(noise_real_I**2 + noise_real_Q**2)

noise_pred_I = noise_pred[:,0]
noise_pred_Q = noise_pred[:,1]
noise_pred_Amp = np.sqrt(noise_pred_I**2 + noise_pred_Q**2)

data_to_plot_noise = [
    (noise_real_I, noise_pred_I, 'Componente I do Ruído'),
    (noise_real_Q, noise_pred_Q, 'Componente Q do Ruído'),
    (noise_real_Amp, noise_pred_Amp, 'Amplitude do Ruído')
]

fig_hist_noise, axes_hist_noise = plt.subplots(len(data_to_plot_noise), 1, figsize=(10, 4 * len(data_to_plot_noise)))
if len(data_to_plot_noise) == 1:
    axes_hist_noise = [axes_hist_noise]

for i, (data_r, data_p, title_suffix) in enumerate(data_to_plot_noise):
    min_val = min(np.min(data_r), np.min(data_p))
    max_val = max(np.max(data_r), np.max(data_p))
    bins = np.linspace(min_val, max_val, 50)

    axes_hist_noise[i].hist(data_r, bins=bins, alpha=0.7, label='Ruído Real (Y_test - X_test)', color='blue', density=True)
    axes_hist_noise[i].hist(data_p, bins=bins, alpha=0.7, label='Ruído Predito (Y_pred - X_test)', color='red', density=True)
    axes_hist_noise[i].set_title(f'Histograma Comparativo: {title_suffix}')
    axes_hist_noise[i].set_xlabel('Valor')
    axes_hist_noise[i].set_ylabel('Densidade')
    axes_hist_noise[i].legend()
    axes_hist_noise[i].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.suptitle("Distribuições de Ruído: Real vs. Predito", fontsize=16, y=1.02)
plot_save_path_hist_noise = os.path.join(logs_base_dir, "campeao_histogramas_ruido_plot.png")
plt.savefig(plot_save_path_hist_noise, dpi=300, bbox_inches='tight')
print(f"Plot de histogramas de ruído salvo em: {plot_save_path_hist_noise}")
plt.show()

# --- 8.3 Gráficos Q-Q (Quantil-Quantil) ---
data_to_qq_signal = [
    (y_test_cpu[:,0], y_pred_final_champion_cpu[:,0], 'Componente I do Sinal Recebido'),
    (y_test_cpu[:,1], y_pred_final_champion_cpu[:,1], 'Componente Q do Sinal Recebido'),
]

fig_qq, axes_qq = plt.subplots(1, len(data_to_qq_signal), figsize=(6 * len(data_to_qq_signal), 5))
if len(data_to_qq_signal) == 1:
    axes_qq = [axes_qq]

for i, (data_r, data_p, title_suffix) in enumerate(data_to_qq_signal):
    quantiles = np.linspace(0, 100, 101)
    qn_r = np.percentile(data_r, quantiles)
    qn_p = np.percentile(data_p, quantiles)

    axes_qq[i].plot(qn_r, qn_p, 'o', markersize=3, alpha=0.7)
    min_val_qq = min(np.min(qn_r), np.min(qn_p))
    max_val_qq = max(np.max(qn_r), np.max(qn_p))
    axes_qq[i].plot([min_val_qq, max_val_qq], [min_val_qq, max_val_qq], 'r--', lw=2, label='Linha de Referência')
    axes_qq[i].set_xlabel('Quantis do Sinal Real (Y_test)')
    axes_qq[i].set_ylabel('Quantis do Sinal Predito (Y_pred)')
    axes_qq[i].set_title(f'Gráfico Q-Q: {title_suffix}')
    axes_qq[i].axis('equal')
    axes_qq[i].grid(True, linestyle='--', alpha=0.5)
    axes_qq[i].legend()

plt.tight_layout()
plt.suptitle("Gráficos Q-Q: Sinal Real vs. Predito", fontsize=16, y=1.03)
plot_save_path_qq = os.path.join(logs_base_dir, "campeao_qq_plot.png")
plt.savefig(plot_save_path_qq, dpi=300, bbox_inches='tight')
print(f"Plot Q-Q salvo em: {plot_save_path_qq}")
plt.show()

# --- 8.4 Curva de Transferência do Canal (Magnitude) ---
mag_X_test = np.sqrt(x_test_cpu[:,0]**2 + x_test_cpu[:,1]**2)
mag_Y_test = np.sqrt(y_test_cpu[:,0]**2 + y_test_cpu[:,1]**2)
mag_Y_pred = np.sqrt(y_pred_final_champion_cpu[:,0]**2 + y_pred_final_champion_cpu[:,1]**2)

# Amostragem para visualização
sample_size = min(5000, len(mag_X_test))
sample_indices = np.random.choice(len(mag_X_test), size=sample_size, replace=False)

fig_transfer, ax_transfer = plt.subplots(1, 1, figsize=(10, 7))
ax_transfer.scatter(mag_X_test[sample_indices], mag_Y_test[sample_indices],
                   alpha=0.5, s=10, label='Real (Y_test vs X_test)', color='blue')
ax_transfer.scatter(mag_X_test[sample_indices], mag_Y_pred[sample_indices],
                   alpha=0.5, s=10, label='Predito (Y_pred vs X_test)', color='red')

# Linha de referência (canal ideal)
min_mag, max_mag = np.min(mag_X_test[sample_indices]), np.max(mag_X_test[sample_indices])
ax_transfer.plot([min_mag, max_mag], [min_mag, max_mag], 'k--', lw=2, label='Canal Ideal (y=x)')

ax_transfer.set_xlabel('Magnitude do Sinal de Entrada (X_test)')
ax_transfer.set_ylabel('Magnitude do Sinal de Saída')
ax_transfer.set_title('Curva de Transferência do Canal (Magnitudes)')
ax_transfer.legend()
ax_transfer.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plot_save_path_transfer = os.path.join(logs_base_dir, "campeao_curva_transferencia_plot.png")
plt.savefig(plot_save_path_transfer, dpi=300, bbox_inches='tight')
print(f"Plot da curva de transferência salvo em: {plot_save_path_transfer}")
plt.show()

# --- 8.5 Mapa de Vetores de Erro ---
error_vectors = y_pred_final_champion_cpu - x_test_cpu
sample_indices_ev = np.random.choice(len(error_vectors), size=min(10000, len(error_vectors)), replace=False)

fig_err_vec, ax_err_vec = plt.subplots(1, 1, figsize=(8, 8))
scatter = ax_err_vec.scatter(error_vectors[sample_indices_ev, 0], error_vectors[sample_indices_ev, 1],
                           s=1, alpha=0.3, c=np.sqrt(error_vectors[sample_indices_ev, 0]**2 + error_vectors[sample_indices_ev, 1]**2),
                           cmap='viridis')
ax_err_vec.set_title('Mapa de Vetores de Erro (Ŷ_campeão - X_test)')
ax_err_vec.set_xlabel('Erro Componente I')
ax_err_vec.set_ylabel('Erro Componente Q')
ax_err_vec.axis('equal')
ax_err_vec.grid(True, linestyle='--', alpha=0.5)

# Adicionar colorbar
plt.colorbar(scatter, ax=ax_err_vec, label='Magnitude do Erro')

plt.tight_layout()
plot_save_path_err_vec = os.path.join(logs_base_dir, "campeao_mapa_vetores_erro_plot.png")
plt.savefig(plot_save_path_err_vec, dpi=300, bbox_inches='tight')
print(f"Plot do mapa de vetores de erro salvo em: {plot_save_path_err_vec}")
plt.show()

# --- 8.6 Métricas Finais do Campeão ---
print("\n🏆  MÉTRICAS DO MODELO CAMPEÃO  🏆")
print("=" * 50)
print("Hiperparâmetros:")
for param, value in best_params.items():
    print(f"  {param}: {value}")
print("=" * 50)

# Calcular métricas finais
evm_pct_champ, evm_db_champ = calculate_evm(X_test, Y_pred_final_champion)
snr_db_champ = calculate_snr(X_test, Y_pred_final_champion)
kl_final_champ = calculate_kl_gpu(Y_test, Y_pred_final_champion)
jsd_final_champ = calculate_jsd_gpu(Y_test, Y_pred_final_champion)
mse_final_champ, rmse_final_champ, mae_final_champ, cos_sim_champ, corr_champ = compute_basic_metrics(X_test, Y_pred_final_champion)
psnr_final_champ = calculate_psnr(mse_final_champ)

# Testes Kolmogorov-Smirnov
ks_stat_I, p_value_I = calculate_ks_test(y_test_cpu[:,0], y_pred_final_champion_cpu[:,0])
ks_stat_Q, p_value_Q = calculate_ks_test(y_test_cpu[:,1], y_pred_final_champion_cpu[:,1])
ks_stat_Amp, p_value_Amp = calculate_ks_test(mag_Y_test, mag_Y_pred)
ks_stat_Noise_Amp, p_value_Noise_Amp = calculate_ks_test(noise_real_Amp, noise_pred_Amp)

# Exibir métricas
print(f"MÉTRICAS DE RECONSTRUÇÃO:")
print(f"  EVM (Ŷ vs X_test)          : {evm_pct_champ:.2f}% ({evm_db_champ:.2f} dB)")
print(f"  SNR (Ŷ vs X_test)          : {snr_db_champ:.2f} dB")
print(f"  RMSE (Ŷ vs X_test)         : {rmse_final_champ:.4f}")
print(f"  MSE (Ŷ vs X_test)          : {mse_final_champ:.4f}")
print(f"  MAE (Ŷ vs X_test)          : {mae_final_champ:.4f}")
print(f"  PSNR (Ŷ vs X_test)         : {psnr_final_champ:.2f} dB")
print(f"  Similaridade Cosseno        : {cos_sim_champ:.4f}")
print(f"  Correlação                  : {corr_champ:.4f}")

print(f"\nMÉTRICAS DE DISTRIBUIÇÃO:")
print(f"  KL Divergence (Y_test||Ŷ)  : {kl_final_champ:.4f}")
print(f"  Jensen-Shannon Div. (Y,Ŷ)  : {jsd_final_champ:.4f}")

print(f"\nTESTE KOLMOGOROV-SMIRNOV (Y_test vs Ŷ):")
print(f"  Componente I - Estatística  : {ks_stat_I:.4f} (p-valor: {p_value_I:.4f})")
print(f"  Componente Q - Estatística  : {ks_stat_Q:.4f} (p-valor: {p_value_Q:.4f})")
print(f"  Amplitude Sinal - Estatística: {ks_stat_Amp:.4f} (p-valor: {p_value_Amp:.4f})")
print(f"  Amplitude Ruído - Estatística: {ks_stat_Noise_Amp:.4f} (p-valor: {p_value_Noise_Amp:.4f})")

print("=" * 50)
print(f"Score final do modelo campeão: {best_model['score']:.4f}")
print(f"Tempo de treinamento: {best_model['duration_sec']:.2f} segundos")
print(f"Épocas treinadas: {best_model['epochs']}")
print("=" * 50)

# --- 8.7 Salvar Resumo das Métricas ---
metrics_summary = {
    'model_score': best_model['score'],
    'hyperparameters': best_params,
    'reconstruction_metrics': {
        'evm_percent': evm_pct_champ,
        'evm_db': evm_db_champ,
        'snr_db': snr_db_champ,
        'rmse': rmse_final_champ,
        'mse': mse_final_champ,
        'mae': mae_final_champ,
        'psnr_db': psnr_final_champ,
        'cosine_similarity': cos_sim_champ,
        'correlation': corr_champ
    },
    'distribution_metrics': {
        'kl_divergence': kl_final_champ,
        'jsd': jsd_final_champ
    },
    'ks_tests': {
        'component_I': {'statistic': ks_stat_I, 'p_value': p_value_I},
        'component_Q': {'statistic': ks_stat_Q, 'p_value': p_value_Q},
        'signal_amplitude': {'statistic': ks_stat_Amp, 'p_value': p_value_Amp},
        'noise_amplitude': {'statistic': ks_stat_Noise_Amp, 'p_value': p_value_Noise_Amp}
    },
    'training_info': {
        'epochs': int(best_model['epochs']),
        'duration_sec': float(best_model['duration_sec']),
        'timestamp': best_model['timestamp']
    }
}

# Salvar resumo em JSON
import json
summary_path = os.path.join(logs_base_dir, "champion_model_summary.json")
with open(summary_path, 'w') as f:
    json.dump(metrics_summary, f, indent=2, default=str)
print(f"Resumo das métricas salvo em: {summary_path}")

print("\n🎯 ANÁLISE DO MODELO CAMPEÃO CONCLUÍDA! 🎯")
print(f"Todos os plots e métricas foram salvos em: {logs_base_dir}")
# Out:
# Retreinando o modelo campeão...
# Retreinando por 341 épocas com batch_size 12000
# Epoch 1/341
# 60/60 [==============================] - 1s 7ms/step - loss: 1.1819 - kl_divergence: 0.8729 - neg_log_likelihood: 1.1819 - total_loss: 1.1819 - reconstruction_error: 0.1987
# Epoch 2/341
# 60/60 [==============================] - 0s 8ms/step - loss: -0.0926 - kl_divergence: 6.1704 - neg_log_likelihood: -0.4505 - total_loss: -0.0926 - reconstruction_error: 0.0347
# Epoch 3/341
# 60/60 [==============================] - 0s 7ms/step - loss: -0.1573 - kl_divergence: 5.1433 - neg_log_likelihood: -0.7540 - total_loss: -0.1573 - reconstruction_error: 0.0252
# Epoch 4/341
# 60/60 [==============================] - 0s 8ms/step - loss: -0.3117 - kl_divergence: 2.5413 - neg_log_likelihood: -0.7539 - total_loss: -0.3117 - reconstruction_error: 0.0251
# Epoch 5/341
# 60/60 [==============================] - 0s 8ms/step - loss: -0.5744 - kl_divergence: 1.0768 - neg_log_likelihood: -0.8242 - total_loss: -0.5744 - reconstruction_error: 0.0231
# Epoch 6/341
# 60/60 [==============================] - 0s 8ms/step - loss: -0.7873 - kl_divergence: 0.5609 - neg_log_likelihood: -0.9500 - total_loss: -0.7873 - reconstruction_error: 0.0202
# Epoch 7/341
# 60/60 [==============================] - 0s 7ms/step - loss: -0.9412 - kl_divergence: 0.3692 - neg_log_likelihood: -1.0696 - total_loss: -0.9412 - reconstruction_error: 0.0178
# Epoch 8/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.0447 - kl_divergence: 0.2803 - neg_log_likelihood: -1.1585 - total_loss: -1.0447 - reconstruction_error: 0.0163
# Epoch 9/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.1242 - kl_divergence: 0.2209 - neg_log_likelihood: -1.2268 - total_loss: -1.1242 - reconstruction_error: 0.0153
# Epoch 10/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.1733 - kl_divergence: 0.1734 - neg_log_likelihood: -1.2638 - total_loss: -1.1733 - reconstruction_error: 0.0148
# Epoch 11/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.2202 - kl_divergence: 0.1317 - neg_log_likelihood: -1.2966 - total_loss: -1.2202 - reconstruction_error: 0.0144
# Epoch 12/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.2665 - kl_divergence: 0.1149 - neg_log_likelihood: -1.3332 - total_loss: -1.2665 - reconstruction_error: 0.0140
# Epoch 13/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.3054 - kl_divergence: 0.1138 - neg_log_likelihood: -1.3715 - total_loss: -1.3054 - reconstruction_error: 0.0136
# Epoch 14/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.3381 - kl_divergence: 0.1180 - neg_log_likelihood: -1.4066 - total_loss: -1.3381 - reconstruction_error: 0.0132
# Epoch 15/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.3693 - kl_divergence: 0.1254 - neg_log_likelihood: -1.4421 - total_loss: -1.3693 - reconstruction_error: 0.0128
# Epoch 16/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.3996 - kl_divergence: 0.1373 - neg_log_likelihood: -1.4793 - total_loss: -1.3996 - reconstruction_error: 0.0124
# Epoch 17/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.4216 - kl_divergence: 0.1518 - neg_log_likelihood: -1.5096 - total_loss: -1.4216 - reconstruction_error: 0.0121
# Epoch 18/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.4477 - kl_divergence: 0.1714 - neg_log_likelihood: -1.5471 - total_loss: -1.4477 - reconstruction_error: 0.0117
# Epoch 19/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.4705 - kl_divergence: 0.1958 - neg_log_likelihood: -1.5840 - total_loss: -1.4705 - reconstruction_error: 0.0114
# Epoch 20/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.4928 - kl_divergence: 0.2230 - neg_log_likelihood: -1.6222 - total_loss: -1.4928 - reconstruction_error: 0.0110
# Epoch 21/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.5128 - kl_divergence: 0.2534 - neg_log_likelihood: -1.6597 - total_loss: -1.5128 - reconstruction_error: 0.0106
# Epoch 22/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.5315 - kl_divergence: 0.2887 - neg_log_likelihood: -1.6989 - total_loss: -1.5315 - reconstruction_error: 0.0103
# Epoch 23/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.5485 - kl_divergence: 0.3245 - neg_log_likelihood: -1.7367 - total_loss: -1.5485 - reconstruction_error: 0.0099
# Epoch 24/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.5678 - kl_divergence: 0.3694 - neg_log_likelihood: -1.7820 - total_loss: -1.5678 - reconstruction_error: 0.0095
# Epoch 25/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.5868 - kl_divergence: 0.4264 - neg_log_likelihood: -1.8341 - total_loss: -1.5868 - reconstruction_error: 0.0090
# Epoch 26/341
# 60/60 [==============================] - 0s 7ms/step - loss: -1.6054 - kl_divergence: 0.4922 - neg_log_likelihood: -1.8909 - total_loss: -1.6054 - reconstruction_error: 0.0085
# Epoch 27/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.6199 - kl_divergence: 0.5424 - neg_log_likelihood: -1.9345 - total_loss: -1.6199 - reconstruction_error: 0.0082
# Epoch 28/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.6445 - kl_divergence: 0.6036 - neg_log_likelihood: -1.9945 - total_loss: -1.6445 - reconstruction_error: 0.0077
# Epoch 29/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.6603 - kl_divergence: 0.6690 - neg_log_likelihood: -2.0483 - total_loss: -1.6603 - reconstruction_error: 0.0073
# Epoch 30/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.6809 - kl_divergence: 0.7393 - neg_log_likelihood: -2.1097 - total_loss: -1.6809 - reconstruction_error: 0.0069
# Epoch 31/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.7082 - kl_divergence: 0.8602 - neg_log_likelihood: -2.2071 - total_loss: -1.7082 - reconstruction_error: 0.0062
# Epoch 32/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.7564 - kl_divergence: 1.1351 - neg_log_likelihood: -2.4148 - total_loss: -1.7564 - reconstruction_error: 0.0050
# Epoch 33/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.8070 - kl_divergence: 1.3723 - neg_log_likelihood: -2.6030 - total_loss: -1.8070 - reconstruction_error: 0.0041
# Epoch 34/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.8490 - kl_divergence: 1.5088 - neg_log_likelihood: -2.7241 - total_loss: -1.8490 - reconstruction_error: 0.0036
# Epoch 35/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.8823 - kl_divergence: 1.6251 - neg_log_likelihood: -2.8248 - total_loss: -1.8823 - reconstruction_error: 0.0032
# Epoch 36/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.9084 - kl_divergence: 1.6842 - neg_log_likelihood: -2.8853 - total_loss: -1.9084 - reconstruction_error: 0.0031
# Epoch 37/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.9507 - kl_divergence: 1.8027 - neg_log_likelihood: -2.9963 - total_loss: -1.9507 - reconstruction_error: 0.0027
# Epoch 38/341
# 60/60 [==============================] - 0s 8ms/step - loss: -1.9727 - kl_divergence: 1.8702 - neg_log_likelihood: -3.0574 - total_loss: -1.9727 - reconstruction_error: 0.0026
# Epoch 39/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.0129 - kl_divergence: 1.9592 - neg_log_likelihood: -3.1493 - total_loss: -2.0129 - reconstruction_error: 0.0024
# Epoch 40/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.0385 - kl_divergence: 2.0256 - neg_log_likelihood: -3.2133 - total_loss: -2.0385 - reconstruction_error: 0.0022
# Epoch 41/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.0718 - kl_divergence: 2.1089 - neg_log_likelihood: -3.2950 - total_loss: -2.0718 - reconstruction_error: 0.0021
# Epoch 42/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.0940 - kl_divergence: 2.1666 - neg_log_likelihood: -3.3507 - total_loss: -2.0940 - reconstruction_error: 0.0020
# Epoch 43/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.1216 - kl_divergence: 2.2415 - neg_log_likelihood: -3.4216 - total_loss: -2.1216 - reconstruction_error: 0.0018
# Epoch 44/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.1488 - kl_divergence: 2.2947 - neg_log_likelihood: -3.4797 - total_loss: -2.1488 - reconstruction_error: 0.0017
# Epoch 45/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.1772 - kl_divergence: 2.3718 - neg_log_likelihood: -3.5528 - total_loss: -2.1772 - reconstruction_error: 0.0016
# Epoch 46/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.2015 - kl_divergence: 2.4286 - neg_log_likelihood: -3.6101 - total_loss: -2.2015 - reconstruction_error: 0.0015
# Epoch 47/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.2301 - kl_divergence: 2.4991 - neg_log_likelihood: -3.6796 - total_loss: -2.2301 - reconstruction_error: 0.0014
# Epoch 48/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.2525 - kl_divergence: 2.5424 - neg_log_likelihood: -3.7271 - total_loss: -2.2525 - reconstruction_error: 0.0014
# Epoch 49/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.2649 - kl_divergence: 2.5911 - neg_log_likelihood: -3.7677 - total_loss: -2.2649 - reconstruction_error: 0.0013
# Epoch 50/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.3029 - kl_divergence: 2.6459 - neg_log_likelihood: -3.8375 - total_loss: -2.3029 - reconstruction_error: 0.0012
# Epoch 51/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.3326 - kl_divergence: 2.7355 - neg_log_likelihood: -3.9192 - total_loss: -2.3326 - reconstruction_error: 0.0011
# Epoch 52/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.3533 - kl_divergence: 2.7891 - neg_log_likelihood: -3.9710 - total_loss: -2.3533 - reconstruction_error: 0.0011
# Epoch 53/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.3764 - kl_divergence: 2.8245 - neg_log_likelihood: -4.0146 - total_loss: -2.3764 - reconstruction_error: 0.0011
# Epoch 54/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.3929 - kl_divergence: 2.8819 - neg_log_likelihood: -4.0643 - total_loss: -2.3929 - reconstruction_error: 0.0010
# Epoch 55/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.4228 - kl_divergence: 2.9558 - neg_log_likelihood: -4.1371 - total_loss: -2.4228 - reconstruction_error: 9.3562e-04
# Epoch 56/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.4398 - kl_divergence: 2.9771 - neg_log_likelihood: -4.1666 - total_loss: -2.4398 - reconstruction_error: 9.1182e-04
# Epoch 57/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.4710 - kl_divergence: 3.0429 - neg_log_likelihood: -4.2358 - total_loss: -2.4710 - reconstruction_error: 8.5593e-04
# Epoch 58/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.4875 - kl_divergence: 3.0952 - neg_log_likelihood: -4.2827 - total_loss: -2.4875 - reconstruction_error: 8.1944e-04
# Epoch 59/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.5167 - kl_divergence: 3.1629 - neg_log_likelihood: -4.3512 - total_loss: -2.5167 - reconstruction_error: 7.6839e-04
# Epoch 60/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.5389 - kl_divergence: 3.2041 - neg_log_likelihood: -4.3973 - total_loss: -2.5389 - reconstruction_error: 7.3711e-04
# Epoch 61/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.5565 - kl_divergence: 3.2605 - neg_log_likelihood: -4.4476 - total_loss: -2.5565 - reconstruction_error: 7.0359e-04
# Epoch 62/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.5737 - kl_divergence: 3.2980 - neg_log_likelihood: -4.4866 - total_loss: -2.5737 - reconstruction_error: 6.7851e-04
# Epoch 63/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.5861 - kl_divergence: 3.3332 - neg_log_likelihood: -4.5194 - total_loss: -2.5861 - reconstruction_error: 6.5790e-04
# Epoch 64/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.6229 - kl_divergence: 3.3905 - neg_log_likelihood: -4.5894 - total_loss: -2.6229 - reconstruction_error: 6.1844e-04
# Epoch 65/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.6126 - kl_divergence: 3.3856 - neg_log_likelihood: -4.5762 - total_loss: -2.6126 - reconstruction_error: 6.2361e-04
# Epoch 66/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.6581 - kl_divergence: 3.5223 - neg_log_likelihood: -4.7011 - total_loss: -2.6581 - reconstruction_error: 5.5776e-04
# Epoch 67/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.6756 - kl_divergence: 3.4785 - neg_log_likelihood: -4.6931 - total_loss: -2.6756 - reconstruction_error: 5.6274e-04
# Epoch 68/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7077 - kl_divergence: 3.5955 - neg_log_likelihood: -4.7931 - total_loss: -2.7077 - reconstruction_error: 5.1371e-04
# Epoch 69/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7263 - kl_divergence: 3.6484 - neg_log_likelihood: -4.8423 - total_loss: -2.7263 - reconstruction_error: 4.9129e-04
# Epoch 70/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7008 - kl_divergence: 3.6103 - neg_log_likelihood: -4.7947 - total_loss: -2.7008 - reconstruction_error: 5.0897e-04
# Epoch 71/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.7420 - kl_divergence: 3.7373 - neg_log_likelihood: -4.9096 - total_loss: -2.7420 - reconstruction_error: 4.6035e-04
# Epoch 72/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.7944 - kl_divergence: 3.7131 - neg_log_likelihood: -4.9480 - total_loss: -2.7944 - reconstruction_error: 4.4837e-04
# Epoch 73/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7814 - kl_divergence: 3.7767 - neg_log_likelihood: -4.9719 - total_loss: -2.7814 - reconstruction_error: 4.3579e-04
# Epoch 74/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7718 - kl_divergence: 3.7940 - neg_log_likelihood: -4.9723 - total_loss: -2.7718 - reconstruction_error: 4.3321e-04
# Epoch 75/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.8294 - kl_divergence: 3.8735 - neg_log_likelihood: -5.0760 - total_loss: -2.8294 - reconstruction_error: 3.9709e-04
# Epoch 76/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7991 - kl_divergence: 3.7958 - neg_log_likelihood: -5.0007 - total_loss: -2.7991 - reconstruction_error: 4.2212e-04
# Epoch 77/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8733 - kl_divergence: 3.9938 - neg_log_likelihood: -5.1897 - total_loss: -2.8733 - reconstruction_error: 3.5973e-04
# Epoch 78/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8944 - kl_divergence: 4.0138 - neg_log_likelihood: -5.2223 - total_loss: -2.8944 - reconstruction_error: 3.4929e-04
# Epoch 79/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8738 - kl_divergence: 4.0300 - neg_log_likelihood: -5.2112 - total_loss: -2.8738 - reconstruction_error: 3.5079e-04
# Epoch 80/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9209 - kl_divergence: 4.0710 - neg_log_likelihood: -5.2820 - total_loss: -2.9209 - reconstruction_error: 3.3133e-04
# Epoch 81/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9289 - kl_divergence: 4.0889 - neg_log_likelihood: -5.3005 - total_loss: -2.9289 - reconstruction_error: 3.2593e-04
# Epoch 82/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9293 - kl_divergence: 4.1489 - neg_log_likelihood: -5.3357 - total_loss: -2.9293 - reconstruction_error: 3.1521e-04
# Epoch 83/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8297 - kl_divergence: 4.0288 - neg_log_likelihood: -5.1664 - total_loss: -2.8297 - reconstruction_error: 3.5760e-04
# Epoch 84/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0208 - kl_divergence: 4.1323 - neg_log_likelihood: -5.4176 - total_loss: -3.0208 - reconstruction_error: 2.9762e-04
# Epoch 85/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8403 - kl_divergence: 4.1710 - neg_log_likelihood: -5.2596 - total_loss: -2.8403 - reconstruction_error: 3.2667e-04
# Epoch 86/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0423 - kl_divergence: 4.1675 - neg_log_likelihood: -5.4594 - total_loss: -3.0423 - reconstruction_error: 2.8646e-04
# Epoch 87/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9617 - kl_divergence: 4.3028 - neg_log_likelihood: -5.4573 - total_loss: -2.9617 - reconstruction_error: 2.7958e-04
# Epoch 88/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9611 - kl_divergence: 4.1596 - neg_log_likelihood: -5.3737 - total_loss: -2.9611 - reconstruction_error: 3.0009e-04
# Epoch 89/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0668 - kl_divergence: 4.3840 - neg_log_likelihood: -5.6096 - total_loss: -3.0668 - reconstruction_error: 2.4940e-04
# Epoch 90/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0787 - kl_divergence: 4.4298 - neg_log_likelihood: -5.6480 - total_loss: -3.0787 - reconstruction_error: 2.4104e-04
# Epoch 91/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0977 - kl_divergence: 4.4767 - neg_log_likelihood: -5.6942 - total_loss: -3.0977 - reconstruction_error: 2.3208e-04
# Epoch 92/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.9615 - kl_divergence: 4.4068 - neg_log_likelihood: -5.5174 - total_loss: -2.9615 - reconstruction_error: 2.6105e-04
# Epoch 93/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.1322 - kl_divergence: 4.3487 - neg_log_likelihood: -5.6545 - total_loss: -3.1322 - reconstruction_error: 2.4110e-04
# Epoch 94/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.8091 - kl_divergence: 4.4779 - neg_log_likelihood: -5.4063 - total_loss: -2.8091 - reconstruction_error: 2.8005e-04
# Epoch 95/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.1385 - kl_divergence: 4.2406 - neg_log_likelihood: -5.5981 - total_loss: -3.1385 - reconstruction_error: 2.5234e-04
# Epoch 96/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.1012 - kl_divergence: 4.5862 - neg_log_likelihood: -5.7612 - total_loss: -3.1012 - reconstruction_error: 2.1674e-04
# Epoch 97/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.1823 - kl_divergence: 4.5454 - neg_log_likelihood: -5.8187 - total_loss: -3.1823 - reconstruction_error: 2.0819e-04
# Epoch 98/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.0388 - kl_divergence: 4.5593 - neg_log_likelihood: -5.6831 - total_loss: -3.0388 - reconstruction_error: 2.2556e-04
# Epoch 99/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2149 - kl_divergence: 4.5832 - neg_log_likelihood: -5.8731 - total_loss: -3.2149 - reconstruction_error: 2.0011e-04
# Epoch 100/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.1056 - kl_divergence: 4.7052 - neg_log_likelihood: -5.8346 - total_loss: -3.1056 - reconstruction_error: 2.0121e-04
# Epoch 101/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.8840 - kl_divergence: 4.3151 - neg_log_likelihood: -5.3868 - total_loss: -2.8840 - reconstruction_error: 2.7388e-04
# Epoch 102/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2754 - kl_divergence: 4.5740 - neg_log_likelihood: -5.9283 - total_loss: -3.2754 - reconstruction_error: 1.9259e-04
# Epoch 103/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2369 - kl_divergence: 4.8164 - neg_log_likelihood: -6.0304 - total_loss: -3.2369 - reconstruction_error: 1.7421e-04
# Epoch 104/341
# 60/60 [==============================] - 0s 7ms/step - loss: -2.9450 - kl_divergence: 4.6062 - neg_log_likelihood: -5.6166 - total_loss: -2.9450 - reconstruction_error: 2.2898e-04
# Epoch 105/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2497 - kl_divergence: 4.6863 - neg_log_likelihood: -5.9677 - total_loss: -3.2497 - reconstruction_error: 1.8355e-04
# Epoch 106/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2900 - kl_divergence: 4.8150 - neg_log_likelihood: -6.0827 - total_loss: -3.2900 - reconstruction_error: 1.6675e-04
# Epoch 107/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2691 - kl_divergence: 4.9117 - neg_log_likelihood: -6.1179 - total_loss: -3.2691 - reconstruction_error: 1.6163e-04
# Epoch 108/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.1906 - kl_divergence: 4.8430 - neg_log_likelihood: -5.9995 - total_loss: -3.1906 - reconstruction_error: 1.7472e-04
# Epoch 109/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2782 - kl_divergence: 4.8458 - neg_log_likelihood: -6.0888 - total_loss: -3.2782 - reconstruction_error: 1.6488e-04
# Epoch 110/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.1675 - kl_divergence: 4.7965 - neg_log_likelihood: -5.9495 - total_loss: -3.1675 - reconstruction_error: 1.7923e-04
# Epoch 111/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2730 - kl_divergence: 4.9180 - neg_log_likelihood: -6.1255 - total_loss: -3.2730 - reconstruction_error: 1.5976e-04
# Epoch 112/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.3306 - kl_divergence: 4.9079 - neg_log_likelihood: -6.1772 - total_loss: -3.3306 - reconstruction_error: 1.5364e-04
# Epoch 113/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2213 - kl_divergence: 5.0228 - neg_log_likelihood: -6.1346 - total_loss: -3.2213 - reconstruction_error: 1.5634e-04
# Epoch 114/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2827 - kl_divergence: 4.8783 - neg_log_likelihood: -6.1121 - total_loss: -3.2827 - reconstruction_error: 1.5883e-04
# Epoch 115/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4075 - kl_divergence: 5.0172 - neg_log_likelihood: -6.3174 - total_loss: -3.4075 - reconstruction_error: 1.3937e-04
# Epoch 116/341
# 60/60 [==============================] - 0s 8ms/step - loss: -2.7300 - kl_divergence: 5.0620 - neg_log_likelihood: -5.6659 - total_loss: -2.7300 - reconstruction_error: 2.0950e-04
# Epoch 117/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.3117 - kl_divergence: 4.5848 - neg_log_likelihood: -5.9709 - total_loss: -3.3117 - reconstruction_error: 1.7748e-04
# Epoch 118/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4117 - kl_divergence: 4.9605 - neg_log_likelihood: -6.2888 - total_loss: -3.4117 - reconstruction_error: 1.4220e-04
# Epoch 119/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.3861 - kl_divergence: 5.1110 - neg_log_likelihood: -6.3505 - total_loss: -3.3861 - reconstruction_error: 1.3377e-04
# Epoch 120/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2853 - kl_divergence: 5.1360 - neg_log_likelihood: -6.2641 - total_loss: -3.2853 - reconstruction_error: 1.3954e-04
# Epoch 121/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4464 - kl_divergence: 5.1408 - neg_log_likelihood: -6.4281 - total_loss: -3.4464 - reconstruction_error: 1.2725e-04
# Epoch 122/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2275 - kl_divergence: 5.0742 - neg_log_likelihood: -6.1705 - total_loss: -3.2275 - reconstruction_error: 1.4725e-04
# Epoch 123/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4053 - kl_divergence: 5.2057 - neg_log_likelihood: -6.4247 - total_loss: -3.4053 - reconstruction_error: 1.2606e-04
# Epoch 124/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.2957 - kl_divergence: 5.1885 - neg_log_likelihood: -6.3050 - total_loss: -3.2957 - reconstruction_error: 1.3392e-04
# Epoch 125/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4195 - kl_divergence: 5.1791 - neg_log_likelihood: -6.4233 - total_loss: -3.4195 - reconstruction_error: 1.2589e-04
# Epoch 126/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4536 - kl_divergence: 5.2555 - neg_log_likelihood: -6.5018 - total_loss: -3.4536 - reconstruction_error: 1.1859e-04
# Epoch 127/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4107 - kl_divergence: 5.3418 - neg_log_likelihood: -6.5090 - total_loss: -3.4107 - reconstruction_error: 1.1737e-04
# Epoch 128/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4298 - kl_divergence: 5.3261 - neg_log_likelihood: -6.5189 - total_loss: -3.4298 - reconstruction_error: 1.1590e-04
# Epoch 129/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4777 - kl_divergence: 5.3322 - neg_log_likelihood: -6.5704 - total_loss: -3.4777 - reconstruction_error: 1.1288e-04
# Epoch 130/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.2513 - kl_divergence: 5.3351 - neg_log_likelihood: -6.3457 - total_loss: -3.2513 - reconstruction_error: 1.2648e-04
# Epoch 131/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.5744 - kl_divergence: 5.3284 - neg_log_likelihood: -6.6649 - total_loss: -3.5744 - reconstruction_error: 1.0660e-04
# Epoch 132/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.1118 - kl_divergence: 5.3656 - neg_log_likelihood: -6.2238 - total_loss: -3.1118 - reconstruction_error: 1.3302e-04
# Epoch 133/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.5743 - kl_divergence: 5.3320 - neg_log_likelihood: -6.6669 - total_loss: -3.5743 - reconstruction_error: 1.0599e-04
# Epoch 134/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4107 - kl_divergence: 5.5177 - neg_log_likelihood: -6.6110 - total_loss: -3.4107 - reconstruction_error: 1.0656e-04
# Epoch 135/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6457 - kl_divergence: 5.5004 - neg_log_likelihood: -6.8359 - total_loss: -3.6457 - reconstruction_error: 9.4218e-05
# Epoch 136/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4679 - kl_divergence: 5.5927 - neg_log_likelihood: -6.7117 - total_loss: -3.4679 - reconstruction_error: 1.0027e-04
# Epoch 137/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.5456 - kl_divergence: 5.5624 - neg_log_likelihood: -6.7718 - total_loss: -3.5456 - reconstruction_error: 9.6915e-05
# Epoch 138/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6288 - kl_divergence: 5.6309 - neg_log_likelihood: -6.8947 - total_loss: -3.6288 - reconstruction_error: 8.9569e-05
# Epoch 139/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.4375 - kl_divergence: 5.6823 - neg_log_likelihood: -6.7332 - total_loss: -3.4375 - reconstruction_error: 9.8092e-05
# Epoch 140/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6534 - kl_divergence: 5.5915 - neg_log_likelihood: -6.8965 - total_loss: -3.6534 - reconstruction_error: 8.9134e-05
# Epoch 141/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6403 - kl_divergence: 5.6693 - neg_log_likelihood: -6.9285 - total_loss: -3.6403 - reconstruction_error: 8.7158e-05
# Epoch 142/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.5709 - kl_divergence: 5.7047 - neg_log_likelihood: -6.8796 - total_loss: -3.5709 - reconstruction_error: 8.9412e-05
# Epoch 143/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6429 - kl_divergence: 5.6900 - neg_log_likelihood: -6.9431 - total_loss: -3.6429 - reconstruction_error: 8.5980e-05
# Epoch 144/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6528 - kl_divergence: 5.7067 - neg_log_likelihood: -6.9627 - total_loss: -3.6528 - reconstruction_error: 8.4750e-05
# Epoch 145/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.5661 - kl_divergence: 5.7003 - neg_log_likelihood: -6.8723 - total_loss: -3.5661 - reconstruction_error: 8.9228e-05
# Epoch 146/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6787 - kl_divergence: 5.7323 - neg_log_likelihood: -7.0034 - total_loss: -3.6787 - reconstruction_error: 8.2222e-05
# Epoch 147/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6499 - kl_divergence: 5.7476 - neg_log_likelihood: -6.9836 - total_loss: -3.6499 - reconstruction_error: 8.3086e-05
# Epoch 148/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6557 - kl_divergence: 5.7522 - neg_log_likelihood: -6.9920 - total_loss: -3.6557 - reconstruction_error: 8.2587e-05
# Epoch 149/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6980 - kl_divergence: 5.7578 - neg_log_likelihood: -7.0375 - total_loss: -3.6980 - reconstruction_error: 8.0062e-05
# Epoch 150/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6221 - kl_divergence: 5.7823 - neg_log_likelihood: -6.9758 - total_loss: -3.6221 - reconstruction_error: 8.3015e-05
# Epoch 151/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7356 - kl_divergence: 5.7614 - neg_log_likelihood: -7.0772 - total_loss: -3.7356 - reconstruction_error: 7.7994e-05
# Epoch 152/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7225 - kl_divergence: 5.7918 - neg_log_likelihood: -7.0817 - total_loss: -3.7225 - reconstruction_error: 7.7691e-05
# Epoch 153/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.5939 - kl_divergence: 5.7875 - neg_log_likelihood: -6.9506 - total_loss: -3.5939 - reconstruction_error: 8.3966e-05
# Epoch 154/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7173 - kl_divergence: 5.7818 - neg_log_likelihood: -7.0707 - total_loss: -3.7173 - reconstruction_error: 7.7795e-05
# Epoch 155/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7439 - kl_divergence: 5.8092 - neg_log_likelihood: -7.1132 - total_loss: -3.7439 - reconstruction_error: 7.5803e-05
# Epoch 156/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6513 - kl_divergence: 5.8203 - neg_log_likelihood: -7.0271 - total_loss: -3.6513 - reconstruction_error: 7.9785e-05
# Epoch 157/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7742 - kl_divergence: 5.8083 - neg_log_likelihood: -7.1430 - total_loss: -3.7742 - reconstruction_error: 7.3982e-05
# Epoch 158/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7642 - kl_divergence: 5.8294 - neg_log_likelihood: -7.1453 - total_loss: -3.7642 - reconstruction_error: 7.3796e-05
# Epoch 159/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.6592 - kl_divergence: 5.8420 - neg_log_likelihood: -7.0476 - total_loss: -3.6592 - reconstruction_error: 7.8571e-05
# Epoch 160/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8083 - kl_divergence: 5.8210 - neg_log_likelihood: -7.1844 - total_loss: -3.8083 - reconstruction_error: 7.1815e-05
# Epoch 161/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7783 - kl_divergence: 5.8481 - neg_log_likelihood: -7.1702 - total_loss: -3.7783 - reconstruction_error: 7.2488e-05
# Epoch 162/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.7544 - kl_divergence: 5.8573 - neg_log_likelihood: -7.1516 - total_loss: -3.7544 - reconstruction_error: 7.3116e-05
# Epoch 163/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7850 - kl_divergence: 5.8542 - neg_log_likelihood: -7.1805 - total_loss: -3.7850 - reconstruction_error: 7.1856e-05
# Epoch 164/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7008 - kl_divergence: 5.8620 - neg_log_likelihood: -7.1008 - total_loss: -3.7008 - reconstruction_error: 7.5583e-05
# Epoch 165/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7906 - kl_divergence: 5.8586 - neg_log_likelihood: -7.1885 - total_loss: -3.7906 - reconstruction_error: 7.1362e-05
# Epoch 166/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7736 - kl_divergence: 5.8670 - neg_log_likelihood: -7.1764 - total_loss: -3.7736 - reconstruction_error: 7.1729e-05
# Epoch 167/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7737 - kl_divergence: 5.8724 - neg_log_likelihood: -7.1797 - total_loss: -3.7737 - reconstruction_error: 7.1640e-05
# Epoch 168/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7782 - kl_divergence: 5.8772 - neg_log_likelihood: -7.1869 - total_loss: -3.7782 - reconstruction_error: 7.1382e-05
# Epoch 169/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8418 - kl_divergence: 5.8795 - neg_log_likelihood: -7.2519 - total_loss: -3.8418 - reconstruction_error: 6.8244e-05
# Epoch 170/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7727 - kl_divergence: 5.8872 - neg_log_likelihood: -7.1873 - total_loss: -3.7727 - reconstruction_error: 7.1108e-05
# Epoch 171/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8148 - kl_divergence: 5.8899 - neg_log_likelihood: -7.2309 - total_loss: -3.8148 - reconstruction_error: 6.9182e-05
# Epoch 172/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8223 - kl_divergence: 5.8908 - neg_log_likelihood: -7.2390 - total_loss: -3.8223 - reconstruction_error: 6.8683e-05
# Epoch 173/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8145 - kl_divergence: 5.8996 - neg_log_likelihood: -7.2363 - total_loss: -3.8145 - reconstruction_error: 6.8813e-05
# Epoch 174/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8352 - kl_divergence: 5.8999 - neg_log_likelihood: -7.2571 - total_loss: -3.8352 - reconstruction_error: 6.7818e-05
# Epoch 175/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7735 - kl_divergence: 5.9029 - neg_log_likelihood: -7.1972 - total_loss: -3.7735 - reconstruction_error: 7.0518e-05
# Epoch 176/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8522 - kl_divergence: 5.8994 - neg_log_likelihood: -7.2738 - total_loss: -3.8522 - reconstruction_error: 6.7042e-05
# Epoch 177/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8398 - kl_divergence: 5.9074 - neg_log_likelihood: -7.2661 - total_loss: -3.8398 - reconstruction_error: 6.7410e-05
# Epoch 178/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8858 - kl_divergence: 5.9117 - neg_log_likelihood: -7.3145 - total_loss: -3.8858 - reconstruction_error: 6.5135e-05
# Epoch 179/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8500 - kl_divergence: 5.9146 - neg_log_likelihood: -7.2805 - total_loss: -3.8500 - reconstruction_error: 6.6704e-05
# Epoch 180/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.7534 - kl_divergence: 5.9116 - neg_log_likelihood: -7.1821 - total_loss: -3.7534 - reconstruction_error: 7.1140e-05
# Epoch 181/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8284 - kl_divergence: 5.9157 - neg_log_likelihood: -7.2595 - total_loss: -3.8284 - reconstruction_error: 6.7578e-05
# Epoch 182/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9044 - kl_divergence: 5.9156 - neg_log_likelihood: -7.3354 - total_loss: -3.9044 - reconstruction_error: 6.3984e-05
# Epoch 183/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8570 - kl_divergence: 5.9203 - neg_log_likelihood: -7.2908 - total_loss: -3.8570 - reconstruction_error: 6.6208e-05
# Epoch 184/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9024 - kl_divergence: 5.9223 - neg_log_likelihood: -7.3373 - total_loss: -3.9024 - reconstruction_error: 6.3992e-05
# Epoch 185/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8781 - kl_divergence: 5.9268 - neg_log_likelihood: -7.3156 - total_loss: -3.8781 - reconstruction_error: 6.4848e-05
# Epoch 186/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8743 - kl_divergence: 5.9243 - neg_log_likelihood: -7.3104 - total_loss: -3.8743 - reconstruction_error: 6.4978e-05
# Epoch 187/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8708 - kl_divergence: 5.9251 - neg_log_likelihood: -7.3073 - total_loss: -3.8708 - reconstruction_error: 6.5181e-05
# Epoch 188/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9010 - kl_divergence: 5.9245 - neg_log_likelihood: -7.3372 - total_loss: -3.9010 - reconstruction_error: 6.3817e-05
# Epoch 189/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8651 - kl_divergence: 5.9257 - neg_log_likelihood: -7.3020 - total_loss: -3.8651 - reconstruction_error: 6.5378e-05
# Epoch 190/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8853 - kl_divergence: 5.9262 - neg_log_likelihood: -7.3225 - total_loss: -3.8853 - reconstruction_error: 6.4453e-05
# Epoch 191/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8677 - kl_divergence: 5.9271 - neg_log_likelihood: -7.3054 - total_loss: -3.8677 - reconstruction_error: 6.5282e-05
# Epoch 192/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9144 - kl_divergence: 5.9299 - neg_log_likelihood: -7.3538 - total_loss: -3.9144 - reconstruction_error: 6.3175e-05
# Epoch 193/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8829 - kl_divergence: 5.9302 - neg_log_likelihood: -7.3224 - total_loss: -3.8829 - reconstruction_error: 6.4411e-05
# Epoch 194/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8601 - kl_divergence: 5.9308 - neg_log_likelihood: -7.2999 - total_loss: -3.8601 - reconstruction_error: 6.5466e-05
# Epoch 195/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9029 - kl_divergence: 5.9310 - neg_log_likelihood: -7.3429 - total_loss: -3.9029 - reconstruction_error: 6.3545e-05
# Epoch 196/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8527 - kl_divergence: 5.9337 - neg_log_likelihood: -7.2943 - total_loss: -3.8527 - reconstruction_error: 6.5647e-05
# Epoch 197/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8809 - kl_divergence: 5.9295 - neg_log_likelihood: -7.3200 - total_loss: -3.8809 - reconstruction_error: 6.4603e-05
# Epoch 198/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9213 - kl_divergence: 5.9313 - neg_log_likelihood: -7.3614 - total_loss: -3.9213 - reconstruction_error: 6.2568e-05
# Epoch 199/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9251 - kl_divergence: 5.9321 - neg_log_likelihood: -7.3657 - total_loss: -3.9251 - reconstruction_error: 6.2392e-05
# Epoch 200/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9539 - kl_divergence: 5.9335 - neg_log_likelihood: -7.3954 - total_loss: -3.9539 - reconstruction_error: 6.0968e-05
# Epoch 201/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8799 - kl_divergence: 5.9322 - neg_log_likelihood: -7.3206 - total_loss: -3.8799 - reconstruction_error: 6.4401e-05
# Epoch 202/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9402 - kl_divergence: 5.9340 - neg_log_likelihood: -7.3820 - total_loss: -3.9402 - reconstruction_error: 6.1778e-05
# Epoch 203/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9360 - kl_divergence: 5.9319 - neg_log_likelihood: -7.3765 - total_loss: -3.9360 - reconstruction_error: 6.1774e-05
# Epoch 204/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8616 - kl_divergence: 5.9338 - neg_log_likelihood: -7.3032 - total_loss: -3.8616 - reconstruction_error: 6.5364e-05
# Epoch 205/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9362 - kl_divergence: 5.9320 - neg_log_likelihood: -7.3768 - total_loss: -3.9362 - reconstruction_error: 6.1793e-05
# Epoch 206/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8845 - kl_divergence: 5.9346 - neg_log_likelihood: -7.3266 - total_loss: -3.8845 - reconstruction_error: 6.4083e-05
# Epoch 207/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9523 - kl_divergence: 5.9351 - neg_log_likelihood: -7.3947 - total_loss: -3.9523 - reconstruction_error: 6.1099e-05
# Epoch 208/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9190 - kl_divergence: 5.9347 - neg_log_likelihood: -7.3611 - total_loss: -3.9190 - reconstruction_error: 6.2422e-05
# Epoch 209/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9343 - kl_divergence: 5.9361 - neg_log_likelihood: -7.3772 - total_loss: -3.9343 - reconstruction_error: 6.1792e-05
# Epoch 210/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9499 - kl_divergence: 5.9363 - neg_log_likelihood: -7.3929 - total_loss: -3.9499 - reconstruction_error: 6.0962e-05
# Epoch 211/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9537 - kl_divergence: 5.9351 - neg_log_likelihood: -7.3961 - total_loss: -3.9537 - reconstruction_error: 6.0814e-05
# Epoch 212/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9776 - kl_divergence: 5.9374 - neg_log_likelihood: -7.4212 - total_loss: -3.9776 - reconstruction_error: 5.9686e-05
# Epoch 213/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8934 - kl_divergence: 5.9352 - neg_log_likelihood: -7.3358 - total_loss: -3.8934 - reconstruction_error: 6.3532e-05
# Epoch 214/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9328 - kl_divergence: 5.9355 - neg_log_likelihood: -7.3754 - total_loss: -3.9328 - reconstruction_error: 6.1937e-05
# Epoch 215/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9588 - kl_divergence: 5.9339 - neg_log_likelihood: -7.4005 - total_loss: -3.9588 - reconstruction_error: 6.0588e-05
# Epoch 216/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9421 - kl_divergence: 5.9376 - neg_log_likelihood: -7.3859 - total_loss: -3.9421 - reconstruction_error: 6.1289e-05
# Epoch 217/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0047 - kl_divergence: 5.9366 - neg_log_likelihood: -7.4479 - total_loss: -4.0047 - reconstruction_error: 5.8360e-05
# Epoch 218/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8855 - kl_divergence: 5.9359 - neg_log_likelihood: -7.3283 - total_loss: -3.8855 - reconstruction_error: 6.3733e-05
# Epoch 219/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9093 - kl_divergence: 5.9367 - neg_log_likelihood: -7.3526 - total_loss: -3.9093 - reconstruction_error: 6.2687e-05
# Epoch 220/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9047 - kl_divergence: 5.9341 - neg_log_likelihood: -7.3465 - total_loss: -3.9047 - reconstruction_error: 6.2956e-05
# Epoch 221/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9969 - kl_divergence: 5.9356 - neg_log_likelihood: -7.4396 - total_loss: -3.9969 - reconstruction_error: 5.8809e-05
# Epoch 222/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9784 - kl_divergence: 5.9363 - neg_log_likelihood: -7.4214 - total_loss: -3.9784 - reconstruction_error: 5.9559e-05
# Epoch 223/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9989 - kl_divergence: 5.9368 - neg_log_likelihood: -7.4423 - total_loss: -3.9989 - reconstruction_error: 5.8572e-05
# Epoch 224/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9374 - kl_divergence: 5.9354 - neg_log_likelihood: -7.3799 - total_loss: -3.9374 - reconstruction_error: 6.1363e-05
# Epoch 225/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9378 - kl_divergence: 5.9361 - neg_log_likelihood: -7.3808 - total_loss: -3.9378 - reconstruction_error: 6.1291e-05
# Epoch 226/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9031 - kl_divergence: 5.9343 - neg_log_likelihood: -7.3450 - total_loss: -3.9031 - reconstruction_error: 6.2892e-05
# Epoch 227/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9508 - kl_divergence: 5.9338 - neg_log_likelihood: -7.3924 - total_loss: -3.9508 - reconstruction_error: 6.0795e-05
# Epoch 228/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9676 - kl_divergence: 5.9355 - neg_log_likelihood: -7.4102 - total_loss: -3.9676 - reconstruction_error: 5.9974e-05
# Epoch 229/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9584 - kl_divergence: 5.9351 - neg_log_likelihood: -7.4008 - total_loss: -3.9584 - reconstruction_error: 6.0489e-05
# Epoch 230/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9251 - kl_divergence: 5.9354 - neg_log_likelihood: -7.3676 - total_loss: -3.9251 - reconstruction_error: 6.1930e-05
# Epoch 231/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9589 - kl_divergence: 5.9322 - neg_log_likelihood: -7.3996 - total_loss: -3.9589 - reconstruction_error: 6.0565e-05
# Epoch 232/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9858 - kl_divergence: 5.9343 - neg_log_likelihood: -7.4277 - total_loss: -3.9858 - reconstruction_error: 5.9165e-05
# Epoch 233/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9924 - kl_divergence: 5.9356 - neg_log_likelihood: -7.4351 - total_loss: -3.9924 - reconstruction_error: 5.8809e-05
# Epoch 234/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9714 - kl_divergence: 5.9345 - neg_log_likelihood: -7.4134 - total_loss: -3.9714 - reconstruction_error: 5.9782e-05
# Epoch 235/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9633 - kl_divergence: 5.9363 - neg_log_likelihood: -7.4064 - total_loss: -3.9633 - reconstruction_error: 6.0116e-05
# Epoch 236/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9102 - kl_divergence: 5.9349 - neg_log_likelihood: -7.3525 - total_loss: -3.9102 - reconstruction_error: 6.2743e-05
# Epoch 237/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9756 - kl_divergence: 5.9352 - neg_log_likelihood: -7.4180 - total_loss: -3.9756 - reconstruction_error: 5.9644e-05
# Epoch 238/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0190 - kl_divergence: 5.9351 - neg_log_likelihood: -7.4614 - total_loss: -4.0190 - reconstruction_error: 5.7642e-05
# Epoch 239/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9295 - kl_divergence: 5.9370 - neg_log_likelihood: -7.3730 - total_loss: -3.9295 - reconstruction_error: 6.1692e-05
# Epoch 240/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9686 - kl_divergence: 5.9347 - neg_log_likelihood: -7.4107 - total_loss: -3.9686 - reconstruction_error: 6.0037e-05
# Epoch 241/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9609 - kl_divergence: 5.9314 - neg_log_likelihood: -7.4011 - total_loss: -3.9609 - reconstruction_error: 6.0245e-05
# Epoch 242/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0268 - kl_divergence: 5.9349 - neg_log_likelihood: -7.4690 - total_loss: -4.0268 - reconstruction_error: 5.7268e-05
# Epoch 243/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.8685 - kl_divergence: 5.9324 - neg_log_likelihood: -7.3093 - total_loss: -3.8685 - reconstruction_error: 6.4607e-05
# Epoch 244/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0119 - kl_divergence: 5.9363 - neg_log_likelihood: -7.4550 - total_loss: -4.0119 - reconstruction_error: 5.8048e-05
# Epoch 245/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0092 - kl_divergence: 5.9342 - neg_log_likelihood: -7.4510 - total_loss: -4.0092 - reconstruction_error: 5.8087e-05
# Epoch 246/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9719 - kl_divergence: 5.9346 - neg_log_likelihood: -7.4140 - total_loss: -3.9719 - reconstruction_error: 5.9757e-05
# Epoch 247/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9969 - kl_divergence: 5.9372 - neg_log_likelihood: -7.4405 - total_loss: -3.9969 - reconstruction_error: 5.8481e-05
# Epoch 248/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9607 - kl_divergence: 5.9365 - neg_log_likelihood: -7.4039 - total_loss: -3.9607 - reconstruction_error: 6.0202e-05
# Epoch 249/341
# ...
# Epoch 273/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9940 - kl_divergence: 5.9368 - neg_log_likelihood: -7.4373 - total_loss: -3.9940 - reconstruction_error: 5.8763e-05
# Epoch 274/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0016 - kl_divergence: 5.9348 - neg_log_likelihood: -7.4438 - total_loss: -4.0016 - reconstruction_error: 5.8554e-05
# Epoch 275/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9978 - kl_divergence: 5.9348 - neg_log_likelihood: -7.4400 - total_loss: -3.9978 - reconstruction_error: 5.8852e-05
# Epoch 276/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9888 - kl_divergence: 5.9334 - neg_log_likelihood: -7.4302 - total_loss: -3.9888 - reconstruction_error: 5.9102e-05
# Epoch 277/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9733 - kl_divergence: 5.9332 - neg_log_likelihood: -7.4146 - total_loss: -3.9733 - reconstruction_error: 5.9789e-05
# Epoch 278/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0245 - kl_divergence: 5.9329 - neg_log_likelihood: -7.4656 - total_loss: -4.0245 - reconstruction_error: 5.7521e-05
# Epoch 279/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9815 - kl_divergence: 5.9359 - neg_log_likelihood: -7.4243 - total_loss: -3.9815 - reconstruction_error: 5.9506e-05
# Epoch 280/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9867 - kl_divergence: 5.9351 - neg_log_likelihood: -7.4290 - total_loss: -3.9867 - reconstruction_error: 5.9113e-05
# Epoch 281/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9911 - kl_divergence: 5.9358 - neg_log_likelihood: -7.4338 - total_loss: -3.9911 - reconstruction_error: 5.8966e-05
# Epoch 282/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9833 - kl_divergence: 5.9355 - neg_log_likelihood: -7.4259 - total_loss: -3.9833 - reconstruction_error: 5.9520e-05
# Epoch 283/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0086 - kl_divergence: 5.9359 - neg_log_likelihood: -7.4514 - total_loss: -4.0086 - reconstruction_error: 5.8015e-05
# Epoch 284/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0060 - kl_divergence: 5.9332 - neg_log_likelihood: -7.4473 - total_loss: -4.0060 - reconstruction_error: 5.8389e-05
# Epoch 285/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0127 - kl_divergence: 5.9375 - neg_log_likelihood: -7.4564 - total_loss: -4.0127 - reconstruction_error: 5.7893e-05
# Epoch 286/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0255 - kl_divergence: 5.9350 - neg_log_likelihood: -7.4678 - total_loss: -4.0255 - reconstruction_error: 5.7378e-05
# Epoch 287/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9428 - kl_divergence: 5.9324 - neg_log_likelihood: -7.3836 - total_loss: -3.9428 - reconstruction_error: 6.1174e-05
# Epoch 288/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0579 - kl_divergence: 5.9337 - neg_log_likelihood: -7.4994 - total_loss: -4.0579 - reconstruction_error: 5.5866e-05
# Epoch 289/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9931 - kl_divergence: 5.9342 - neg_log_likelihood: -7.4350 - total_loss: -3.9931 - reconstruction_error: 5.8943e-05
# Epoch 290/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9417 - kl_divergence: 5.9342 - neg_log_likelihood: -7.3835 - total_loss: -3.9417 - reconstruction_error: 6.1296e-05
# Epoch 291/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0078 - kl_divergence: 5.9336 - neg_log_likelihood: -7.4493 - total_loss: -4.0078 - reconstruction_error: 5.8421e-05
# Epoch 292/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0149 - kl_divergence: 5.9335 - neg_log_likelihood: -7.4563 - total_loss: -4.0149 - reconstruction_error: 5.8076e-05
# Epoch 293/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0068 - kl_divergence: 5.9321 - neg_log_likelihood: -7.4474 - total_loss: -4.0068 - reconstruction_error: 5.8380e-05
# Epoch 294/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0127 - kl_divergence: 5.9325 - neg_log_likelihood: -7.4535 - total_loss: -4.0127 - reconstruction_error: 5.8192e-05
# Epoch 295/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0040 - kl_divergence: 5.9320 - neg_log_likelihood: -7.4446 - total_loss: -4.0040 - reconstruction_error: 5.8626e-05
# Epoch 296/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0100 - kl_divergence: 5.9346 - neg_log_likelihood: -7.4521 - total_loss: -4.0100 - reconstruction_error: 5.8201e-05
# Epoch 297/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0074 - kl_divergence: 5.9341 - neg_log_likelihood: -7.4492 - total_loss: -4.0074 - reconstruction_error: 5.8256e-05
# Epoch 298/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0310 - kl_divergence: 5.9327 - neg_log_likelihood: -7.4720 - total_loss: -4.0310 - reconstruction_error: 5.7270e-05
# Epoch 299/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0124 - kl_divergence: 5.9337 - neg_log_likelihood: -7.4540 - total_loss: -4.0124 - reconstruction_error: 5.7951e-05
# Epoch 300/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0401 - kl_divergence: 5.9341 - neg_log_likelihood: -7.4819 - total_loss: -4.0401 - reconstruction_error: 5.6948e-05
# Epoch 301/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0150 - kl_divergence: 5.9308 - neg_log_likelihood: -7.4549 - total_loss: -4.0150 - reconstruction_error: 5.8031e-05
# Epoch 302/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0511 - kl_divergence: 5.9358 - neg_log_likelihood: -7.4939 - total_loss: -4.0511 - reconstruction_error: 5.6250e-05
# Epoch 303/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9040 - kl_divergence: 5.9341 - neg_log_likelihood: -7.3458 - total_loss: -3.9040 - reconstruction_error: 6.3282e-05
# Epoch 304/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0264 - kl_divergence: 5.9338 - neg_log_likelihood: -7.4680 - total_loss: -4.0264 - reconstruction_error: 5.7469e-05
# Epoch 305/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.8943 - kl_divergence: 5.9320 - neg_log_likelihood: -7.3349 - total_loss: -3.8943 - reconstruction_error: 6.3523e-05
# Epoch 306/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0651 - kl_divergence: 5.9351 - neg_log_likelihood: -7.5075 - total_loss: -4.0651 - reconstruction_error: 5.5694e-05
# Epoch 307/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0356 - kl_divergence: 5.9350 - neg_log_likelihood: -7.4779 - total_loss: -4.0356 - reconstruction_error: 5.7040e-05
# Epoch 308/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0511 - kl_divergence: 5.9330 - neg_log_likelihood: -7.4922 - total_loss: -4.0511 - reconstruction_error: 5.6295e-05
# Epoch 309/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9728 - kl_divergence: 5.9335 - neg_log_likelihood: -7.4142 - total_loss: -3.9728 - reconstruction_error: 5.9936e-05
# Epoch 310/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0185 - kl_divergence: 5.9338 - neg_log_likelihood: -7.4601 - total_loss: -4.0185 - reconstruction_error: 5.7891e-05
# Epoch 311/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0050 - kl_divergence: 5.9343 - neg_log_likelihood: -7.4469 - total_loss: -4.0050 - reconstruction_error: 5.8508e-05
# Epoch 312/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0591 - kl_divergence: 5.9355 - neg_log_likelihood: -7.5017 - total_loss: -4.0591 - reconstruction_error: 5.5945e-05
# Epoch 313/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9764 - kl_divergence: 5.9313 - neg_log_likelihood: -7.4166 - total_loss: -3.9764 - reconstruction_error: 5.9789e-05
# Epoch 314/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0095 - kl_divergence: 5.9313 - neg_log_likelihood: -7.4497 - total_loss: -4.0095 - reconstruction_error: 5.8208e-05
# Epoch 315/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0073 - kl_divergence: 5.9326 - neg_log_likelihood: -7.4482 - total_loss: -4.0073 - reconstruction_error: 5.8518e-05
# Epoch 316/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9411 - kl_divergence: 5.9351 - neg_log_likelihood: -7.3835 - total_loss: -3.9411 - reconstruction_error: 6.1239e-05
# Epoch 317/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0538 - kl_divergence: 5.9349 - neg_log_likelihood: -7.4960 - total_loss: -4.0538 - reconstruction_error: 5.6317e-05
# Epoch 318/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0225 - kl_divergence: 5.9339 - neg_log_likelihood: -7.4642 - total_loss: -4.0225 - reconstruction_error: 5.7760e-05
# Epoch 319/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0458 - kl_divergence: 5.9312 - neg_log_likelihood: -7.4859 - total_loss: -4.0458 - reconstruction_error: 5.6818e-05
# Epoch 320/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0200 - kl_divergence: 5.9349 - neg_log_likelihood: -7.4623 - total_loss: -4.0200 - reconstruction_error: 5.7768e-05
# Epoch 321/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9823 - kl_divergence: 5.9329 - neg_log_likelihood: -7.4234 - total_loss: -3.9823 - reconstruction_error: 5.9622e-05
# Epoch 322/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0303 - kl_divergence: 5.9333 - neg_log_likelihood: -7.4716 - total_loss: -4.0303 - reconstruction_error: 5.7272e-05
# Epoch 323/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0441 - kl_divergence: 5.9337 - neg_log_likelihood: -7.4857 - total_loss: -4.0441 - reconstruction_error: 5.6642e-05
# Epoch 324/341
# 60/60 [==============================] - 0s 8ms/step - loss: -3.9817 - kl_divergence: 5.9312 - neg_log_likelihood: -7.4218 - total_loss: -3.9817 - reconstruction_error: 5.9661e-05
# Epoch 325/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0235 - kl_divergence: 5.9326 - neg_log_likelihood: -7.4644 - total_loss: -4.0235 - reconstruction_error: 5.7648e-05
# Epoch 326/341
# 60/60 [==============================] - 0s 8ms/step - loss: -4.0396 - kl_divergence: 5.9336 - neg_log_likelihood: -7.4811 - total_loss: -4.0396 - reconstruction_error: 5.6841e-05
# Epoch 327/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9740 - kl_divergence: 5.9321 - neg_log_likelihood: -7.4147 - total_loss: -3.9740 - reconstruction_error: 5.9916e-05
# Epoch 328/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0249 - kl_divergence: 5.9313 - neg_log_likelihood: -7.4650 - total_loss: -4.0249 - reconstruction_error: 5.7792e-05
# Epoch 329/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0377 - kl_divergence: 5.9313 - neg_log_likelihood: -7.4779 - total_loss: -4.0377 - reconstruction_error: 5.7026e-05
# Epoch 330/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0418 - kl_divergence: 5.9318 - neg_log_likelihood: -7.4823 - total_loss: -4.0418 - reconstruction_error: 5.6877e-05
# Epoch 331/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9967 - kl_divergence: 5.9321 - neg_log_likelihood: -7.4374 - total_loss: -3.9967 - reconstruction_error: 5.8910e-05
# Epoch 332/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0062 - kl_divergence: 5.9330 - neg_log_likelihood: -7.4474 - total_loss: -4.0062 - reconstruction_error: 5.8634e-05
# Epoch 333/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0760 - kl_divergence: 5.9339 - neg_log_likelihood: -7.5176 - total_loss: -4.0760 - reconstruction_error: 5.5312e-05
# Epoch 334/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0073 - kl_divergence: 5.9315 - neg_log_likelihood: -7.4476 - total_loss: -4.0073 - reconstruction_error: 5.8529e-05
# Epoch 335/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0175 - kl_divergence: 5.9324 - neg_log_likelihood: -7.4583 - total_loss: -4.0175 - reconstruction_error: 5.8041e-05
# Epoch 336/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0151 - kl_divergence: 5.9338 - neg_log_likelihood: -7.4567 - total_loss: -4.0151 - reconstruction_error: 5.8005e-05
# Epoch 337/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9600 - kl_divergence: 5.9335 - neg_log_likelihood: -7.4014 - total_loss: -3.9600 - reconstruction_error: 6.0441e-05
# Epoch 338/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0712 - kl_divergence: 5.9312 - neg_log_likelihood: -7.5113 - total_loss: -4.0712 - reconstruction_error: 5.5585e-05
# Epoch 339/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0329 - kl_divergence: 5.9337 - neg_log_likelihood: -7.4745 - total_loss: -4.0329 - reconstruction_error: 5.7319e-05
# Epoch 340/341
# 60/60 [==============================] - 0s 7ms/step - loss: -3.9953 - kl_divergence: 5.9322 - neg_log_likelihood: -7.4360 - total_loss: -3.9953 - reconstruction_error: 5.9051e-05
# Epoch 341/341
# 60/60 [==============================] - 0s 7ms/step - loss: -4.0398 - kl_divergence: 5.9312 - neg_log_likelihood: -7.4799 - total_loss: -4.0398 - reconstruction_error: 5.6954e-05
# 2025-06-10 16:02:17.440455: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /workspace/2-Training_Codes_Jupyter/logs_runs/cvae_campeao_exported/assets
# ✅ Modelo campeão salvo em:
#    • /workspace/2-Training_Codes_Jupyter/logs_runs/cvae_campeao_exported   (SavedModel)
#    • /workspace/2-Training_Codes_Jupyter/logs_runs/cvae_campeao_exported.keras (.keras)
#
# Gerando análises visuais e métricas para o modelo campeão...
# Plot de constelações salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/campeao_constelacao_plot.png
# Plot de histogramas de ruído salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/campeao_histogramas_ruido_plot.png
# Plot Q-Q salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/campeao_qq_plot.png
# Plot da curva de transferência salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/campeao_curva_transferencia_plot.png
# Plot do mapa de vetores de erro salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/campeao_mapa_vetores_erro_plot.png
# 🏆  MÉTRICAS DO MODELO CAMPEÃO  🏆
# ==================================================
# Hiperparâmetros:
#   layer1: 128
#   layer2: 256
#   layer3: 512
#   latent_dim: 48
#   beta: 0.58
#   batch_size: 12000
#   learning_rate: 0.0001
#   activation: leaky_relu
# ==================================================
# MÉTRICAS DE RECONSTRUÇÃO:
#   EVM (Ŷ vs X_test)          : 19.00% (-14.42 dB)
#   SNR (Ŷ vs X_test)          : 14.42 dB
#   RMSE (Ŷ vs X_test)         : 0.1550
#   MSE (Ŷ vs X_test)          : 0.0240
#   MAE (Ŷ vs X_test)          : 0.1292
#   PSNR (Ŷ vs X_test)         : 16.19 dB
#   Similaridade Cosseno        : 0.9820
#   Correlação                  : 0.9821
#
# MÉTRICAS DE DISTRIBUIÇÃO:
#   KL Divergence (Y_test||Ŷ)  : 0.0000
#   Jensen-Shannon Div. (Y,Ŷ)  : 0.0000
#
# TESTE KOLMOGOROV-SMIRNOV (Y_test vs Ŷ):
#   Componente I - Estatística  : 0.0016 (p-valor: 0.9745)
#   Componente Q - Estatística  : 0.0011 (p-valor: 0.9998)
#   Amplitude Sinal - Estatística: 0.0008 (p-valor: 1.0000)
#   Amplitude Ruído - Estatística: 0.0021 (p-valor: 0.7997)
# ==================================================
# Score final do modelo campeão: 10.7577
# Tempo de treinamento: 165.61 segundos
# Épocas treinadas: 341
# ==================================================
# Resumo das métricas salvo em: /workspace/2-Training_Codes_Jupyter/logs_runs/champion_model_summary.json
#
# 🎯 ANÁLISE DO MODELO CAMPEÃO CONCLUÍDA! 🎯
# Todos os plots e métricas foram salvos em: /workspace/2-Training_Codes_Jupyter/logs_runs/
