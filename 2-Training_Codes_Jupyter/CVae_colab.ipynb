# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Treino + ranking de CVAE para modelagem de canal VLC
====================================================

• Autor:  <Rodrigo Fuchs Miranda>
• Data :  09/06/2025>
"""

# ────────────────────────────────────────────────────────────────────────
# 0)  IMPORTS & BACKEND
# ────────────────────────────────────────────────────────────────────────
import os
import time
import itertools
import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from scipy import stats
import matplotlib.pyplot as plt

# GPU/CPU backend setup
try:
    import cupy as cp
    xp, gpu_enabled = cp, True
    print("CuPy (GPU) backend ativado.")
except ImportError:
    xp, gpu_enabled = np, False
    print("NumPy (CPU) backend ativado.")

# Reproducibilidade
np.random.seed(33)
tf.random.set_seed(33)
if gpu_enabled:
    cp.random.seed(33)

# ────────────────────────────────────────────────────────────────────────
# 1)  CARREGAMENTO E PREPARAÇÃO DOS DADOS
# ────────────────────────────────────────────────────────────────────────
print("Carregando dados...")
base_path = "/content/drive/MyDrive/Temp/IQ_data/" # Ex: Caminho do Colab

# Verificação dos arquivos
for fname in ["sent_data_tuple.npy", "received_data_tuple_sync-phase.npy"]:
    fpath = os.path.join(base_path, fname)
    if not os.path.exists(fpath):
        raise FileNotFoundError(f"Arquivo não encontrado: {fpath}")
    print(f"Arquivo localizado: {fpath}")

# Carregamento dos dados
X = np.load(os.path.join(base_path, "sent_data_tuple.npy"))
Y = np.load(os.path.join(base_path, "received_data_tuple_sync-phase.npy"))

print(f"Dados carregados - X: {X.shape}, Y: {Y.shape}")

# Embaralhamento e divisão
idx = np.arange(len(X))
np.random.shuffle(idx)
X, Y = X[idx], Y[idx]

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
Y_train, Y_test = Y[:split], Y[split:]

print(f"Divisão - Train: X{X_train.shape}, Y{Y_train.shape}")
print(f"         Test:  X{X_test.shape}, Y{Y_test.shape}")

# ────────────────────────────────────────────────────────────────────────
# 2)  FUNÇÕES DE MÉTRICA
# ────────────────────────────────────────────────────────────────────────

def safe_log10(x, eps=1e-12):
    """Log10 seguro com epsilon para evitar log(0)"""
    return xp.log10(xp.maximum(x, eps))

def safe_log2(x, eps=1e-12):
    """Log2 seguro com epsilon para evitar log(0)"""
    return xp.log2(xp.maximum(x, eps))

def calculate_evm(ref, test):
    """Calcula EVM (Error Vector Magnitude)"""
    ref, test = xp.asarray(ref), xp.asarray(test)
    rc = ref[:,0] + 1j * ref[:,1]
    tc = test[:,0] + 1j * test[:,1]

    mean_power = xp.mean(xp.abs(rc)**2)
    if mean_power == 0:
        return float('inf'), float('-inf')

    err = tc - rc
    evm_val = xp.sqrt(xp.mean(xp.abs(err)**2) / mean_power)
    evm_pct = float(evm_val * 100)
    evm_db = float(20 * safe_log10(evm_val))

    return evm_pct, evm_db

def calculate_snr(ref, test):
    """Calcula SNR (Signal-to-Noise Ratio)"""
    ref, test = xp.asarray(ref), xp.asarray(test)
    rc = ref[:,0] + 1j * ref[:,1]
    tc = test[:,0] + 1j * test[:,1]

    noise = rc - tc
    signal_power = xp.mean(xp.abs(rc)**2)
    noise_power = xp.mean(xp.abs(noise)**2)

    if noise_power == 0:
        return float('inf') if signal_power > 0 else 0.0

    snr_val = signal_power / noise_power
    return float(10 * safe_log10(snr_val))

def calculate_psnr(mse, peak=1.0):
    """Calcula PSNR (Peak Signal-to-Noise Ratio)"""
    if mse <= 0:
        return float('inf') if mse == 0 else float('-inf')
    return float(20 * np.log10(peak) - 10 * np.log10(mse))

def calculate_noise_power(sent, recv):
    """Calcula potência do ruído"""
    sent, recv = xp.asarray(sent), xp.asarray(recv)
    noise = recv - sent
    return float(xp.mean(xp.sum(noise**2, axis=1)))

def compute_basic_metrics(x, y):
    """Calcula métricas básicas (MSE, RMSE, MAE, correlação)"""
    x_gpu, y_gpu = xp.asarray(x), xp.asarray(y)
    err = x_gpu - y_gpu

    # MSE e RMSE
    mse = float(xp.mean(xp.sum(err**2, axis=1)))
    rmse = float(xp.sqrt(mse))

    # MAE
    mae = float(xp.mean(xp.linalg.norm(err, axis=1)))

    # Similaridade cosseno
    norm_x = xp.linalg.norm(x_gpu.ravel())
    norm_y = xp.linalg.norm(y_gpu.ravel())
    if norm_x == 0 or norm_y == 0:
        cos = 0.0
    else:
        cos = float(xp.dot(x_gpu.ravel(), y_gpu.ravel()) / (norm_x * norm_y))

    # Correlação (na CPU)
    x_cpu = cp.asnumpy(x_gpu) if gpu_enabled else x_gpu
    y_cpu = cp.asnumpy(y_gpu) if gpu_enabled else y_gpu

    if len(x_cpu.ravel()) < 2 or len(y_cpu.ravel()) < 2:
        corr = 0.0
    else:
        try:
            corr_matrix = np.corrcoef(x_cpu.ravel(), y_cpu.ravel())
            corr = float(corr_matrix[0,1]) if corr_matrix.ndim == 2 else 0.0
        except:
            corr = 0.0

    return mse, rmse, mae, cos, corr

# --- KDE-based JSD / KL (GPU-ready) ---
def _kde_gpu(data, positions, bw=0.1, batch_size=3000):
    """Estimação de densidade por kernel na GPU"""
    data = xp.asarray(data)
    val = xp.zeros(positions.shape[0], dtype=xp.float32)
    num_points = len(data)

    if num_points == 0:
        return val

    for i in range(0, num_points, batch_size):
        batch_data = data[i:i+batch_size]
        exp_term = -0.5 * (((batch_data[:,0,None] - positions[:,0])/bw)**2 +
                          ((batch_data[:,1,None] - positions[:,1])/bw)**2)
        val += xp.sum(xp.exp(exp_term), axis=0)

    val /= num_points
    val /= (2 * np.pi * bw**2)  # Normalização Gaussiana

    sum_val = xp.sum(val)
    if sum_val > 0:
        val /= sum_val

    return val

def _prep_grid(grid_res=200, data_min=-1.5, data_max=1.5):
    """Prepara grade para estimação de densidade"""
    xi = xp.linspace(data_min, data_max, grid_res)
    X_grid, Y_grid = xp.meshgrid(xi, xi)
    return xp.stack([X_grid.ravel(), Y_grid.ravel()], axis=1)

def calculate_jsd_gpu(real, pred, grid_res=200, bw=0.1):
    """Calcula Jensen-Shannon Divergence"""
    pos = _prep_grid(grid_res)
    P = _kde_gpu(real, pos, bw)
    Q = _kde_gpu(pred, pos, bw)
    M = 0.5 * (P + Q)

    eps = 1e-12
    jsd = 0.5 * xp.sum(xp.where(P > eps, P * safe_log2(P / (M + eps)), 0)) + \
          0.5 * xp.sum(xp.where(Q > eps, Q * safe_log2(Q / (M + eps)), 0))

    return float(jsd)

def calculate_kl_gpu(real, pred, grid_res=200, bw=0.1):
    """Calcula Kullback-Leibler Divergence"""
    pos = _prep_grid(grid_res)
    P = _kde_gpu(real, pos, bw)
    Q = _kde_gpu(pred, pos, bw)

    eps = 1e-12
    kl_val = xp.sum(xp.where(P > eps, P * xp.log((P + eps) / (Q + eps)), 0))

    return float(kl_val)

def calculate_ks_test(data1, data2):
    """Calcula teste Kolmogorov-Smirnov"""
    if gpu_enabled:
        data1 = cp.asnumpy(data1) if isinstance(data1, cp.ndarray) else data1
        data2 = cp.asnumpy(data2) if isinstance(data2, cp.ndarray) else data2

    if data1.ndim > 1:
        data1 = data1.ravel()
    if data2.ndim > 1:
        data2 = data2.ravel()

    if len(data1) == 0 or len(data2) == 0:
        return 0.0, 0.0

    try:
        ks_statistic, p_value = stats.ks_2samp(data1, data2)
        return float(ks_statistic), float(p_value)
    except:
        return 0.0, 0.0

# ────────────────────────────────────────────────────────────────────────
# 3)  DEFINIÇÕES DO VAE
# ────────────────────────────────────────────────────────────────────────

class Sampling(layers.Layer):
    """Camada de amostragem para VAE"""
    def call(self, inputs):
        z_mu, z_logv = inputs
        eps = tf.random.normal(tf.shape(z_mu))
        return z_mu + tf.exp(0.5 * z_logv) * eps

class BetaScheduler(tf.keras.callbacks.Callback):
    """Agendador de beta para VAE"""
    def __init__(self, loss_layer, max_beta=1.0, warmup_epochs=10):
        super().__init__()
        self.loss_layer = loss_layer
        self.max_beta = max_beta
        self.warmup_epochs = warmup_epochs

    def on_epoch_begin(self, epoch, logs=None):
        if self.warmup_epochs > 0:
            current_beta = self.max_beta * min(1.0, epoch / self.warmup_epochs)
        else:
            current_beta = self.max_beta
        if isinstance(self.loss_layer.beta, tf.Variable):
            self.loss_layer.beta.assign(current_beta)   # ← use assign()
        else:                                           # fallback de segurança
            self.loss_layer.beta = tf.Variable(current_beta, trainable=False)

class VAELossLayer(layers.Layer):
    """
    Enhanced VAE Loss Layer optimized for VLC channel digital twin modeling.

    Combines proper Gaussian NLL with KL divergence and includes robust
    numerical stability measures for telecommunications signal processing.
    """

    def __init__(self, beta=1.0, name="vae_loss_layer", **kwargs):
        super().__init__(name=name, **kwargs)

        # Use tf.Variable for dynamic beta scheduling during training
        self.beta = tf.Variable(beta, trainable=False, dtype=tf.float32, name="beta")

        # Separate metric trackers for monitoring
        self.kl_tracker = tf.keras.metrics.Mean(name="kl_divergence")
        self.nll_tracker = tf.keras.metrics.Mean(name="neg_log_likelihood")
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")

        # Additional metrics for VLC channel analysis
        self.reconstruction_error = tf.keras.metrics.Mean(name="reconstruction_error")

    def call(self, inputs):
        x_in, dec_out, y_true, z_mu, z_logv = inputs

        # Separate decoder outputs: mean and log-variance
        mu = dec_out[:, :2]  # First 2 components: I and Q means

        # Clip log-variance for numerical stability (critical for VLC signals)
        logv = tf.clip_by_value(dec_out[:, 2:], -10.0, 10.0)
        var = tf.exp(logv) + 1e-8  # Add small epsilon to prevent division by zero

        # === NEGATIVE LOG-LIKELIHOOD (Gaussian) ===
        # Complete formula for multivariate Gaussian NLL
        diff_squared = tf.square(y_true - mu)

        nll = 0.5 * tf.reduce_mean(
            tf.reduce_sum(
                tf.math.log(2 * np.pi) + logv + (diff_squared / var),
                axis=-1
            )
        )

        # === KL DIVERGENCE ===
        # KL divergence between learned latent distribution and standard Gaussian
        kl_div = -0.5 * tf.reduce_mean(
            tf.reduce_sum(
                1 + z_logv - tf.square(z_mu) - tf.exp(z_logv),
                axis=-1
            )
        )

        # === TOTAL LOSS ===
        total_loss = nll + self.beta * kl_div

        # Add loss to the model
        self.add_loss(total_loss)

        # === UPDATE METRICS ===
        self.nll_tracker.update_state(nll)
        self.kl_tracker.update_state(kl_div)
        self.total_loss_tracker.update_state(total_loss)

        # Track reconstruction error for VLC channel analysis
        mse = tf.reduce_mean(diff_squared)
        self.reconstruction_error.update_state(mse)

        # === REPARAMETERIZATION TRICK ===
        # Sample from learned distribution
        eps = tf.random.normal(tf.shape(mu))
        sampled_output = mu + tf.sqrt(var) * eps

        return sampled_output

    @property
    def metrics(self):
        """Return all tracked metrics"""
        return [
            self.nll_tracker,
            self.kl_tracker,
            self.total_loss_tracker,
            self.reconstruction_error
        ]

    def get_kl(self):
        """Get current KL divergence value - useful for monitoring training"""
        return self.kl_tracker.result().numpy()

    def get_nll(self):
        """Get current NLL value - useful for monitoring reconstruction quality"""
        return self.nll_tracker.result().numpy()

    def get_reconstruction_error(self):
        """Get current reconstruction MSE - important for VLC channel fidelity"""
        return self.reconstruction_error.result().numpy()

    def update_beta(self, new_beta):
        """Update beta value during training (for beta-VAE scheduling)"""
        self.beta.assign(new_beta)

    def get_config(self):
        config = super().get_config()
        beta_val = self.beta.numpy() if isinstance(self.beta, tf.Variable) else self.beta
        config.update({"beta": float(beta_val)})
        return config

    @classmethod
    def from_config(cls, config):
        """Enable model loading"""
        return cls(**config)

def build_encoder(layer_sizes, latent_dim, activation):
    """
    Constrói o Encoder CONDICIONAL.
    Recebe tanto o sinal de entrada (condição) quanto o sinal de saída (alvo)
    para aprender a representação latente do CANAL.
    """
    # Define two separate inputs: one for the original signal and one for the target signal
    x_in = layers.Input(shape=(2,), name="encoder_x_input")
    y_in = layers.Input(shape=(2,), name="encoder_y_input")

    # Concatenate the inputs to condition the encoder on both
    concatenated_inputs = layers.Concatenate()([x_in, y_in])

    x = concatenated_inputs
    for size in reversed(layer_sizes):
        x = layers.Dense(size, activation=activation)(x)

    z_mu = layers.Dense(latent_dim, name="z_mu")(x)
    z_logv = layers.Dense(latent_dim, name="z_log_var")(x)

    # The model now takes a list of two inputs
    return models.Model(inputs=[x_in, y_in], outputs=[z_mu, z_logv], name="conditional_encoder")

def build_decoder(layer_sizes, latent_dim, activation):
    """
    Constrói o Decoder CONDICIONAL.
    Recebe o vetor latente 'z' (representando o canal) e o sinal de entrada 'x_in' (a condição)
    para reconstruir o sinal de saída.
    """
    # Define two separate inputs: one for the latent vector and one for the condition
    z_in = layers.Input(shape=(latent_dim,), name="decoder_z_input")
    condition_in = layers.Input(shape=(2,), name="decoder_condition_input")

    # Concatenate the inputs to make the decoding process conditional
    concatenated_inputs = layers.Concatenate()([z_in, condition_in])

    z = concatenated_inputs
    for size in layer_sizes:
        z = layers.Dense(size, activation=activation)(z)

    # A saída permanece a mesma: [mu_I, mu_Q, logv_I, logv_Q]
    out = layers.Dense(4, activation="linear", name="mu_logv")(z)

    # The model now takes a list of two inputs
    return models.Model(inputs=[z_in, condition_in], outputs=out, name="conditional_decoder")

def build_conditional_vae(layer_sizes, latent_dim, activation, beta, learning_rate):
    """
    Constrói o CVAE completo com a arquitetura CONDICIONAL correta.
    """
    # Instantiate the corrected conditional encoder and decoder
    enc = build_encoder(layer_sizes, latent_dim, activation)
    dec = build_decoder(layer_sizes, latent_dim, activation)

    # Entradas para o modelo completo
    x_in = layers.Input(shape=(2,), name="x_in")
    y_true = layers.Input(shape=(2,), name="y_true")

    # --- Forward pass CORRIGIDO ---
    # 1. Encoder recebe X e Y para gerar z (o canal)
    z_mu, z_logv = enc([x_in, y_true])

    # 2. Amostragem para obter z
    z = Sampling()([z_mu, z_logv])

    # 3. Decoder recebe z (o canal) e X (a condição) para gerar a predição
    dec_out = dec([z, x_in])

    # A camada de perda e a compilação permanecem as mesmas
    loss_layer = VAELossLayer(beta=0.0)
    y_out = loss_layer([x_in, dec_out, y_true, z_mu, z_logv])

    vae = models.Model(inputs=[x_in, y_true], outputs=y_out, name="cvae")
    vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=None)

    beta_scheduler = BetaScheduler(loss_layer, max_beta=beta, warmup_epochs=10)

    return vae, beta_scheduler

# ────────────────────────────────────────────────────────────────────────
# 4)  CONFIGURAÇÃO DO GRID SEARCH
# ────────────────────────────────────────────────────────────────────────

param_grid = {
    "layer1": [128],
    "layer2": [256],
    "layer3": [512],
    "latent_dim": [48,54],
    "beta": [0.48,0.58],
    "batch_size": [12000,20000],
    "learning_rate": [1e-4],
    "activation": ["leaky_relu"]
}

# Configuração de logs
logs_base_dir = "/content/drive/MyDrive/Temp/IQ_data/logs_runs/"


os.makedirs(logs_base_dir, exist_ok=True)

log_path = os.path.join(logs_base_dir, "experimentos.csv")
ranked_log_path = os.path.join(logs_base_dir, "experimentos_ranked.csv")

# Limpar logs existentes
for path in [log_path, ranked_log_path]:
    if os.path.exists(path):
        print(f"Removendo arquivo existente: {path}")
        os.remove(path)

# ────────────────────────────────────────────────────────────────────────
# 5)  EXECUÇÃO DO GRID SEARCH
# ────────────────────────────────────────────────────────────────────────

print("\nIniciando Grid Search...")
results_list = []
total_combos = len(list(itertools.product(*param_grid.values())))

for i, combo in enumerate(itertools.product(*param_grid.values())):
    params = dict(zip(param_grid.keys(), combo))
    print(f"\n--- Combinação {i+1}/{total_combos} ---")
    print(params)

    # Construir modelo
    layer_sizes = [params['layer1'], params['layer2'], params['layer3']]
    vae, beta_scheduler = build_conditional_vae(
        layer_sizes=layer_sizes,
        latent_dim=params['latent_dim'],
        activation=params['activation'],
        beta=params['beta'],
        learning_rate=params['learning_rate']
    )

    # Callback de early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )

    # Treinamento
    start_time = time.time()
    history = vae.fit(
        [X_train, Y_train], Y_train,
        validation_data=([X_test, Y_test], Y_test),
        epochs=800,
        batch_size=params['batch_size'],
        callbacks=[early_stopping, beta_scheduler],
        verbose=0
    )
    duration = time.time() - start_time

    # Extrair métricas do treinamento
    val_losses = history.history.get('val_loss', [])
    best_val_loss = min(val_losses) if val_losses else float('inf')
    epochs_trained = len(history.history['loss'])

    # Predições
    Y_pred = vae.predict([X_test, Y_test],
                        batch_size=params['batch_size'],
                        verbose=0)
    Y_pred = Y_pred[:len(Y_test)]  # Garantir mesmo tamanho

    # Calcular métricas
    try:
        # Métricas básicas
        evm_real_pct, _ = calculate_evm(X_test, Y_test)
        evm_pred_pct, _ = calculate_evm(X_test, Y_pred)
        snr_real = calculate_snr(X_test, Y_test)
        snr_pred = calculate_snr(X_test, Y_pred)
        noise_pow_real = calculate_noise_power(X_test, Y_test)
        noise_pow_pred = calculate_noise_power(X_test, Y_pred)

        # Métricas de distribuição
        kl_divergence = calculate_kl_gpu(Y_test, Y_pred)
        jsd = calculate_jsd_gpu(Y_test, Y_pred)

        # Testes KS
        ks_stat_i, p_val_i = calculate_ks_test(Y_test[:, 0], Y_pred[:, 0])
        ks_stat_q, p_val_q = calculate_ks_test(Y_test[:, 1], Y_pred[:, 1])

        # Métricas básicas
        mse, rmse, mae, cos_sim, corr = compute_basic_metrics(X_test, Y_pred)
        psnr = calculate_psnr(mse)

        # KL latente
        kl_latent = 0.0
        for layer in vae.layers:
            if isinstance(layer, VAELossLayer):
                kl_latent = layer.get_kl()
                break

    except Exception as e:
        print(f"Erro no cálculo de métricas: {e}")
        # Valores padrão em caso de erro
        evm_real_pct = evm_pred_pct = float('inf')
        snr_real = snr_pred = 0.0
        noise_pow_real = noise_pow_pred = 0.0
        kl_divergence = jsd = float('inf')
        ks_stat_i = ks_stat_q = p_val_i = p_val_q = 0.0
        mse = rmse = mae = psnr = float('inf')
        cos_sim = corr = kl_latent = 0.0

    # Registro dos resultados
    result = {
        **params,
        "val_loss": best_val_loss,
        "kl_latent": kl_latent,
        "kl_real_pred": kl_divergence,
        "jsd_real_pred": jsd,
        "ks_stat_i": ks_stat_i,
        "p_value_i": p_val_i,
        "ks_stat_q": ks_stat_q,
        "p_value_q": p_val_q,
        "evm_real_%": evm_real_pct,
        "evm_pred_%": evm_pred_pct,
        "delta_evm_%": evm_pred_pct - evm_real_pct,
        "snr_real_dB": snr_real,
        "snr_pred_dB": snr_pred,
        "delta_snr_dB": snr_pred - snr_real,
        "rmse_pred": rmse,
        "psnr_pred_dB": psnr,
        "diff_noise_pow": noise_pow_pred - noise_pow_real,
        "epochs": epochs_trained,
        "duration_sec": round(duration, 2),
        "timestamp": datetime.datetime.now().isoformat(timespec='seconds')
    }

    results_list.append(result)

    print(f" → val_loss={result['val_loss']:.4f} | "
          f"ΔEVM={result['delta_evm_%']:+.2f}% | "
          f"ΔSNR={result['delta_snr_dB']:+.2f} dB | "
          f"JSD={result['jsd_real_pred']:.4f}")

# Salvar resultados
df_results = pd.DataFrame(results_list)
df_results.to_csv(log_path, index=False)
print(f"\nResultados salvos em: {log_path}")

# ────────────────────────────────────────────────────────────────────────
# 6)  RANKING DOS MODELOS
# ────────────────────────────────────────────────────────────────────────

print("\nIniciando ranking dos modelos...")

# Critérios de ranking e pesos
ranking_criteria = {
    'delta_evm_%': {'weight': -1.0, 'maximize': False},
    'delta_snr_dB': {'weight': 1.0, 'maximize': True},
    'jsd_real_pred': {'weight': -2.0, 'maximize': False},
    'rmse_pred': {'weight': -1.0, 'maximize': False},
    'diff_noise_pow': {'weight': -0.5, 'maximize': False},
    'p_value_i': {'weight': 1.0, 'maximize': True},
    'p_value_q': {'weight': 1.0, 'maximize': True}
}

# Normalização robusta das métricas
df_normalized = df_results.copy()
df_normalized['score'] = 0.0

for metric, props in ranking_criteria.items():
    if metric in df_results.columns:
        values = df_results[metric]

        # Verificar se há variação nos dados
        if values.nunique() <= 1 or not np.isfinite(values).all():
            print(f"Aviso: Métrica '{metric}' tem valores constantes ou inválidos")
            df_normalized[f'{metric}_norm'] = 0.0
            continue

        # Normalização robusta (usando mediana e IQR)
        median = values.median()
        q25, q75 = values.quantile([0.25, 0.75])
        iqr = q75 - q25

        if iqr == 0:
            print(f"Aviso: IQR zero para métrica '{metric}'")
            df_normalized[f'{metric}_norm'] = 0.0
            continue

        # Normalizar
        normalized = (values - median) / iqr
        df_normalized[f'{metric}_norm'] = normalized

        # Calcular contribuição para o score
        if props['maximize']:
            score_contrib = normalized * props['weight']
        else:
            score_contrib = -normalized * props['weight']

        df_normalized['score'] += score_contrib

# Ranking final
df_ranked = df_normalized.sort_values('score', ascending=False)
df_ranked.to_csv(ranked_log_path, index=False, sep=';', decimal=',')
print(f"Resultados rankeados salvos em: {ranked_log_path}")


# Mostrar top modelos
TOP_N = 10
display_cols = ['score'] + list(param_grid.keys()) + list(ranking_criteria.keys())
display_cols = [col for col in display_cols if col in df_ranked.columns]

print(f"\n### TOP-{TOP_N} MODELOS ###")
print(df_ranked[display_cols].head(TOP_N).to_string(index=False))

# Selecionar melhor modelo
best_model = df_ranked.iloc[0]
print(f"\nMelhor modelo selecionado com score: {best_model['score']:.4f}")

print("\n🏆 GRID SEARCH CONCLUÍDO! 🏆")
print(f"Total de combinações testadas: {total_combos}")
print(f"Melhor configuração encontrada:")
for param in param_grid.keys():
    if param in best_model.index:
        print(f"  {param}: {best_model[param]}")
# Out:
# CuPy (GPU) backend ativado.
# Carregando dados...
# Arquivo localizado: /content/drive/MyDrive/Temp/IQ_data/sent_data_tuple.npy
# Arquivo localizado: /content/drive/MyDrive/Temp/IQ_data/received_data_tuple_sync-phase.npy
# Dados carregados - X: (900000, 2), Y: (900000, 2)
# Divisão - Train: X(720000, 2), Y(720000, 2)
#          Test:  X(180000, 2), Y(180000, 2)
#
# Iniciando Grid Search...
#
# --- Combinação 1/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.48, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 272: early stopping
# Restoring model weights from the end of the best epoch: 252.
#  → val_loss=-4.6740 | ΔEVM=-0.04% | ΔSNR=+0.02 dB | JSD=0.0000
#
# --- Combinação 2/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.48, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 492: early stopping
# Restoring model weights from the end of the best epoch: 472.
#  → val_loss=-4.6948 | ΔEVM=+0.01% | ΔSNR=-0.01 dB | JSD=0.0000
#
# --- Combinação 3/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.58, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 359: early stopping
# Restoring model weights from the end of the best epoch: 339.
#  → val_loss=-4.0996 | ΔEVM=+0.21% | ΔSNR=-0.10 dB | JSD=0.0000
#
# --- Combinação 4/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 48, 'beta': 0.58, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 420: early stopping
# Restoring model weights from the end of the best epoch: 400.
#  → val_loss=-4.0770 | ΔEVM=+0.27% | ΔSNR=-0.13 dB | JSD=0.0000
#
# --- Combinação 5/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.48, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 340: early stopping
# Restoring model weights from the end of the best epoch: 320.
#  → val_loss=-4.6963 | ΔEVM=-0.04% | ΔSNR=+0.02 dB | JSD=0.0000
#
# --- Combinação 6/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.48, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 471: early stopping
# Restoring model weights from the end of the best epoch: 451.
#  → val_loss=-4.6939 | ΔEVM=-0.03% | ΔSNR=+0.01 dB | JSD=0.0000
#
# --- Combinação 7/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.58, 'batch_size': 12000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 291: early stopping
# Restoring model weights from the end of the best epoch: 271.
#  → val_loss=-4.0764 | ΔEVM=-0.05% | ΔSNR=+0.02 dB | JSD=0.0000
#
# --- Combinação 8/8 ---
# {'layer1': 128, 'layer2': 256, 'layer3': 512, 'latent_dim': 54, 'beta': 0.58, 'batch_size': 20000, 'learning_rate': 0.0001, 'activation': 'leaky_relu'}
# Epoch 446: early stopping
# Restoring model weights from the end of the best epoch: 426.
#  → val_loss=-4.0903 | ΔEVM=+0.04% | ΔSNR=-0.02 dB | JSD=0.0000
#
# Resultados salvos em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/experimentos.csv
#
# Iniciando ranking dos modelos...
# Resultados rankeados salvos em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/experimentos_ranked.csv
#
# ### TOP-10 MODELOS ###
#        score  layer1  layer2  layer3  latent_dim  beta  batch_size  learning_rate activation  delta_evm_%  delta_snr_dB  jsd_real_pred  rmse_pred  diff_noise_pow  p_value_i  p_value_q
#     3.745645     128     256     512          48  0.58       20000         0.0001 leaky_relu     0.272385     -0.129995   2.162407e-06   0.149586        0.000660   1.000000        1.0
#     0.800239     128     256     512          48  0.48       20000         0.0001 leaky_relu     0.012203     -0.005867   2.150160e-06   0.147464        0.000029   1.000000        1.0
#     0.564623     128     256     512          48  0.58       12000         0.0001 leaky_relu     0.209560     -0.100185   8.002880e-07   0.149074        0.000507   1.000000        1.0
#     0.342225     128     256     512          48  0.48       12000         0.0001 leaky_relu    -0.040855      0.019667   2.353612e-06   0.147031       -0.000098   1.000000        1.0
#    -0.943813     128     256     512          54  0.58       20000         0.0001 leaky_relu     0.038872     -0.018672   1.053852e-06   0.147681        0.000094   1.000000        1.0
#    -7.389265     128     256     512          54  0.48       20000         0.0001 leaky_relu    -0.030785      0.014815   1.658122e-06   0.147113       -0.000074   1.000000        1.0
#  -101.751129     128     256     512          54  0.48       12000         0.0001 leaky_relu    -0.043112      0.020754   1.180626e-06   0.147012       -0.000104   1.000000        1.0
# -2442.199552     128     256     512          54  0.58       12000         0.0001 leaky_relu    -0.050261      0.024200   2.694835e-06   0.146954       -0.000121   0.999932        1.0
#
# Melhor modelo selecionado com score: 3.7456
#
# 🏆 GRID SEARCH CONCLUÍDO! 🏆
# Total de combinações testadas: 8
# Melhor configuração encontrada:
#   layer1: 128
#   layer2: 256
#   layer3: 512
#   latent_dim: 48
#   beta: 0.58
#   batch_size: 20000
#   learning_rate: 0.0001
#   activation: leaky_relu

# %%
# ────────────────────────────────────────────────────────────────────────
# 7)  RETREINA E SALVA O MODELO CAMPEÃO
# ────────────────────────────────────────────────────────────────────────
print("\nRetreinando o modelo campeão...")

# Selecionar os parâmetros do melhor modelo
best_params = {k: best_model[k] for k in param_grid.keys() if k in best_model.index}

# Construir o modelo campeão
vae_best, beta_cb_champion = build_conditional_vae(
    layer_sizes=[int(best_params['layer1']), int(best_params['layer2']), int(best_params['layer3'])],
    latent_dim=int(best_params['latent_dim']),
    activation=best_params['activation'],
    beta=float(best_params['beta']),
    learning_rate=float(best_params['learning_rate'])
)

# Configurar treinamento do campeão
epochs_champion_retrain = int(best_model['epochs'])
batch_size_champion_retrain = int(best_params['batch_size'])

print(f"Retreinando por {epochs_champion_retrain} épocas com batch_size {batch_size_champion_retrain}")

# Treinar o modelo campeão
history_champion = vae_best.fit(
    [X_train, Y_train], Y_train,
    epochs=epochs_champion_retrain,
    batch_size=batch_size_champion_retrain,
    callbacks=[beta_cb_champion],
    verbose=1
)

# Gerar predições finais
Y_pred_final_champion = vae_best.predict(
    [X_test, Y_test],
    batch_size=batch_size_champion_retrain,
    verbose=0
)
Y_pred_final_champion = Y_pred_final_champion[:Y_test.shape[0]]

# ─── Salvar o modelo campeão em dois formatos (CORRIGIDO para Colab / Keras 3) ───

# Nomes e caminhos para os modelos
modelo_escolhido = "cvae_campeao"
logs_base_dir = "/content/drive/MyDrive/Temp/IQ_data/logs_runs" # Exemplo de caminho

savedmodel_dir= os.path.join(logs_base_dir, modelo_escolhido + "_exported") # Pasta para SavedModel
keras_file= os.path.join(logs_base_dir, modelo_escolhido + ".keras")# Arquivo .keras



print(f"Exportando modelo para produção (TF-Serving) em: {savedmodel_dir}")
# 1) SavedModel (pasta) → Use .export() para criar um modelo para inferência.
#    Este é o método correto e moderno para compatibilidade com TF-Serving.
vae_best.export(savedmodel_dir)

print(f"Salvando modelo em formato nativo Keras em: {keras_file}")
# 2) Arquivo único .keras → Seu código já estava correto para esta parte!
#    .save() é o método certo para salvar em um arquivo .keras.
vae_best.save(keras_file, include_optimizer=False)

print("\nModelos salvos com sucesso nos dois formatos!")
print("✅ Modelo campeão salvo em:")
print(f"   • {savedmodel_dir}   (SavedModel)")
print(f"   • {keras_file} (.keras)")



# ────────────────────────────────────────────────────────────────────────
# 8)  PLOTS E MÉTRICAS DO CAMPEÃO
# ────────────────────────────────────────────────────────────────────────
print("\nGerando análises visuais e métricas para o modelo campeão...")

# Converter dados para CPU para plotagem
if gpu_enabled:
    y_test_cpu = cp.asnumpy(Y_test) if isinstance(Y_test, cp.ndarray) else Y_test
    y_pred_final_champion_cpu = cp.asnumpy(Y_pred_final_champion) if isinstance(Y_pred_final_champion, cp.ndarray) else Y_pred_final_champion
    x_test_cpu = cp.asnumpy(X_test) if isinstance(X_test, cp.ndarray) else X_test
else:
    y_test_cpu = Y_test
    y_pred_final_champion_cpu = Y_pred_final_champion
    x_test_cpu = X_test

# --- 8.1 Constelações ---
fig_const, ax_const = plt.subplots(1, 2, figsize=(12, 5))

ax_const[0].scatter(y_test_cpu[:,0], y_test_cpu[:,1], s=0.5, alpha=0.6, label="Y_test (Real)")
ax_const[0].set_title("Constelação Recebida (Y_test)")
ax_const[0].set_xlabel("Componente I")
ax_const[0].set_ylabel("Componente Q")
ax_const[0].axis('equal')
ax_const[0].grid(True, linestyle='--', alpha=0.5)
ax_const[0].legend()

ax_const[1].scatter(y_pred_final_champion_cpu[:,0], y_pred_final_champion_cpu[:,1], s=0.5, alpha=0.6, color='red', label="Y_pred (Campeão)")
ax_const[1].set_title("Constelação Reconstruída (Ŷ_campeão)")
ax_const[1].set_xlabel("Componente I")
ax_const[1].set_ylabel("Componente Q")
ax_const[1].axis('equal')
ax_const[1].grid(True, linestyle='--', alpha=0.5)
ax_const[1].legend()

plt.tight_layout()
plt.suptitle("Comparação de Constelações: Real vs. Predição do Campeão", fontsize=16, y=1.03)
plot_save_path_const = os.path.join(logs_base_dir, "campeao_constelacao_plot.png")
plt.savefig(plot_save_path_const, dpi=300, bbox_inches='tight')
print(f"Plot de constelações salvo em: {plot_save_path_const}")
plt.show()

# --- 8.2 Análise de Distribuições de Ruído ---
noise_real = y_test_cpu - x_test_cpu
noise_pred = y_pred_final_champion_cpu - x_test_cpu

noise_real_I = noise_real[:,0]
noise_real_Q = noise_real[:,1]
noise_real_Amp = np.sqrt(noise_real_I**2 + noise_real_Q**2)

noise_pred_I = noise_pred[:,0]
noise_pred_Q = noise_pred[:,1]
noise_pred_Amp = np.sqrt(noise_pred_I**2 + noise_pred_Q**2)

data_to_plot_noise = [
    (noise_real_I, noise_pred_I, 'Componente I do Ruído'),
    (noise_real_Q, noise_pred_Q, 'Componente Q do Ruído'),
    (noise_real_Amp, noise_pred_Amp, 'Amplitude do Ruído')
]

fig_hist_noise, axes_hist_noise = plt.subplots(len(data_to_plot_noise), 1, figsize=(10, 4 * len(data_to_plot_noise)))
if len(data_to_plot_noise) == 1:
    axes_hist_noise = [axes_hist_noise]

for i, (data_r, data_p, title_suffix) in enumerate(data_to_plot_noise):
    min_val = min(np.min(data_r), np.min(data_p))
    max_val = max(np.max(data_r), np.max(data_p))
    bins = np.linspace(min_val, max_val, 50)

    axes_hist_noise[i].hist(data_r, bins=bins, alpha=0.7, label='Ruído Real (Y_test - X_test)', color='blue', density=True)
    axes_hist_noise[i].hist(data_p, bins=bins, alpha=0.7, label='Ruído Predito (Y_pred - X_test)', color='red', density=True)
    axes_hist_noise[i].set_title(f'Histograma Comparativo: {title_suffix}')
    axes_hist_noise[i].set_xlabel('Valor')
    axes_hist_noise[i].set_ylabel('Densidade')
    axes_hist_noise[i].legend()
    axes_hist_noise[i].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.suptitle("Distribuições de Ruído: Real vs. Predito", fontsize=16, y=1.02)
plot_save_path_hist_noise = os.path.join(logs_base_dir, "campeao_histogramas_ruido_plot.png")
plt.savefig(plot_save_path_hist_noise, dpi=300, bbox_inches='tight')
print(f"Plot de histogramas de ruído salvo em: {plot_save_path_hist_noise}")
plt.show()

# --- 8.3 Gráficos Q-Q (Quantil-Quantil) ---
data_to_qq_signal = [
    (y_test_cpu[:,0], y_pred_final_champion_cpu[:,0], 'Componente I do Sinal Recebido'),
    (y_test_cpu[:,1], y_pred_final_champion_cpu[:,1], 'Componente Q do Sinal Recebido'),
]

fig_qq, axes_qq = plt.subplots(1, len(data_to_qq_signal), figsize=(6 * len(data_to_qq_signal), 5))
if len(data_to_qq_signal) == 1:
    axes_qq = [axes_qq]

for i, (data_r, data_p, title_suffix) in enumerate(data_to_qq_signal):
    quantiles = np.linspace(0, 100, 101)
    qn_r = np.percentile(data_r, quantiles)
    qn_p = np.percentile(data_p, quantiles)

    axes_qq[i].plot(qn_r, qn_p, 'o', markersize=3, alpha=0.7)
    min_val_qq = min(np.min(qn_r), np.min(qn_p))
    max_val_qq = max(np.max(qn_r), np.max(qn_p))
    axes_qq[i].plot([min_val_qq, max_val_qq], [min_val_qq, max_val_qq], 'r--', lw=2, label='Linha de Referência')
    axes_qq[i].set_xlabel('Quantis do Sinal Real (Y_test)')
    axes_qq[i].set_ylabel('Quantis do Sinal Predito (Y_pred)')
    axes_qq[i].set_title(f'Gráfico Q-Q: {title_suffix}')
    axes_qq[i].axis('equal')
    axes_qq[i].grid(True, linestyle='--', alpha=0.5)
    axes_qq[i].legend()

plt.tight_layout()
plt.suptitle("Gráficos Q-Q: Sinal Real vs. Predito", fontsize=16, y=1.03)
plot_save_path_qq = os.path.join(logs_base_dir, "campeao_qq_plot.png")
plt.savefig(plot_save_path_qq, dpi=300, bbox_inches='tight')
print(f"Plot Q-Q salvo em: {plot_save_path_qq}")
plt.show()

# --- 8.4 Curva de Transferência do Canal (Magnitude) ---
mag_X_test = np.sqrt(x_test_cpu[:,0]**2 + x_test_cpu[:,1]**2)
mag_Y_test = np.sqrt(y_test_cpu[:,0]**2 + y_test_cpu[:,1]**2)
mag_Y_pred = np.sqrt(y_pred_final_champion_cpu[:,0]**2 + y_pred_final_champion_cpu[:,1]**2)

# Amostragem para visualização
sample_size = min(5000, len(mag_X_test))
sample_indices = np.random.choice(len(mag_X_test), size=sample_size, replace=False)

fig_transfer, ax_transfer = plt.subplots(1, 1, figsize=(10, 7))
ax_transfer.scatter(mag_X_test[sample_indices], mag_Y_test[sample_indices],
                   alpha=0.5, s=10, label='Real (Y_test vs X_test)', color='blue')
ax_transfer.scatter(mag_X_test[sample_indices], mag_Y_pred[sample_indices],
                   alpha=0.5, s=10, label='Predito (Y_pred vs X_test)', color='red')

# Linha de referência (canal ideal)
min_mag, max_mag = np.min(mag_X_test[sample_indices]), np.max(mag_X_test[sample_indices])
ax_transfer.plot([min_mag, max_mag], [min_mag, max_mag], 'k--', lw=2, label='Canal Ideal (y=x)')

ax_transfer.set_xlabel('Magnitude do Sinal de Entrada (X_test)')
ax_transfer.set_ylabel('Magnitude do Sinal de Saída')
ax_transfer.set_title('Curva de Transferência do Canal (Magnitudes)')
ax_transfer.legend()
ax_transfer.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plot_save_path_transfer = os.path.join(logs_base_dir, "campeao_curva_transferencia_plot.png")
plt.savefig(plot_save_path_transfer, dpi=300, bbox_inches='tight')
print(f"Plot da curva de transferência salvo em: {plot_save_path_transfer}")
plt.show()

# --- 8.5 Mapa de Vetores de Erro ---
error_vectors = y_pred_final_champion_cpu - x_test_cpu
sample_indices_ev = np.random.choice(len(error_vectors), size=min(10000, len(error_vectors)), replace=False)

fig_err_vec, ax_err_vec = plt.subplots(1, 1, figsize=(8, 8))
scatter = ax_err_vec.scatter(error_vectors[sample_indices_ev, 0], error_vectors[sample_indices_ev, 1],
                           s=1, alpha=0.3, c=np.sqrt(error_vectors[sample_indices_ev, 0]**2 + error_vectors[sample_indices_ev, 1]**2),
                           cmap='viridis')
ax_err_vec.set_title('Mapa de Vetores de Erro (Ŷ_campeão - X_test)')
ax_err_vec.set_xlabel('Erro Componente I')
ax_err_vec.set_ylabel('Erro Componente Q')
ax_err_vec.axis('equal')
ax_err_vec.grid(True, linestyle='--', alpha=0.5)

# Adicionar colorbar
plt.colorbar(scatter, ax=ax_err_vec, label='Magnitude do Erro')

plt.tight_layout()
plot_save_path_err_vec = os.path.join(logs_base_dir, "campeao_mapa_vetores_erro_plot.png")
plt.savefig(plot_save_path_err_vec, dpi=300, bbox_inches='tight')
print(f"Plot do mapa de vetores de erro salvo em: {plot_save_path_err_vec}")
plt.show()

# --- 8.6 Métricas Finais do Campeão ---
print("\n🏆  MÉTRICAS DO MODELO CAMPEÃO  🏆")
print("=" * 50)
print("Hiperparâmetros:")
for param, value in best_params.items():
    print(f"  {param}: {value}")
print("=" * 50)

# Calcular métricas finais
evm_pct_champ, evm_db_champ = calculate_evm(X_test, Y_pred_final_champion)
snr_db_champ = calculate_snr(X_test, Y_pred_final_champion)
kl_final_champ = calculate_kl_gpu(Y_test, Y_pred_final_champion)
jsd_final_champ = calculate_jsd_gpu(Y_test, Y_pred_final_champion)
mse_final_champ, rmse_final_champ, mae_final_champ, cos_sim_champ, corr_champ = compute_basic_metrics(X_test, Y_pred_final_champion)
psnr_final_champ = calculate_psnr(mse_final_champ)

# Testes Kolmogorov-Smirnov
ks_stat_I, p_value_I = calculate_ks_test(y_test_cpu[:,0], y_pred_final_champion_cpu[:,0])
ks_stat_Q, p_value_Q = calculate_ks_test(y_test_cpu[:,1], y_pred_final_champion_cpu[:,1])
ks_stat_Amp, p_value_Amp = calculate_ks_test(mag_Y_test, mag_Y_pred)
ks_stat_Noise_Amp, p_value_Noise_Amp = calculate_ks_test(noise_real_Amp, noise_pred_Amp)

# Exibir métricas
print(f"MÉTRICAS DE RECONSTRUÇÃO:")
print(f"  EVM (Ŷ vs X_test)          : {evm_pct_champ:.2f}% ({evm_db_champ:.2f} dB)")
print(f"  SNR (Ŷ vs X_test)          : {snr_db_champ:.2f} dB")
print(f"  RMSE (Ŷ vs X_test)         : {rmse_final_champ:.4f}")
print(f"  MSE (Ŷ vs X_test)          : {mse_final_champ:.4f}")
print(f"  MAE (Ŷ vs X_test)          : {mae_final_champ:.4f}")
print(f"  PSNR (Ŷ vs X_test)         : {psnr_final_champ:.2f} dB")
print(f"  Similaridade Cosseno        : {cos_sim_champ:.4f}")
print(f"  Correlação                  : {corr_champ:.4f}")

print(f"\nMÉTRICAS DE DISTRIBUIÇÃO:")
print(f"  KL Divergence (Y_test||Ŷ)  : {kl_final_champ:.4f}")
print(f"  Jensen-Shannon Div. (Y,Ŷ)  : {jsd_final_champ:.4f}")

print(f"\nTESTE KOLMOGOROV-SMIRNOV (Y_test vs Ŷ):")
print(f"  Componente I - Estatística  : {ks_stat_I:.4f} (p-valor: {p_value_I:.4f})")
print(f"  Componente Q - Estatística  : {ks_stat_Q:.4f} (p-valor: {p_value_Q:.4f})")
print(f"  Amplitude Sinal - Estatística: {ks_stat_Amp:.4f} (p-valor: {p_value_Amp:.4f})")
print(f"  Amplitude Ruído - Estatística: {ks_stat_Noise_Amp:.4f} (p-valor: {p_value_Noise_Amp:.4f})")

print("=" * 50)
print(f"Score final do modelo campeão: {best_model['score']:.4f}")
print(f"Tempo de treinamento: {best_model['duration_sec']:.2f} segundos")
print(f"Épocas treinadas: {best_model['epochs']}")
print("=" * 50)

# --- 8.7 Salvar Resumo das Métricas ---
metrics_summary = {
    'model_score': best_model['score'],
    'hyperparameters': best_params,
    'reconstruction_metrics': {
        'evm_percent': evm_pct_champ,
        'evm_db': evm_db_champ,
        'snr_db': snr_db_champ,
        'rmse': rmse_final_champ,
        'mse': mse_final_champ,
        'mae': mae_final_champ,
        'psnr_db': psnr_final_champ,
        'cosine_similarity': cos_sim_champ,
        'correlation': corr_champ
    },
    'distribution_metrics': {
        'kl_divergence': kl_final_champ,
        'jsd': jsd_final_champ
    },
    'ks_tests': {
        'component_I': {'statistic': ks_stat_I, 'p_value': p_value_I},
        'component_Q': {'statistic': ks_stat_Q, 'p_value': p_value_Q},
        'signal_amplitude': {'statistic': ks_stat_Amp, 'p_value': p_value_Amp},
        'noise_amplitude': {'statistic': ks_stat_Noise_Amp, 'p_value': p_value_Noise_Amp}
    },
    'training_info': {
        'epochs': int(best_model['epochs']),
        'duration_sec': float(best_model['duration_sec']),
        'timestamp': best_model['timestamp']
    }
}

# Salvar resumo em JSON
import json
summary_path = os.path.join(logs_base_dir, "champion_model_summary.json")
with open(summary_path, 'w') as f:
    json.dump(metrics_summary, f, indent=2, default=str)
print(f"Resumo das métricas salvo em: {summary_path}")

print("\n🎯 ANÁLISE DO MODELO CAMPEÃO CONCLUÍDA! 🎯")
print(f"Todos os plots e métricas foram salvos em: {logs_base_dir}")
# Out:
# Retreinando o modelo campeão...
# Retreinando por 420 épocas com batch_size 20000
# Epoch 1/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_divergence: 0.1473 - loss: 1.8442 - neg_log_likelihood: 1.8442 - reconstruction_error: 0.2948 - total_loss: 1.8442
# Epoch 2/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.6569 - loss: 0.6312 - neg_log_likelihood: 0.5351 - reconstruction_error: 0.0944 - total_loss: 0.6312
# Epoch 3/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1261 - loss: 0.1806 - neg_log_likelihood: -0.2980 - reconstruction_error: 0.0390 - total_loss: 0.1806
# Epoch 4/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.6052 - loss: 0.0220 - neg_log_likelihood: -0.4313 - reconstruction_error: 0.0348 - total_loss: 0.0220
# Epoch 5/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.0724 - loss: -0.2123 - neg_log_likelihood: -0.4611 - reconstruction_error: 0.0335 - total_loss: -0.2123
# Epoch 6/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3893 - loss: -0.4383 - neg_log_likelihood: -0.5512 - reconstruction_error: 0.0305 - total_loss: -0.4383
# Epoch 7/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1970 - loss: -0.5956 - neg_log_likelihood: -0.6642 - reconstruction_error: 0.0271 - total_loss: -0.5956
# Epoch 8/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1197 - loss: -0.7231 - neg_log_likelihood: -0.7717 - reconstruction_error: 0.0243 - total_loss: -0.7231
# Epoch 9/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0780 - loss: -0.8204 - neg_log_likelihood: -0.8566 - reconstruction_error: 0.0222 - total_loss: -0.8204
# Epoch 10/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0545 - loss: -0.9016 - neg_log_likelihood: -0.9300 - reconstruction_error: 0.0206 - total_loss: -0.9016
# Epoch 11/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0399 - loss: -0.9701 - neg_log_likelihood: -0.9932 - reconstruction_error: 0.0194 - total_loss: -0.9701
# Epoch 12/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0327 - loss: -1.0304 - neg_log_likelihood: -1.0493 - reconstruction_error: 0.0183 - total_loss: -1.0304
# Epoch 13/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0303 - loss: -1.0774 - neg_log_likelihood: -1.0950 - reconstruction_error: 0.0175 - total_loss: -1.0774
# Epoch 14/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0291 - loss: -1.1211 - neg_log_likelihood: -1.1380 - reconstruction_error: 0.0168 - total_loss: -1.1211
# Epoch 15/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0282 - loss: -1.1608 - neg_log_likelihood: -1.1771 - reconstruction_error: 0.0162 - total_loss: -1.1608
# Epoch 16/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0281 - loss: -1.1926 - neg_log_likelihood: -1.2089 - reconstruction_error: 0.0158 - total_loss: -1.1926
# Epoch 17/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0283 - loss: -1.2209 - neg_log_likelihood: -1.2373 - reconstruction_error: 0.0154 - total_loss: -1.2209
# Epoch 18/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0291 - loss: -1.2512 - neg_log_likelihood: -1.2681 - reconstruction_error: 0.0150 - total_loss: -1.2512
# Epoch 19/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0302 - loss: -1.2734 - neg_log_likelihood: -1.2909 - reconstruction_error: 0.0147 - total_loss: -1.2734
# Epoch 20/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0324 - loss: -1.2964 - neg_log_likelihood: -1.3152 - reconstruction_error: 0.0144 - total_loss: -1.2964
# Epoch 21/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0347 - loss: -1.3201 - neg_log_likelihood: -1.3402 - reconstruction_error: 0.0141 - total_loss: -1.3201
# Epoch 22/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0378 - loss: -1.3427 - neg_log_likelihood: -1.3647 - reconstruction_error: 0.0138 - total_loss: -1.3427
# Epoch 23/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0424 - loss: -1.3628 - neg_log_likelihood: -1.3874 - reconstruction_error: 0.0136 - total_loss: -1.3628
# Epoch 24/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0473 - loss: -1.3805 - neg_log_likelihood: -1.4079 - reconstruction_error: 0.0134 - total_loss: -1.3805
# Epoch 25/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0536 - loss: -1.4009 - neg_log_likelihood: -1.4320 - reconstruction_error: 0.0132 - total_loss: -1.4009
# Epoch 26/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0613 - loss: -1.4174 - neg_log_likelihood: -1.4530 - reconstruction_error: 0.0130 - total_loss: -1.4174
# Epoch 27/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0700 - loss: -1.4335 - neg_log_likelihood: -1.4741 - reconstruction_error: 0.0128 - total_loss: -1.4335
# Epoch 28/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0808 - loss: -1.4547 - neg_log_likelihood: -1.5015 - reconstruction_error: 0.0126 - total_loss: -1.4547
# Epoch 29/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.0917 - loss: -1.4652 - neg_log_likelihood: -1.5183 - reconstruction_error: 0.0124 - total_loss: -1.4652
# Epoch 30/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1040 - loss: -1.4789 - neg_log_likelihood: -1.5392 - reconstruction_error: 0.0122 - total_loss: -1.4789
# Epoch 31/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1181 - loss: -1.4943 - neg_log_likelihood: -1.5628 - reconstruction_error: 0.0120 - total_loss: -1.4943
# Epoch 32/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1348 - loss: -1.5054 - neg_log_likelihood: -1.5836 - reconstruction_error: 0.0118 - total_loss: -1.5054
# Epoch 33/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1534 - loss: -1.5169 - neg_log_likelihood: -1.6059 - reconstruction_error: 0.0116 - total_loss: -1.5169
# Epoch 34/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1733 - loss: -1.5292 - neg_log_likelihood: -1.6297 - reconstruction_error: 0.0113 - total_loss: -1.5292
# Epoch 35/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.1959 - loss: -1.5391 - neg_log_likelihood: -1.6528 - reconstruction_error: 0.0111 - total_loss: -1.5391
# Epoch 36/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.2143 - loss: -1.5512 - neg_log_likelihood: -1.6756 - reconstruction_error: 0.0108 - total_loss: -1.5512
# Epoch 37/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.2370 - loss: -1.5619 - neg_log_likelihood: -1.6993 - reconstruction_error: 0.0106 - total_loss: -1.5619
# Epoch 38/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.2578 - loss: -1.5727 - neg_log_likelihood: -1.7222 - reconstruction_error: 0.0103 - total_loss: -1.5727
# Epoch 39/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.2728 - loss: -1.5792 - neg_log_likelihood: -1.7374 - reconstruction_error: 0.0102 - total_loss: -1.5792
# Epoch 40/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.2855 - loss: -1.5882 - neg_log_likelihood: -1.7538 - reconstruction_error: 0.0100 - total_loss: -1.5882
# Epoch 41/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3020 - loss: -1.5968 - neg_log_likelihood: -1.7719 - reconstruction_error: 0.0098 - total_loss: -1.5968
# Epoch 42/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3149 - loss: -1.6058 - neg_log_likelihood: -1.7885 - reconstruction_error: 0.0097 - total_loss: -1.6058
# Epoch 43/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3262 - loss: -1.6166 - neg_log_likelihood: -1.8058 - reconstruction_error: 0.0095 - total_loss: -1.6166
# Epoch 44/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3371 - loss: -1.6195 - neg_log_likelihood: -1.8150 - reconstruction_error: 0.0095 - total_loss: -1.6195
# Epoch 45/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3478 - loss: -1.6285 - neg_log_likelihood: -1.8302 - reconstruction_error: 0.0093 - total_loss: -1.6285
# Epoch 46/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3629 - loss: -1.6381 - neg_log_likelihood: -1.8485 - reconstruction_error: 0.0092 - total_loss: -1.6381
# Epoch 47/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3754 - loss: -1.6434 - neg_log_likelihood: -1.8611 - reconstruction_error: 0.0091 - total_loss: -1.6434
# Epoch 48/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3865 - loss: -1.6531 - neg_log_likelihood: -1.8773 - reconstruction_error: 0.0089 - total_loss: -1.6531
# Epoch 49/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.3999 - loss: -1.6539 - neg_log_likelihood: -1.8858 - reconstruction_error: 0.0088 - total_loss: -1.6538
# Epoch 50/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.4138 - loss: -1.6641 - neg_log_likelihood: -1.9041 - reconstruction_error: 0.0087 - total_loss: -1.6641
# Epoch 51/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.4349 - loss: -1.6676 - neg_log_likelihood: -1.9198 - reconstruction_error: 0.0085 - total_loss: -1.6676
# Epoch 52/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.4583 - loss: -1.6784 - neg_log_likelihood: -1.9442 - reconstruction_error: 0.0083 - total_loss: -1.6784
# Epoch 53/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.5004 - loss: -1.6865 - neg_log_likelihood: -1.9767 - reconstruction_error: 0.0081 - total_loss: -1.6865
# Epoch 54/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.5835 - loss: -1.7059 - neg_log_likelihood: -2.0443 - reconstruction_error: 0.0075 - total_loss: -1.7059
# Epoch 55/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.7174 - loss: -1.7030 - neg_log_likelihood: -2.1190 - reconstruction_error: 0.0070 - total_loss: -1.7030
# Epoch 56/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.8693 - loss: -1.7512 - neg_log_likelihood: -2.2554 - reconstruction_error: 0.0062 - total_loss: -1.7512
# Epoch 57/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 0.9140 - loss: -1.7696 - neg_log_likelihood: -2.2997 - reconstruction_error: 0.0060 - total_loss: -1.7696
# Epoch 58/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.0447 - loss: -1.7965 - neg_log_likelihood: -2.4024 - reconstruction_error: 0.0056 - total_loss: -1.7965
# Epoch 59/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.0959 - loss: -1.8159 - neg_log_likelihood: -2.4515 - reconstruction_error: 0.0053 - total_loss: -1.8159
# Epoch 60/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.1911 - loss: -1.8303 - neg_log_likelihood: -2.5211 - reconstruction_error: 0.0050 - total_loss: -1.8303
# Epoch 61/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.3062 - loss: -1.8649 - neg_log_likelihood: -2.6225 - reconstruction_error: 0.0044 - total_loss: -1.8649
# Epoch 62/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.6029 - loss: -1.9095 - neg_log_likelihood: -2.8391 - reconstruction_error: 0.0034 - total_loss: -1.9095
# Epoch 63/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.6828 - loss: -1.9466 - neg_log_likelihood: -2.9226 - reconstruction_error: 0.0030 - total_loss: -1.9466
# Epoch 64/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.8767 - loss: -1.9865 - neg_log_likelihood: -3.0750 - reconstruction_error: 0.0026 - total_loss: -1.9865
# Epoch 65/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 1.9446 - loss: -1.9981 - neg_log_likelihood: -3.1260 - reconstruction_error: 0.0025 - total_loss: -1.9981
# Epoch 66/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.0025 - loss: -2.0321 - neg_log_likelihood: -3.1935 - reconstruction_error: 0.0023 - total_loss: -2.0321
# Epoch 67/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.0387 - loss: -2.0504 - neg_log_likelihood: -3.2329 - reconstruction_error: 0.0022 - total_loss: -2.0504
# Epoch 68/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.1275 - loss: -2.0776 - neg_log_likelihood: -3.3115 - reconstruction_error: 0.0020 - total_loss: -2.0776
# Epoch 69/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.1478 - loss: -2.0856 - neg_log_likelihood: -3.3313 - reconstruction_error: 0.0020 - total_loss: -2.0856
# Epoch 70/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.2199 - loss: -2.1137 - neg_log_likelihood: -3.4013 - reconstruction_error: 0.0019 - total_loss: -2.1137
# Epoch 71/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.2923 - loss: -2.1256 - neg_log_likelihood: -3.4551 - reconstruction_error: 0.0018 - total_loss: -2.1256
# Epoch 72/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.2971 - loss: -2.1433 - neg_log_likelihood: -3.4756 - reconstruction_error: 0.0017 - total_loss: -2.1433
# Epoch 73/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.3258 - loss: -2.1640 - neg_log_likelihood: -3.5130 - reconstruction_error: 0.0017 - total_loss: -2.1640
# Epoch 74/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.4088 - loss: -2.1870 - neg_log_likelihood: -3.5841 - reconstruction_error: 0.0016 - total_loss: -2.1870
# Epoch 75/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.4270 - loss: -2.1967 - neg_log_likelihood: -3.6043 - reconstruction_error: 0.0015 - total_loss: -2.1967
# Epoch 76/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.4739 - loss: -2.2188 - neg_log_likelihood: -3.6536 - reconstruction_error: 0.0015 - total_loss: -2.2188
# Epoch 77/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.5447 - loss: -2.2346 - neg_log_likelihood: -3.7105 - reconstruction_error: 0.0014 - total_loss: -2.2346
# Epoch 78/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.5501 - loss: -2.2608 - neg_log_likelihood: -3.7399 - reconstruction_error: 0.0014 - total_loss: -2.2608
# Epoch 79/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.6039 - loss: -2.2794 - neg_log_likelihood: -3.7897 - reconstruction_error: 0.0013 - total_loss: -2.2794
# Epoch 80/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.6594 - loss: -2.2850 - neg_log_likelihood: -3.8274 - reconstruction_error: 0.0012 - total_loss: -2.2850
# Epoch 81/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.6689 - loss: -2.2989 - neg_log_likelihood: -3.8469 - reconstruction_error: 0.0012 - total_loss: -2.2989
# Epoch 82/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.7378 - loss: -2.3176 - neg_log_likelihood: -3.9055 - reconstruction_error: 0.0012 - total_loss: -2.3176
# Epoch 83/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.7767 - loss: -2.3381 - neg_log_likelihood: -3.9486 - reconstruction_error: 0.0011 - total_loss: -2.3381
# Epoch 84/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.7759 - loss: -2.3444 - neg_log_likelihood: -3.9544 - reconstruction_error: 0.0011 - total_loss: -2.3444
# Epoch 85/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.8453 - loss: -2.3461 - neg_log_likelihood: -3.9964 - reconstruction_error: 0.0011 - total_loss: -2.3461
# Epoch 86/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.8771 - loss: -2.3815 - neg_log_likelihood: -4.0502 - reconstruction_error: 0.0010 - total_loss: -2.3815
# Epoch 87/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.9083 - loss: -2.3958 - neg_log_likelihood: -4.0826 - reconstruction_error: 9.8268e-04 - total_loss: -2.3958
# Epoch 88/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.9369 - loss: -2.4160 - neg_log_likelihood: -4.1194 - reconstruction_error: 9.4884e-04 - total_loss: -2.4160
# Epoch 89/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.9647 - loss: -2.4135 - neg_log_likelihood: -4.1330 - reconstruction_error: 9.3611e-04 - total_loss: -2.4135
# Epoch 90/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 2.9927 - loss: -2.4528 - neg_log_likelihood: -4.1886 - reconstruction_error: 8.9125e-04 - total_loss: -2.4528
# Epoch 91/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.0562 - loss: -2.4545 - neg_log_likelihood: -4.2271 - reconstruction_error: 8.6047e-04 - total_loss: -2.4545
# Epoch 92/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.0631 - loss: -2.4631 - neg_log_likelihood: -4.2396 - reconstruction_error: 8.4918e-04 - total_loss: -2.4631
# Epoch 93/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.1047 - loss: -2.4774 - neg_log_likelihood: -4.2781 - reconstruction_error: 8.1890e-04 - total_loss: -2.4774
# Epoch 94/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.1457 - loss: -2.4998 - neg_log_likelihood: -4.3243 - reconstruction_error: 7.8455e-04 - total_loss: -2.4998
# Epoch 95/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.2066 - loss: -2.5054 - neg_log_likelihood: -4.3652 - reconstruction_error: 7.5375e-04 - total_loss: -2.5054
# Epoch 96/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.1960 - loss: -2.5154 - neg_log_likelihood: -4.3691 - reconstruction_error: 7.5366e-04 - total_loss: -2.5154
# Epoch 97/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.2636 - loss: -2.5491 - neg_log_likelihood: -4.4421 - reconstruction_error: 7.0398e-04 - total_loss: -2.5491
# Epoch 98/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.2403 - loss: -2.5530 - neg_log_likelihood: -4.4324 - reconstruction_error: 7.1218e-04 - total_loss: -2.5530
# Epoch 99/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.3181 - loss: -2.5557 - neg_log_likelihood: -4.4801 - reconstruction_error: 6.7846e-04 - total_loss: -2.5557
# Epoch 100/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.3263 - loss: -2.5880 - neg_log_likelihood: -4.5172 - reconstruction_error: 6.5858e-04 - total_loss: -2.5880
# Epoch 101/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.3904 - loss: -2.5932 - neg_log_likelihood: -4.5596 - reconstruction_error: 6.3130e-04 - total_loss: -2.5932
# Epoch 102/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.3767 - loss: -2.6025 - neg_log_likelihood: -4.5610 - reconstruction_error: 6.3021e-04 - total_loss: -2.6025
# Epoch 103/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.4175 - loss: -2.6126 - neg_log_likelihood: -4.5948 - reconstruction_error: 6.1133e-04 - total_loss: -2.6126
# Epoch 104/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.4267 - loss: -2.6118 - neg_log_likelihood: -4.5993 - reconstruction_error: 6.0887e-04 - total_loss: -2.6118
# Epoch 105/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.3283 - loss: -2.6271 - neg_log_likelihood: -4.5575 - reconstruction_error: 6.3744e-04 - total_loss: -2.6271
# Epoch 106/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.4469 - loss: -2.6250 - neg_log_likelihood: -4.6242 - reconstruction_error: 5.9246e-04 - total_loss: -2.6250
# Epoch 107/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.5418 - loss: -2.6851 - neg_log_likelihood: -4.7394 - reconstruction_error: 5.3744e-04 - total_loss: -2.6851
# Epoch 108/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.6054 - loss: -2.6718 - neg_log_likelihood: -4.7629 - reconstruction_error: 5.2401e-04 - total_loss: -2.6718
# Epoch 109/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.5049 - loss: -2.7065 - neg_log_likelihood: -4.7394 - reconstruction_error: 5.3701e-04 - total_loss: -2.7065
# Epoch 110/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.6286 - loss: -2.6932 - neg_log_likelihood: -4.7977 - reconstruction_error: 5.0551e-04 - total_loss: -2.6932
# Epoch 111/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.6379 - loss: -2.7096 - neg_log_likelihood: -4.8196 - reconstruction_error: 4.9710e-04 - total_loss: -2.7096
# Epoch 112/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.6893 - loss: -2.7316 - neg_log_likelihood: -4.8714 - reconstruction_error: 4.7472e-04 - total_loss: -2.7316
# Epoch 113/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.6004 - loss: -2.4928 - neg_log_likelihood: -4.5810 - reconstruction_error: 5.9124e-04 - total_loss: -2.4928
# Epoch 114/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.5049 - loss: -2.7584 - neg_log_likelihood: -4.7912 - reconstruction_error: 5.2191e-04 - total_loss: -2.7584
# Epoch 115/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.7141 - loss: -2.7656 - neg_log_likelihood: -4.9197 - reconstruction_error: 4.5449e-04 - total_loss: -2.7656
# Epoch 116/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.7832 - loss: -2.7834 - neg_log_likelihood: -4.9776 - reconstruction_error: 4.3136e-04 - total_loss: -2.7834
# Epoch 117/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.8185 - loss: -2.8085 - neg_log_likelihood: -5.0232 - reconstruction_error: 4.1380e-04 - total_loss: -2.8085
# Epoch 118/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.8498 - loss: -2.6916 - neg_log_likelihood: -4.9245 - reconstruction_error: 4.4363e-04 - total_loss: -2.6916
# Epoch 119/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.7530 - loss: -2.8312 - neg_log_likelihood: -5.0079 - reconstruction_error: 4.2102e-04 - total_loss: -2.8312
# Epoch 120/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.9093 - loss: -2.7976 - neg_log_likelihood: -5.0650 - reconstruction_error: 3.9631e-04 - total_loss: -2.7976
# Epoch 121/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.8644 - loss: -2.7119 - neg_log_likelihood: -4.9532 - reconstruction_error: 4.2988e-04 - total_loss: -2.7119
# Epoch 122/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.8695 - loss: -2.8553 - neg_log_likelihood: -5.0996 - reconstruction_error: 3.8718e-04 - total_loss: -2.8553
# Epoch 123/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.9695 - loss: -2.7729 - neg_log_likelihood: -5.0752 - reconstruction_error: 3.8763e-04 - total_loss: -2.7729
# Epoch 124/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.9398 - loss: -2.8818 - neg_log_likelihood: -5.1669 - reconstruction_error: 3.6350e-04 - total_loss: -2.8818
# Epoch 125/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.9945 - loss: -2.8677 - neg_log_likelihood: -5.1846 - reconstruction_error: 3.5651e-04 - total_loss: -2.8677
# Epoch 126/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.0078 - loss: -2.8625 - neg_log_likelihood: -5.1870 - reconstruction_error: 3.5627e-04 - total_loss: -2.8625
# Epoch 127/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.8597 - loss: -2.7513 - neg_log_likelihood: -4.9899 - reconstruction_error: 4.0610e-04 - total_loss: -2.7513
# Epoch 128/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.7736 - loss: -2.9015 - neg_log_likelihood: -5.0902 - reconstruction_error: 3.9222e-04 - total_loss: -2.9015
# Epoch 129/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.0460 - loss: -2.9229 - neg_log_likelihood: -5.2696 - reconstruction_error: 3.3145e-04 - total_loss: -2.9229
# Epoch 130/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.0482 - loss: -2.9239 - neg_log_likelihood: -5.2719 - reconstruction_error: 3.3013e-04 - total_loss: -2.9239
# Epoch 131/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1315 - loss: -2.9043 - neg_log_likelihood: -5.3006 - reconstruction_error: 3.2006e-04 - total_loss: -2.9043
# Epoch 132/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1006 - loss: -2.9326 - neg_log_likelihood: -5.3109 - reconstruction_error: 3.1742e-04 - total_loss: -2.9326
# Epoch 133/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1704 - loss: -2.9512 - neg_log_likelihood: -5.3700 - reconstruction_error: 3.0163e-04 - total_loss: -2.9512
# Epoch 134/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1822 - loss: -2.8893 - neg_log_likelihood: -5.3150 - reconstruction_error: 3.1334e-04 - total_loss: -2.8893
# Epoch 135/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.0945 - loss: -2.9073 - neg_log_likelihood: -5.2821 - reconstruction_error: 3.2190e-04 - total_loss: -2.9073
# Epoch 136/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1525 - loss: -3.0004 - neg_log_likelihood: -5.4088 - reconstruction_error: 2.9342e-04 - total_loss: -3.0004
# Epoch 137/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.2500 - loss: -2.8461 - neg_log_likelihood: -5.3111 - reconstruction_error: 3.0996e-04 - total_loss: -2.8461
# Epoch 138/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 3.9609 - loss: -2.9009 - neg_log_likelihood: -5.1982 - reconstruction_error: 3.4132e-04 - total_loss: -2.9009
# Epoch 139/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.0313 - loss: -3.0196 - neg_log_likelihood: -5.3578 - reconstruction_error: 3.0878e-04 - total_loss: -3.0196
# Epoch 140/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.2538 - loss: -2.9399 - neg_log_likelihood: -5.4070 - reconstruction_error: 2.8669e-04 - total_loss: -2.9399
# Epoch 141/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.3202 - loss: -3.0396 - neg_log_likelihood: -5.5453 - reconstruction_error: 2.5875e-04 - total_loss: -3.0396
# Epoch 142/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.3601 - loss: -2.8166 - neg_log_likelihood: -5.3455 - reconstruction_error: 2.9550e-04 - total_loss: -2.8166
# Epoch 143/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1260 - loss: -2.9370 - neg_log_likelihood: -5.3301 - reconstruction_error: 3.0503e-04 - total_loss: -2.9370
# Epoch 144/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.2515 - loss: -3.0827 - neg_log_likelihood: -5.5486 - reconstruction_error: 2.6016e-04 - total_loss: -3.0827
# Epoch 145/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4238 - loss: -3.0796 - neg_log_likelihood: -5.6454 - reconstruction_error: 2.3678e-04 - total_loss: -3.0796
# Epoch 146/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4174 - loss: -2.6772 - neg_log_likelihood: -5.2392 - reconstruction_error: 3.0745e-04 - total_loss: -2.6772
# Epoch 147/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1831 - loss: -2.9017 - neg_log_likelihood: -5.3279 - reconstruction_error: 3.0364e-04 - total_loss: -2.9017
# Epoch 148/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1685 - loss: -3.1077 - neg_log_likelihood: -5.5254 - reconstruction_error: 2.6657e-04 - total_loss: -3.1077
# Epoch 149/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4297 - loss: -3.1288 - neg_log_likelihood: -5.6980 - reconstruction_error: 2.2729e-04 - total_loss: -3.1288
# Epoch 150/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5398 - loss: -2.8151 - neg_log_likelihood: -5.4482 - reconstruction_error: 2.6558e-04 - total_loss: -2.8151
# Epoch 151/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.1580 - loss: -3.0278 - neg_log_likelihood: -5.4394 - reconstruction_error: 2.7456e-04 - total_loss: -3.0278
# Epoch 152/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.3141 - loss: -3.1060 - neg_log_likelihood: -5.6082 - reconstruction_error: 2.4633e-04 - total_loss: -3.1060
# Epoch 153/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4058 - loss: -2.9182 - neg_log_likelihood: -5.4736 - reconstruction_error: 2.6457e-04 - total_loss: -2.9182
# Epoch 154/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.2990 - loss: -3.1451 - neg_log_likelihood: -5.6386 - reconstruction_error: 2.3965e-04 - total_loss: -3.1451
# Epoch 155/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5142 - loss: -3.1736 - neg_log_likelihood: -5.7919 - reconstruction_error: 2.0910e-04 - total_loss: -3.1736
# Epoch 156/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6228 - loss: -3.1568 - neg_log_likelihood: -5.8380 - reconstruction_error: 1.9902e-04 - total_loss: -3.1568
# Epoch 157/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6220 - loss: -3.0458 - neg_log_likelihood: -5.7266 - reconstruction_error: 2.1386e-04 - total_loss: -3.0458
# Epoch 158/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4566 - loss: -3.1429 - neg_log_likelihood: -5.7277 - reconstruction_error: 2.1778e-04 - total_loss: -3.1429
# Epoch 159/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5631 - loss: -3.1307 - neg_log_likelihood: -5.7773 - reconstruction_error: 2.0891e-04 - total_loss: -3.1307
# Epoch 160/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5098 - loss: -3.0892 - neg_log_likelihood: -5.7048 - reconstruction_error: 2.1805e-04 - total_loss: -3.0892
# Epoch 161/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5357 - loss: -3.2008 - neg_log_likelihood: -5.8315 - reconstruction_error: 2.0132e-04 - total_loss: -3.2008
# Epoch 162/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6713 - loss: -3.1614 - neg_log_likelihood: -5.8707 - reconstruction_error: 1.9148e-04 - total_loss: -3.1614
# Epoch 163/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6737 - loss: -3.1539 - neg_log_likelihood: -5.8647 - reconstruction_error: 1.9229e-04 - total_loss: -3.1539
# Epoch 164/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6732 - loss: -2.8813 - neg_log_likelihood: -5.5917 - reconstruction_error: 2.2510e-04 - total_loss: -2.8813
# Epoch 165/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5466 - loss: -3.0410 - neg_log_likelihood: -5.6780 - reconstruction_error: 2.1840e-04 - total_loss: -3.0410
# Epoch 166/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5916 - loss: -3.2568 - neg_log_likelihood: -5.9200 - reconstruction_error: 1.8708e-04 - total_loss: -3.2568
# Epoch 167/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7804 - loss: -2.8953 - neg_log_likelihood: -5.6680 - reconstruction_error: 2.1644e-04 - total_loss: -2.8953
# Epoch 168/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4480 - loss: -3.1588 - neg_log_likelihood: -5.7387 - reconstruction_error: 2.1099e-04 - total_loss: -3.1588
# Epoch 169/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5482 - loss: -3.2525 - neg_log_likelihood: -5.8905 - reconstruction_error: 1.9316e-04 - total_loss: -3.2525
# Epoch 170/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7219 - loss: -2.8360 - neg_log_likelihood: -5.5747 - reconstruction_error: 2.2408e-04 - total_loss: -2.8360
# Epoch 171/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.4255 - loss: -3.1837 - neg_log_likelihood: -5.7504 - reconstruction_error: 2.0835e-04 - total_loss: -3.1837
# Epoch 172/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.5880 - loss: -3.2957 - neg_log_likelihood: -5.9567 - reconstruction_error: 1.8167e-04 - total_loss: -3.2957
# Epoch 173/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7780 - loss: -3.1157 - neg_log_likelihood: -5.8869 - reconstruction_error: 1.8341e-04 - total_loss: -3.1157
# Epoch 174/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8019 - loss: -3.3205 - neg_log_likelihood: -6.1056 - reconstruction_error: 1.5886e-04 - total_loss: -3.3205
# Epoch 175/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9250 - loss: -2.8858 - neg_log_likelihood: -5.7424 - reconstruction_error: 1.9751e-04 - total_loss: -2.8858
# Epoch 176/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.6084 - loss: -3.2479 - neg_log_likelihood: -5.9208 - reconstruction_error: 1.8218e-04 - total_loss: -3.2479
# Epoch 177/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7362 - loss: -3.2965 - neg_log_likelihood: -6.0435 - reconstruction_error: 1.6732e-04 - total_loss: -3.2965
# Epoch 178/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8348 - loss: -3.2217 - neg_log_likelihood: -6.0259 - reconstruction_error: 1.6523e-04 - total_loss: -3.2217
# Epoch 179/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8367 - loss: -3.3529 - neg_log_likelihood: -6.1583 - reconstruction_error: 1.5200e-04 - total_loss: -3.3529
# Epoch 180/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9755 - loss: -3.2687 - neg_log_likelihood: -6.1545 - reconstruction_error: 1.4912e-04 - total_loss: -3.2687
# Epoch 181/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9584 - loss: -3.3145 - neg_log_likelihood: -6.1904 - reconstruction_error: 1.4595e-04 - total_loss: -3.3145
# Epoch 182/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9729 - loss: -3.3353 - neg_log_likelihood: -6.2196 - reconstruction_error: 1.4173e-04 - total_loss: -3.3353
# Epoch 183/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9940 - loss: -3.1547 - neg_log_likelihood: -6.0513 - reconstruction_error: 1.5772e-04 - total_loss: -3.1547
# Epoch 184/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9293 - loss: -3.0531 - neg_log_likelihood: -5.9121 - reconstruction_error: 1.7430e-04 - total_loss: -3.0531
# Epoch 185/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7191 - loss: -3.3589 - neg_log_likelihood: -6.0959 - reconstruction_error: 1.5908e-04 - total_loss: -3.3589
# Epoch 186/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9299 - loss: -3.2622 - neg_log_likelihood: -6.1215 - reconstruction_error: 1.5140e-04 - total_loss: -3.2622
# Epoch 187/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9880 - loss: -3.2101 - neg_log_likelihood: -6.1031 - reconstruction_error: 1.5232e-04 - total_loss: -3.2101
# Epoch 188/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8859 - loss: -3.3590 - neg_log_likelihood: -6.1928 - reconstruction_error: 1.4445e-04 - total_loss: -3.3590
# Epoch 189/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9680 - loss: -3.0623 - neg_log_likelihood: -5.9438 - reconstruction_error: 1.6468e-04 - total_loss: -3.0623
# Epoch 190/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9415 - loss: -3.4259 - neg_log_likelihood: -6.2920 - reconstruction_error: 1.3536e-04 - total_loss: -3.4259
# Epoch 191/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.1159 - loss: -2.9226 - neg_log_likelihood: -5.8899 - reconstruction_error: 1.6881e-04 - total_loss: -2.9226
# Epoch 192/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8553 - loss: -3.2949 - neg_log_likelihood: -6.1110 - reconstruction_error: 1.5064e-04 - total_loss: -3.2949
# Epoch 193/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.8965 - loss: -3.4176 - neg_log_likelihood: -6.2575 - reconstruction_error: 1.3950e-04 - total_loss: -3.4176
# Epoch 194/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.0537 - loss: -3.3750 - neg_log_likelihood: -6.3061 - reconstruction_error: 1.3145e-04 - total_loss: -3.3750
# Epoch 195/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.1637 - loss: -3.1509 - neg_log_likelihood: -6.1458 - reconstruction_error: 1.4338e-04 - total_loss: -3.1509
# Epoch 196/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9585 - loss: -3.0536 - neg_log_likelihood: -5.9295 - reconstruction_error: 1.6105e-04 - total_loss: -3.0536
# Epoch 197/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.7449 - loss: -3.4117 - neg_log_likelihood: -6.1637 - reconstruction_error: 1.5019e-04 - total_loss: -3.4117
# Epoch 198/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9903 - loss: -3.3413 - neg_log_likelihood: -6.2357 - reconstruction_error: 1.3805e-04 - total_loss: -3.3413
# Epoch 199/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.0480 - loss: -3.4723 - neg_log_likelihood: -6.4002 - reconstruction_error: 1.2316e-04 - total_loss: -3.4723
# Epoch 200/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.1697 - loss: -2.6827 - neg_log_likelihood: -5.6811 - reconstruction_error: 1.7570e-04 - total_loss: -2.6827
# Epoch 201/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9185 - loss: -3.4257 - neg_log_likelihood: -6.2784 - reconstruction_error: 1.3309e-04 - total_loss: -3.4257
# Epoch 202/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.0565 - loss: -3.4978 - neg_log_likelihood: -6.4306 - reconstruction_error: 1.2096e-04 - total_loss: -3.4978
# Epoch 203/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.2383 - loss: -3.2285 - neg_log_likelihood: -6.2667 - reconstruction_error: 1.2809e-04 - total_loss: -3.2285
# Epoch 204/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.2103 - loss: -3.4950 - neg_log_likelihood: -6.5170 - reconstruction_error: 1.1106e-04 - total_loss: -3.4950
# Epoch 205/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.2968 - loss: -3.5213 - neg_log_likelihood: -6.5934 - reconstruction_error: 1.0500e-04 - total_loss: -3.5213
# Epoch 206/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.3830 - loss: -3.2210 - neg_log_likelihood: -6.3431 - reconstruction_error: 1.2007e-04 - total_loss: -3.2210
# Epoch 207/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.3499 - loss: -3.2176 - neg_log_likelihood: -6.3205 - reconstruction_error: 1.2374e-04 - total_loss: -3.2176
# Epoch 208/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.1916 - loss: -3.1733 - neg_log_likelihood: -6.1845 - reconstruction_error: 1.3361e-04 - total_loss: -3.1733
# Epoch 209/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 4.9666 - loss: -3.5043 - neg_log_likelihood: -6.3849 - reconstruction_error: 1.2507e-04 - total_loss: -3.5043
# Epoch 210/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.1935 - loss: -3.4765 - neg_log_likelihood: -6.4887 - reconstruction_error: 1.1373e-04 - total_loss: -3.4765
# Epoch 211/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.3110 - loss: -3.3230 - neg_log_likelihood: -6.4034 - reconstruction_error: 1.1576e-04 - total_loss: -3.3230
# Epoch 212/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.3099 - loss: -3.5580 - neg_log_likelihood: -6.6378 - reconstruction_error: 1.0069e-04 - total_loss: -3.5580
# Epoch 213/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.3873 - loss: -3.5693 - neg_log_likelihood: -6.6939 - reconstruction_error: 9.6557e-05 - total_loss: -3.5693
# Epoch 214/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.4850 - loss: -3.4927 - neg_log_likelihood: -6.6740 - reconstruction_error: 9.6396e-05 - total_loss: -3.4927
# Epoch 215/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5027 - loss: -3.5131 - neg_log_likelihood: -6.7047 - reconstruction_error: 9.4176e-05 - total_loss: -3.5131
# Epoch 216/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5144 - loss: -3.4711 - neg_log_likelihood: -6.6694 - reconstruction_error: 9.6120e-05 - total_loss: -3.4711
# Epoch 217/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5346 - loss: -3.5381 - neg_log_likelihood: -6.7482 - reconstruction_error: 9.0992e-05 - total_loss: -3.5381
# Epoch 218/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5427 - loss: -3.1365 - neg_log_likelihood: -6.3513 - reconstruction_error: 1.1492e-04 - total_loss: -3.1365
# Epoch 219/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.4199 - loss: -3.5971 - neg_log_likelihood: -6.7406 - reconstruction_error: 9.1744e-05 - total_loss: -3.5971
# Epoch 220/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.4687 - loss: -3.2967 - neg_log_likelihood: -6.4686 - reconstruction_error: 1.0693e-04 - total_loss: -3.2967
# Epoch 221/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5041 - loss: -3.6250 - neg_log_likelihood: -6.8174 - reconstruction_error: 8.6805e-05 - total_loss: -3.6250
# Epoch 222/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5669 - loss: -3.5185 - neg_log_likelihood: -6.7473 - reconstruction_error: 9.0403e-05 - total_loss: -3.5185
# Epoch 223/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5825 - loss: -3.5884 - neg_log_likelihood: -6.8263 - reconstruction_error: 8.5411e-05 - total_loss: -3.5884
# Epoch 224/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.5882 - loss: -3.5847 - neg_log_likelihood: -6.8259 - reconstruction_error: 8.5268e-05 - total_loss: -3.5847
# Epoch 225/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6035 - loss: -3.5054 - neg_log_likelihood: -6.7554 - reconstruction_error: 8.9072e-05 - total_loss: -3.5054
# Epoch 226/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6069 - loss: -3.5920 - neg_log_likelihood: -6.8439 - reconstruction_error: 8.3821e-05 - total_loss: -3.5920
# Epoch 227/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6252 - loss: -3.4853 - neg_log_likelihood: -6.7479 - reconstruction_error: 8.8918e-05 - total_loss: -3.4853
# Epoch 228/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6208 - loss: -3.6149 - neg_log_likelihood: -6.8749 - reconstruction_error: 8.1891e-05 - total_loss: -3.6149
# Epoch 229/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6338 - loss: -3.5534 - neg_log_likelihood: -6.8210 - reconstruction_error: 8.4543e-05 - total_loss: -3.5534
# Epoch 230/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6399 - loss: -3.5979 - neg_log_likelihood: -6.8691 - reconstruction_error: 8.1798e-05 - total_loss: -3.5979
# Epoch 231/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6533 - loss: -3.6509 - neg_log_likelihood: -6.9298 - reconstruction_error: 7.8270e-05 - total_loss: -3.6509
# Epoch 232/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6687 - loss: -3.5350 - neg_log_likelihood: -6.8229 - reconstruction_error: 8.3962e-05 - total_loss: -3.5350
# Epoch 233/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6458 - loss: -3.6480 - neg_log_likelihood: -6.9226 - reconstruction_error: 7.8535e-05 - total_loss: -3.6480
# Epoch 234/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6631 - loss: -3.6773 - neg_log_likelihood: -6.9619 - reconstruction_error: 7.6097e-05 - total_loss: -3.6773
# Epoch 235/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6994 - loss: -3.5806 - neg_log_likelihood: -6.8862 - reconstruction_error: 7.9824e-05 - total_loss: -3.5806
# Epoch 236/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6810 - loss: -3.4995 - neg_log_likelihood: -6.7945 - reconstruction_error: 8.4779e-05 - total_loss: -3.4995
# Epoch 237/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6522 - loss: -3.6829 - neg_log_likelihood: -6.9612 - reconstruction_error: 7.5813e-05 - total_loss: -3.6829
# Epoch 238/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.6634 - loss: -3.6886 - neg_log_likelihood: -6.9733 - reconstruction_error: 7.5270e-05 - total_loss: -3.6886
# Epoch 239/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7137 - loss: -3.6615 - neg_log_likelihood: -6.9754 - reconstruction_error: 7.4782e-05 - total_loss: -3.6615
# Epoch 240/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7330 - loss: -3.6906 - neg_log_likelihood: -7.0157 - reconstruction_error: 7.2381e-05 - total_loss: -3.6906
# Epoch 241/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7436 - loss: -3.6184 - neg_log_likelihood: -6.9497 - reconstruction_error: 7.5781e-05 - total_loss: -3.6184
# Epoch 242/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7450 - loss: -3.7066 - neg_log_likelihood: -7.0387 - reconstruction_error: 7.0988e-05 - total_loss: -3.7066
# Epoch 243/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7511 - loss: -3.6408 - neg_log_likelihood: -6.9764 - reconstruction_error: 7.3984e-05 - total_loss: -3.6408
# Epoch 244/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7447 - loss: -3.6657 - neg_log_likelihood: -6.9976 - reconstruction_error: 7.2939e-05 - total_loss: -3.6657
# Epoch 245/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7538 - loss: -3.6631 - neg_log_likelihood: -7.0003 - reconstruction_error: 7.2584e-05 - total_loss: -3.6631
# Epoch 246/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7464 - loss: -3.7207 - neg_log_likelihood: -7.0537 - reconstruction_error: 6.9893e-05 - total_loss: -3.7207
# Epoch 247/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7442 - loss: -3.6398 - neg_log_likelihood: -6.9714 - reconstruction_error: 7.3817e-05 - total_loss: -3.6398
# Epoch 248/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7432 - loss: -3.7024 - neg_log_likelihood: -7.0334 - reconstruction_error: 7.0734e-05 - total_loss: -3.7024
# Epoch 249/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7376 - loss: -3.7622 - neg_log_likelihood: -7.0900 - reconstruction_error: 6.7946e-05 - total_loss: -3.7622
# Epoch 250/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7762 - loss: -3.7398 - neg_log_likelihood: -7.0900 - reconstruction_error: 6.7714e-05 - total_loss: -3.7398
# Epoch 251/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7902 - loss: -3.5696 - neg_log_likelihood: -6.9279 - reconstruction_error: 7.5672e-05 - total_loss: -3.5696
# Epoch 252/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7617 - loss: -3.7716 - neg_log_likelihood: -7.1134 - reconstruction_error: 6.6305e-05 - total_loss: -3.7716
# Epoch 253/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7679 - loss: -3.7812 - neg_log_likelihood: -7.1265 - reconstruction_error: 6.5778e-05 - total_loss: -3.7812
# Epoch 254/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7995 - loss: -3.6811 - neg_log_likelihood: -7.0449 - reconstruction_error: 6.9392e-05 - total_loss: -3.6811
# Epoch 255/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7948 - loss: -3.6950 - neg_log_likelihood: -7.0560 - reconstruction_error: 6.8811e-05 - total_loss: -3.6950
# Epoch 256/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8044 - loss: -3.7353 - neg_log_likelihood: -7.1018 - reconstruction_error: 6.6457e-05 - total_loss: -3.7353
# Epoch 257/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8117 - loss: -3.6842 - neg_log_likelihood: -7.0550 - reconstruction_error: 6.8695e-05 - total_loss: -3.6842
# Epoch 258/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8079 - loss: -3.7861 - neg_log_likelihood: -7.1547 - reconstruction_error: 6.3779e-05 - total_loss: -3.7861
# Epoch 259/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8151 - loss: -3.6847 - neg_log_likelihood: -7.0575 - reconstruction_error: 6.8456e-05 - total_loss: -3.6847
# Epoch 260/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8134 - loss: -3.7071 - neg_log_likelihood: -7.0789 - reconstruction_error: 6.7390e-05 - total_loss: -3.7071
# Epoch 261/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8156 - loss: -3.7998 - neg_log_likelihood: -7.1729 - reconstruction_error: 6.2700e-05 - total_loss: -3.7998
# Epoch 262/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8301 - loss: -3.6667 - neg_log_likelihood: -7.0482 - reconstruction_error: 6.8608e-05 - total_loss: -3.6667
# Epoch 263/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8281 - loss: -3.7976 - neg_log_likelihood: -7.1779 - reconstruction_error: 6.2359e-05 - total_loss: -3.7976
# Epoch 264/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8381 - loss: -3.6553 - neg_log_likelihood: -7.0414 - reconstruction_error: 6.8825e-05 - total_loss: -3.6553
# Epoch 265/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8423 - loss: -3.8030 - neg_log_likelihood: -7.1915 - reconstruction_error: 6.1627e-05 - total_loss: -3.8030
# Epoch 266/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8512 - loss: -3.7603 - neg_log_likelihood: -7.1540 - reconstruction_error: 6.3290e-05 - total_loss: -3.7603
# Epoch 267/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.8477 - loss: -3.0527 - neg_log_likelihood: -6.4443 - reconstruction_error: 9.7875e-05 - total_loss: -3.0527
# Epoch 268/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.7599 - loss: -3.8159 - neg_log_likelihood: -7.1567 - reconstruction_error: 6.3053e-05 - total_loss: -3.8159
# Epoch 269/420
# ...
# Epoch 359/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9413 - loss: -3.9565 - neg_log_likelihood: -7.4025 - reconstruction_error: 5.0891e-05 - total_loss: -3.9565
# Epoch 360/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9377 - loss: -4.0164 - neg_log_likelihood: -7.4603 - reconstruction_error: 4.8078e-05 - total_loss: -4.0164
# Epoch 361/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9386 - loss: -3.9500 - neg_log_likelihood: -7.3944 - reconstruction_error: 5.1193e-05 - total_loss: -3.9500
# Epoch 362/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9370 - loss: -3.9494 - neg_log_likelihood: -7.3929 - reconstruction_error: 5.1005e-05 - total_loss: -3.9494
# Epoch 363/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9393 - loss: -3.9414 - neg_log_likelihood: -7.3862 - reconstruction_error: 5.1384e-05 - total_loss: -3.9414
# Epoch 364/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9403 - loss: -3.9559 - neg_log_likelihood: -7.4012 - reconstruction_error: 5.0690e-05 - total_loss: -3.9559
# Epoch 365/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9407 - loss: -4.0247 - neg_log_likelihood: -7.4703 - reconstruction_error: 4.7545e-05 - total_loss: -4.0247
# Epoch 366/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9417 - loss: -4.0294 - neg_log_likelihood: -7.4756 - reconstruction_error: 4.7588e-05 - total_loss: -4.0294
# Epoch 367/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9366 - loss: -3.8657 - neg_log_likelihood: -7.3089 - reconstruction_error: 5.4892e-05 - total_loss: -3.8657
# Epoch 368/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9374 - loss: -3.9719 - neg_log_likelihood: -7.4155 - reconstruction_error: 5.0202e-05 - total_loss: -3.9719
# Epoch 369/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9405 - loss: -3.9074 - neg_log_likelihood: -7.3529 - reconstruction_error: 5.3044e-05 - total_loss: -3.9074
# Epoch 370/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9405 - loss: -4.0144 - neg_log_likelihood: -7.4599 - reconstruction_error: 4.8118e-05 - total_loss: -4.0144
# Epoch 371/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9391 - loss: -4.0086 - neg_log_likelihood: -7.4532 - reconstruction_error: 4.8323e-05 - total_loss: -4.0086
# Epoch 372/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9397 - loss: -3.2273 - neg_log_likelihood: -6.6723 - reconstruction_error: 8.3920e-05 - total_loss: -3.2273
# Epoch 373/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9389 - loss: -4.0107 - neg_log_likelihood: -7.4553 - reconstruction_error: 4.8283e-05 - total_loss: -4.0107
# Epoch 374/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9378 - loss: -4.0519 - neg_log_likelihood: -7.4959 - reconstruction_error: 4.6336e-05 - total_loss: -4.0519
# Epoch 375/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9401 - loss: -4.0542 - neg_log_likelihood: -7.4995 - reconstruction_error: 4.6313e-05 - total_loss: -4.0542
# Epoch 376/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9403 - loss: -4.0479 - neg_log_likelihood: -7.4933 - reconstruction_error: 4.6624e-05 - total_loss: -4.0479
# Epoch 377/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9393 - loss: -4.0496 - neg_log_likelihood: -7.4944 - reconstruction_error: 4.6520e-05 - total_loss: -4.0496
# Epoch 378/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9384 - loss: -4.0289 - neg_log_likelihood: -7.4732 - reconstruction_error: 4.7407e-05 - total_loss: -4.0289
# Epoch 379/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9403 - loss: -3.9997 - neg_log_likelihood: -7.4451 - reconstruction_error: 4.8715e-05 - total_loss: -3.9997
# Epoch 380/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9399 - loss: -4.0130 - neg_log_likelihood: -7.4581 - reconstruction_error: 4.8218e-05 - total_loss: -4.0130
# Epoch 381/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9400 - loss: -3.9358 - neg_log_likelihood: -7.3810 - reconstruction_error: 5.1543e-05 - total_loss: -3.9358
# Epoch 382/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9380 - loss: -3.9998 - neg_log_likelihood: -7.4438 - reconstruction_error: 4.8736e-05 - total_loss: -3.9998
# Epoch 383/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9410 - loss: -3.9882 - neg_log_likelihood: -7.4340 - reconstruction_error: 4.9168e-05 - total_loss: -3.9882
# Epoch 384/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9409 - loss: -4.0004 - neg_log_likelihood: -7.4461 - reconstruction_error: 4.8557e-05 - total_loss: -4.0004
# Epoch 385/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9392 - loss: -3.9050 - neg_log_likelihood: -7.3498 - reconstruction_error: 5.3181e-05 - total_loss: -3.9050
# Epoch 386/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9390 - loss: -3.9835 - neg_log_likelihood: -7.4282 - reconstruction_error: 4.9531e-05 - total_loss: -3.9835
# Epoch 387/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9416 - loss: -3.9370 - neg_log_likelihood: -7.3832 - reconstruction_error: 5.1462e-05 - total_loss: -3.9370
# Epoch 388/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9358 - loss: -4.0134 - neg_log_likelihood: -7.4561 - reconstruction_error: 4.8215e-05 - total_loss: -4.0134
# Epoch 389/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9413 - loss: -4.0221 - neg_log_likelihood: -7.4681 - reconstruction_error: 4.7745e-05 - total_loss: -4.0221
# Epoch 390/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9375 - loss: -3.9720 - neg_log_likelihood: -7.4158 - reconstruction_error: 5.0014e-05 - total_loss: -3.9720
# Epoch 391/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9356 - loss: -3.9970 - neg_log_likelihood: -7.4397 - reconstruction_error: 4.8818e-05 - total_loss: -3.9970
# Epoch 392/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9397 - loss: -3.9736 - neg_log_likelihood: -7.4186 - reconstruction_error: 4.9937e-05 - total_loss: -3.9736
# Epoch 393/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9394 - loss: -4.0093 - neg_log_likelihood: -7.4541 - reconstruction_error: 4.8346e-05 - total_loss: -4.0093
# Epoch 394/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9412 - loss: -4.0409 - neg_log_likelihood: -7.4867 - reconstruction_error: 4.6811e-05 - total_loss: -4.0409
# Epoch 395/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9371 - loss: -3.8802 - neg_log_likelihood: -7.3238 - reconstruction_error: 5.4212e-05 - total_loss: -3.8802
# Epoch 396/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9400 - loss: -4.0041 - neg_log_likelihood: -7.4493 - reconstruction_error: 4.8356e-05 - total_loss: -4.0041
# Epoch 397/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9394 - loss: -4.0296 - neg_log_likelihood: -7.4745 - reconstruction_error: 4.7290e-05 - total_loss: -4.0296
# Epoch 398/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9360 - loss: -4.0400 - neg_log_likelihood: -7.4829 - reconstruction_error: 4.7086e-05 - total_loss: -4.0400
# Epoch 399/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9397 - loss: -4.0094 - neg_log_likelihood: -7.4545 - reconstruction_error: 4.8160e-05 - total_loss: -4.0094
# Epoch 400/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9409 - loss: -3.9583 - neg_log_likelihood: -7.4041 - reconstruction_error: 5.0371e-05 - total_loss: -3.9583
# Epoch 401/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9417 - loss: -3.7408 - neg_log_likelihood: -7.1870 - reconstruction_error: 6.0656e-05 - total_loss: -3.7408
# Epoch 402/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9406 - loss: -4.0367 - neg_log_likelihood: -7.4822 - reconstruction_error: 4.7108e-05 - total_loss: -4.0367
# Epoch 403/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9400 - loss: -4.0588 - neg_log_likelihood: -7.5040 - reconstruction_error: 4.5902e-05 - total_loss: -4.0588
# Epoch 404/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9396 - loss: -4.0343 - neg_log_likelihood: -7.4793 - reconstruction_error: 4.7397e-05 - total_loss: -4.0343
# Epoch 405/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9385 - loss: -3.9986 - neg_log_likelihood: -7.4429 - reconstruction_error: 4.8823e-05 - total_loss: -3.9986
# Epoch 406/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9388 - loss: -3.9822 - neg_log_likelihood: -7.4267 - reconstruction_error: 4.9708e-05 - total_loss: -3.9822
# Epoch 407/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9382 - loss: -4.0439 - neg_log_likelihood: -7.4881 - reconstruction_error: 4.6740e-05 - total_loss: -4.0439
# Epoch 408/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9425 - loss: -4.0426 - neg_log_likelihood: -7.4893 - reconstruction_error: 4.6692e-05 - total_loss: -4.0426
# Epoch 409/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9386 - loss: -3.9802 - neg_log_likelihood: -7.4245 - reconstruction_error: 4.9440e-05 - total_loss: -3.9802
# Epoch 410/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9386 - loss: -3.6846 - neg_log_likelihood: -7.1290 - reconstruction_error: 6.3156e-05 - total_loss: -3.6846
# Epoch 411/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9395 - loss: -3.9999 - neg_log_likelihood: -7.4448 - reconstruction_error: 4.8483e-05 - total_loss: -3.9999
# Epoch 412/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9400 - loss: -4.0037 - neg_log_likelihood: -7.4489 - reconstruction_error: 4.8602e-05 - total_loss: -4.0037
# Epoch 413/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9386 - loss: -4.0604 - neg_log_likelihood: -7.5047 - reconstruction_error: 4.5965e-05 - total_loss: -4.0604
# Epoch 414/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9384 - loss: -3.9180 - neg_log_likelihood: -7.3623 - reconstruction_error: 5.2470e-05 - total_loss: -3.9180
# Epoch 415/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9361 - loss: -4.0412 - neg_log_likelihood: -7.4842 - reconstruction_error: 4.7144e-05 - total_loss: -4.0412
# Epoch 416/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9373 - loss: -3.9670 - neg_log_likelihood: -7.4106 - reconstruction_error: 5.0391e-05 - total_loss: -3.9670
# Epoch 417/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9405 - loss: -4.0085 - neg_log_likelihood: -7.4540 - reconstruction_error: 4.8348e-05 - total_loss: -4.0085
# Epoch 418/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9395 - loss: -4.0265 - neg_log_likelihood: -7.4714 - reconstruction_error: 4.7546e-05 - total_loss: -4.0265
# Epoch 419/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9380 - loss: -3.9129 - neg_log_likelihood: -7.3570 - reconstruction_error: 5.2896e-05 - total_loss: -3.9129
# Epoch 420/420
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_divergence: 5.9391 - loss: -3.9737 - neg_log_likelihood: -7.4184 - reconstruction_error: 4.9982e-05 - total_loss: -3.9737
# Exportando modelo para produção (TF-Serving) em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/cvae_campeao_exported
# Saved artifact at '/content/drive/MyDrive/Temp/IQ_data/logs_runs/cvae_campeao_exported'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 2), dtype=tf.float32, name='x_in'), TensorSpec(shape=(None, 2), dtype=tf.float32, name='y_true')]
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   135932025191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932277078160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323715920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323713424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323723216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323724368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323724944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323715536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323711888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323715728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323716304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932323721680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377778128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377791568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377786768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377786576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377781776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377777744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135935724974352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135935724973584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932377792336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932344470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932344471760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932344468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135932344474064: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Salvando modelo em formato nativo Keras em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/cvae_campeao.keras
#
# Modelos salvos com sucesso nos dois formatos!
# ✅ Modelo campeão salvo em:
#    • /content/drive/MyDrive/Temp/IQ_data/logs_runs/cvae_campeao_exported   (SavedModel)
#    • /content/drive/MyDrive/Temp/IQ_data/logs_runs/cvae_campeao.keras (.keras)
#
# Gerando análises visuais e métricas para o modelo campeão...
# Plot de constelações salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/campeao_constelacao_plot.png
# Plot de histogramas de ruído salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/campeao_histogramas_ruido_plot.png
# Plot Q-Q salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/campeao_qq_plot.png
# Plot da curva de transferência salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/campeao_curva_transferencia_plot.png
# Plot do mapa de vetores de erro salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/campeao_mapa_vetores_erro_plot.png
# 🏆  MÉTRICAS DO MODELO CAMPEÃO  🏆
# ==================================================
# Hiperparâmetros:
#   layer1: 128
#   layer2: 256
#   layer3: 512
#   latent_dim: 48
#   beta: 0.58
#   batch_size: 20000
#   learning_rate: 0.0001
#   activation: leaky_relu
# ==================================================
# MÉTRICAS DE RECONSTRUÇÃO:
#   EVM (Ŷ vs X_test)          : 17.95% (-14.92 dB)
#   SNR (Ŷ vs X_test)          : 14.92 dB
#   RMSE (Ŷ vs X_test)         : 0.1464
#   MSE (Ŷ vs X_test)          : 0.0214
#   MAE (Ŷ vs X_test)          : 0.1286
#   PSNR (Ŷ vs X_test)         : 16.69 dB
#   Similaridade Cosseno        : 0.9839
#   Correlação                  : 0.9841
#
# MÉTRICAS DE DISTRIBUIÇÃO:
#   KL Divergence (Y_test||Ŷ)  : 0.0000
#   Jensen-Shannon Div. (Y,Ŷ)  : 0.0000
#
# TESTE KOLMOGOROV-SMIRNOV (Y_test vs Ŷ):
#   Componente I - Estatística  : 0.0016 (p-valor: 0.9790)
#   Componente Q - Estatística  : 0.0011 (p-valor: 0.9999)
#   Amplitude Sinal - Estatística: 0.0009 (p-valor: 1.0000)
#   Amplitude Ruído - Estatística: 0.0022 (p-valor: 0.7755)
# ==================================================
# Score final do modelo campeão: 3.7456
# Tempo de treinamento: 135.91 segundos
# Épocas treinadas: 420
# ==================================================
# Resumo das métricas salvo em: /content/drive/MyDrive/Temp/IQ_data/logs_runs/champion_model_summary.json
#
# 🎯 ANÁLISE DO MODELO CAMPEÃO CONCLUÍDA! 🎯
# Todos os plots e métricas foram salvos em: /content/drive/MyDrive/Temp/IQ_data/logs_runs
